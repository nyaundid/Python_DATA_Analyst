# %% [markdown]
# # Pulling data from public APIs (without registration) - GET request

# %%
# loading the packages
# requests provides us with the capabilities of sending an HTTP request to a server
import requests

# %% [markdown]
# ## Extracting data on currency exchange rates

# %%
# We will use an API containing currency exchange rates as published by the European Central Bank
# Documentation at https://exchangeratesapi.io

# %% [markdown]
# ### Sending a GET request

# %%
# Define the base URL
# Base URL: the part of the URL common to all requests, not containing the parameters
base_url = "http://api.exchangeratesapi.io/v1/latest?access_key=607afcc8df989a520b996d1f2bda8702"

# %%
# We can make a GET request to this API endpoint with requests.get
response = requests.get(base_url)

# This method returns the response from the server
# We store this response in a variable for future processing

# %% [markdown]
# ### Investigating the response

# %%
# Checking if the request went through ok
response.ok
# Out:
# True

# %%
# Checking the status code of the response
response.status_code
# Out:
# 200

# %%
# Inspecting the content body of the response (as a regular 'string')
response.text
# Out:
# '{"success":true,"timestamp":1617574386,"base":"EUR","date":"2021-04-04","rates":{"AED":4.321484,"AFN":90.88952,"ALL":123.127977,"AMD":627.31014,"ANG":2.105721,"AOA":741.213753,"ARS":107.96303,"AUD":1.545851,"AWG":2.117821,"AZN":2.014971,"BAM":1.95453,"BBD":2.368225,"BDT":99.456838,"BGN":1.956332,"BHD":0.44356,"BIF":2314.307902,"BMD":1.176567,"BND":1.579618,"BOB":8.110705,"BRL":6.715896,"BSD":1.17292,"BTC":2.0296277e-5,"BTN":86.148192,"BWP":12.933775,"BYN":3.094042,"BYR":23060.71931,"BZD":2.364227,"CAD":1.479098,"CDF":2350.781681,"CHF":1.108903,"CLF":0.030577,"CLP":843.712651,"CNY":7.727103,"COP":4308.236525,"CRC":720.153348,"CUC":1.176567,"CUP":31.179034,"CVE":110.655902,"CZK":26.093145,"DJF":209.099598,"DKK":7.437577,"DOP":67.017152,"DZD":157.778871,"EGP":18.500879,"ERN":17.648165,"ETB":48.70856,"EUR":1,"FJD":2.441966,"FKP":0.850803,"GBP":0.850841,"GEL":4.029757,"GGP":0.850803,"GHS":6.782918,"GIP":0.850803,"GMD":60.298999,"GNF":11753.907401,"GTQ":9.046082,"GYD":245.386761,"HKD":9.148823,"HNL":28.390272,"HRK":7.563208,"HTG":93.847725,"HUF":361.348527,"IDR":17103.759011,"ILS":3.918672,"IMP":0.850803,"INR":86.334215,"IQD":1720.729693,"IRR":49539.366364,"ISK":148.765238,"JEP":0.850803,"JMD":173.620016,"JOD":0.834202,"JPY":130.171842,"KES":128.127327,"KGS":99.772083,"KHR":4756.27205,"KMF":492.753395,"KPW":1058.76334,"KRW":1329.268079,"KWD":0.355312,"KYD":0.97745,"KZT":501.546356,"LAK":11059.733018,"LBP":1775.237356,"LKR":233.995539,"LRD":203.546527,"LSL":17.248452,"LTL":3.474098,"LVL":0.711693,"LYD":5.341775,"MAD":10.659107,"MDL":21.191503,"MGA":4459.189762,"MKD":61.574039,"MMK":1654.055822,"MNT":3358.577492,"MOP":9.39555,"MRO":420.034328,"MUR":47.519786,"MVR":18.189587,"MWK":923.604844,"MXN":23.877916,"MYR":4.87132,"MZN":78.889116,"NAD":17.248929,"NGN":448.271902,"NIO":41.29943,"NOK":10.038361,"NPR":137.860725,"NZD":1.674838,"OMR":0.453139,"PAB":1.17292,"PEN":4.403857,"PGK":4.15286,"PHP":57.126458,"PKR":180.661871,"PLN":4.603756,"PYG":7538.285304,"QAR":4.283587,"RON":4.924616,"RSD":117.501834,"RUB":89.954221,"RWF":1153.035965,"SAR":4.412657,"SBD":9.397652,"SCR":24.473927,"SDG":447.688638,"SEK":10.259514,"SGD":1.583248,"SHP":0.850803,"SLL":12015.691953,"SOS":689.468733,"SRD":16.653145,"STD":24242.115546,"SVC":10.263173,"SYP":1479.481397,"SZL":17.248286,"THB":36.861263,"TJS":13.373504,"TMT":4.129751,"TND":3.289099,"TOP":2.695867,"TRY":9.627556,"TTD":7.960404,"TWD":33.5857,"TZS":2728.459264,"UAH":32.656227,"UGX":4296.341943,"USD":1.176567,"UYU":52.047377,"UZS":12338.661371,"VEF":233264085898.67575,"VND":27149.290718,"VUV":129.560151,"WST":2.991203,"XAF":655.632302,"XAG":0.04717,"XAU":0.000681,"XCD":3.179732,"XDR":0.827776,"XOF":654.757865,"XPF":119.862804,"YER":294.553824,"ZAR":17.274432,"ZMK":10590.517952,"ZMW":25.906666,"ZWL":378.855064}}'

# %%
# Inspecting the content of the response (in 'bytes' format)
response.content
# Out:
# b'{"success":true,"timestamp":1617574386,"base":"EUR","date":"2021-04-04","rates":{"AED":4.321484,"AFN":90.88952,"ALL":123.127977,"AMD":627.31014,"ANG":2.105721,"AOA":741.213753,"ARS":107.96303,"AUD":1.545851,"AWG":2.117821,"AZN":2.014971,"BAM":1.95453,"BBD":2.368225,"BDT":99.456838,"BGN":1.956332,"BHD":0.44356,"BIF":2314.307902,"BMD":1.176567,"BND":1.579618,"BOB":8.110705,"BRL":6.715896,"BSD":1.17292,"BTC":2.0296277e-5,"BTN":86.148192,"BWP":12.933775,"BYN":3.094042,"BYR":23060.71931,"BZD":2.364227,"CAD":1.479098,"CDF":2350.781681,"CHF":1.108903,"CLF":0.030577,"CLP":843.712651,"CNY":7.727103,"COP":4308.236525,"CRC":720.153348,"CUC":1.176567,"CUP":31.179034,"CVE":110.655902,"CZK":26.093145,"DJF":209.099598,"DKK":7.437577,"DOP":67.017152,"DZD":157.778871,"EGP":18.500879,"ERN":17.648165,"ETB":48.70856,"EUR":1,"FJD":2.441966,"FKP":0.850803,"GBP":0.850841,"GEL":4.029757,"GGP":0.850803,"GHS":6.782918,"GIP":0.850803,"GMD":60.298999,"GNF":11753.907401,"GTQ":9.046082,"GYD":245.386761,"HKD":9.148823,"HNL":28.390272,"HRK":7.563208,"HTG":93.847725,"HUF":361.348527,"IDR":17103.759011,"ILS":3.918672,"IMP":0.850803,"INR":86.334215,"IQD":1720.729693,"IRR":49539.366364,"ISK":148.765238,"JEP":0.850803,"JMD":173.620016,"JOD":0.834202,"JPY":130.171842,"KES":128.127327,"KGS":99.772083,"KHR":4756.27205,"KMF":492.753395,"KPW":1058.76334,"KRW":1329.268079,"KWD":0.355312,"KYD":0.97745,"KZT":501.546356,"LAK":11059.733018,"LBP":1775.237356,"LKR":233.995539,"LRD":203.546527,"LSL":17.248452,"LTL":3.474098,"LVL":0.711693,"LYD":5.341775,"MAD":10.659107,"MDL":21.191503,"MGA":4459.189762,"MKD":61.574039,"MMK":1654.055822,"MNT":3358.577492,"MOP":9.39555,"MRO":420.034328,"MUR":47.519786,"MVR":18.189587,"MWK":923.604844,"MXN":23.877916,"MYR":4.87132,"MZN":78.889116,"NAD":17.248929,"NGN":448.271902,"NIO":41.29943,"NOK":10.038361,"NPR":137.860725,"NZD":1.674838,"OMR":0.453139,"PAB":1.17292,"PEN":4.403857,"PGK":4.15286,"PHP":57.126458,"PKR":180.661871,"PLN":4.603756,"PYG":7538.285304,"QAR":4.283587,"RON":4.924616,"RSD":117.501834,"RUB":89.954221,"RWF":1153.035965,"SAR":4.412657,"SBD":9.397652,"SCR":24.473927,"SDG":447.688638,"SEK":10.259514,"SGD":1.583248,"SHP":0.850803,"SLL":12015.691953,"SOS":689.468733,"SRD":16.653145,"STD":24242.115546,"SVC":10.263173,"SYP":1479.481397,"SZL":17.248286,"THB":36.861263,"TJS":13.373504,"TMT":4.129751,"TND":3.289099,"TOP":2.695867,"TRY":9.627556,"TTD":7.960404,"TWD":33.5857,"TZS":2728.459264,"UAH":32.656227,"UGX":4296.341943,"USD":1.176567,"UYU":52.047377,"UZS":12338.661371,"VEF":233264085898.67575,"VND":27149.290718,"VUV":129.560151,"WST":2.991203,"XAF":655.632302,"XAG":0.04717,"XAU":0.000681,"XCD":3.179732,"XDR":0.827776,"XOF":654.757865,"XPF":119.862804,"YER":294.553824,"ZAR":17.274432,"ZMK":10590.517952,"ZMW":25.906666,"ZWL":378.855064}}'

# %%
# The data is presented in JSON format

# %% [markdown]
# ### Handling the JSON

# %%
# Requests has in-build method to directly convert the response to JSON format
response.json()
# Out:
# {'success': True,
#  'timestamp': 1617574386,
#  'base': 'EUR',
#  'date': '2021-04-04',
#  'rates': {'AED': 4.321484,
#   'AFN': 90.88952,
#   'ALL': 123.127977,
#   'AMD': 627.31014,
#   'ANG': 2.105721,
#   'AOA': 741.213753,
#   'ARS': 107.96303,
#   'AUD': 1.545851,
#   'AWG': 2.117821,
#   'AZN': 2.014971,
#   'BAM': 1.95453,
#   'BBD': 2.368225,
#   'BDT': 99.456838,
#   'BGN': 1.956332,
#   'BHD': 0.44356,
#   'BIF': 2314.307902,
#   'BMD': 1.176567,
#   'BND': 1.579618,
#   'BOB': 8.110705,
#   'BRL': 6.715896,
#   'BSD': 1.17292,
#   'BTC': 2.0296277e-05,
#   'BTN': 86.148192,
#   'BWP': 12.933775,
#   'BYN': 3.094042,
#   'BYR': 23060.71931,
#   'BZD': 2.364227,
#   'CAD': 1.479098,
#   'CDF': 2350.781681,
#   'CHF': 1.108903,
#   'CLF': 0.030577,
#   'CLP': 843.712651,
#   'CNY': 7.727103,
#   'COP': 4308.236525,
#   'CRC': 720.153348,
#   'CUC': 1.176567,
#   'CUP': 31.179034,
#   'CVE': 110.655902,
#   'CZK': 26.093145,
#   'DJF': 209.099598,
#   'DKK': 7.437577,
#   'DOP': 67.017152,
#   'DZD': 157.778871,
#   'EGP': 18.500879,
#   'ERN': 17.648165,
#   'ETB': 48.70856,
#   'EUR': 1,
#   'FJD': 2.441966,
#   'FKP': 0.850803,
#   'GBP': 0.850841,
#   'GEL': 4.029757,
#   'GGP': 0.850803,
#   'GHS': 6.782918,
#   'GIP': 0.850803,
#   'GMD': 60.298999,
#   'GNF': 11753.907401,
#   'GTQ': 9.046082,
#   'GYD': 245.386761,
#   'HKD': 9.148823,
#   'HNL': 28.390272,
#   'HRK': 7.563208,
#   'HTG': 93.847725,
#   'HUF': 361.348527,
#   'IDR': 17103.759011,
#   'ILS': 3.918672,
#   'IMP': 0.850803,
#   'INR': 86.334215,
#   'IQD': 1720.729693,
#   'IRR': 49539.366364,
#   'ISK': 148.765238,
#   'JEP': 0.850803,
#   'JMD': 173.620016,
#   'JOD': 0.834202,
#   'JPY': 130.171842,
#   'KES': 128.127327,
#   'KGS': 99.772083,
#   'KHR': 4756.27205,
#   'KMF': 492.753395,
#   'KPW': 1058.76334,
#   'KRW': 1329.268079,
#   'KWD': 0.355312,
#   'KYD': 0.97745,
#   'KZT': 501.546356,
#   'LAK': 11059.733018,
#   'LBP': 1775.237356,
#   'LKR': 233.995539,
#   'LRD': 203.546527,
#   'LSL': 17.248452,
#   'LTL': 3.474098,
#   'LVL': 0.711693,
#   'LYD': 5.341775,
#   'MAD': 10.659107,
#   'MDL': 21.191503,
#   'MGA': 4459.189762,
#   'MKD': 61.574039,
#   'MMK': 1654.055822,
#   'MNT': 3358.577492,
#   'MOP': 9.39555,
#   'MRO': 420.034328,
#   'MUR': 47.519786,
#   'MVR': 18.189587,
#   'MWK': 923.604844,
#   'MXN': 23.877916,
#   'MYR': 4.87132,
#   'MZN': 78.889116,
#   'NAD': 17.248929,
#   'NGN': 448.271902,
#   'NIO': 41.29943,
#   'NOK': 10.038361,
#   'NPR': 137.860725,
#   'NZD': 1.674838,
#   'OMR': 0.453139,
#   'PAB': 1.17292,
#   'PEN': 4.403857,
#   'PGK': 4.15286,
#   'PHP': 57.126458,
#   'PKR': 180.661871,
#   'PLN': 4.603756,
#   'PYG': 7538.285304,
#   'QAR': 4.283587,
#   'RON': 4.924616,
#   'RSD': 117.501834,
#   'RUB': 89.954221,
#   'RWF': 1153.035965,
#   'SAR': 4.412657,
#   'SBD': 9.397652,
#   'SCR': 24.473927,
#   'SDG': 447.688638,
#   'SEK': 10.259514,
#   'SGD': 1.583248,
#   'SHP': 0.850803,
#   'SLL': 12015.691953,
#   'SOS': 689.468733,
#   'SRD': 16.653145,
#   'STD': 24242.115546,
#   'SVC': 10.263173,
#   'SYP': 1479.481397,
#   'SZL': 17.248286,
#   'THB': 36.861263,
#   'TJS': 13.373504,
#   'TMT': 4.129751,
#   'TND': 3.289099,
#   'TOP': 2.695867,
#   'TRY': 9.627556,
#   'TTD': 7.960404,
#   'TWD': 33.5857,
#   'TZS': 2728.459264,
#   'UAH': 32.656227,
#   'UGX': 4296.341943,
#   'USD': 1.176567,
#   'UYU': 52.047377,
#   'UZS': 12338.661371,
#   'VEF': 233264085898.67575,
#   'VND': 27149.290718,
#   'VUV': 129.560151,
#   'WST': 2.991203,
#   'XAF': 655.632302,
#   'XAG': 0.04717,
#   'XAU': 0.000681,
#   'XCD': 3.179732,
#   'XDR': 0.827776,
#   'XOF': 654.757865,
#   'XPF': 119.862804,
#   'YER': 294.553824,
#   'ZAR': 17.274432,
#   'ZMK': 10590.517952,
#   'ZMW': 25.906666,
#   'ZWL': 378.855064}}

# %%
# In Python, this JSON is stored as a dictionary
type(response.json())
# Out:
# dict

# %%
# A useful library for JSON manipulation and pretty print
import json

# It has two main methods:
# .loads(), which creates a Python dictionary from a JSON format string (just as response.json() does)
# .dumps(), which creates a JSON format string out of a Python dictionary

# %%
# .dumps() has options to make the string 'prettier', more readable
# We can choose the number of spaces to be used as indentation
json.dumps(response.json(), indent=4)
# Out:
# '{\n    "success": true,\n    "timestamp": 1617574386,\n    "base": "EUR",\n    "date": "2021-04-04",\n    "rates": {\n        "AED": 4.321484,\n        "AFN": 90.88952,\n        "ALL": 123.127977,\n        "AMD": 627.31014,\n        "ANG": 2.105721,\n        "AOA": 741.213753,\n        "ARS": 107.96303,\n        "AUD": 1.545851,\n        "AWG": 2.117821,\n        "AZN": 2.014971,\n        "BAM": 1.95453,\n        "BBD": 2.368225,\n        "BDT": 99.456838,\n        "BGN": 1.956332,\n        "BHD": 0.44356,\n        "BIF": 2314.307902,\n        "BMD": 1.176567,\n        "BND": 1.579618,\n        "BOB": 8.110705,\n        "BRL": 6.715896,\n        "BSD": 1.17292,\n        "BTC": 2.0296277e-05,\n        "BTN": 86.148192,\n        "BWP": 12.933775,\n        "BYN": 3.094042,\n        "BYR": 23060.71931,\n        "BZD": 2.364227,\n        "CAD": 1.479098,\n        "CDF": 2350.781681,\n        "CHF": 1.108903,\n        "CLF": 0.030577,\n        "CLP": 843.712651,\n        "CNY": 7.727103,\n        "COP": 4308.236525,\n        "CRC": 720.153348,\n        "CUC": 1.176567,\n        "CUP": 31.179034,\n        "CVE": 110.655902,\n        "CZK": 26.093145,\n        "DJF": 209.099598,\n        "DKK": 7.437577,\n        "DOP": 67.017152,\n        "DZD": 157.778871,\n        "EGP": 18.500879,\n        "ERN": 17.648165,\n        "ETB": 48.70856,\n        "EUR": 1,\n        "FJD": 2.441966,\n        "FKP": 0.850803,\n        "GBP": 0.850841,\n        "GEL": 4.029757,\n        "GGP": 0.850803,\n        "GHS": 6.782918,\n        "GIP": 0.850803,\n        "GMD": 60.298999,\n        "GNF": 11753.907401,\n        "GTQ": 9.046082,\n        "GYD": 245.386761,\n        "HKD": 9.148823,\n        "HNL": 28.390272,\n        "HRK": 7.563208,\n        "HTG": 93.847725,\n        "HUF": 361.348527,\n        "IDR": 17103.759011,\n        "ILS": 3.918672,\n        "IMP": 0.850803,\n        "INR": 86.334215,\n        "IQD": 1720.729693,\n        "IRR": 49539.366364,\n        "ISK": 148.765238,\n        "JEP": 0.850803,\n        "JMD": 173.620016,\n        "JOD": 0.834202,\n        "JPY": 130.171842,\n        "KES": 128.127327,\n        "KGS": 99.772083,\n        "KHR": 4756.27205,\n        "KMF": 492.753395,\n        "KPW": 1058.76334,\n        "KRW": 1329.268079,\n        "KWD": 0.355312,\n        "KYD": 0.97745,\n        "KZT": 501.546356,\n        "LAK": 11059.733018,\n        "LBP": 1775.237356,\n        "LKR": 233.995539,\n        "LRD": 203.546527,\n        "LSL": 17.248452,\n        "LTL": 3.474098,\n        "LVL": 0.711693,\n        "LYD": 5.341775,\n        "MAD": 10.659107,\n        "MDL": 21.191503,\n        "MGA": 4459.189762,\n        "MKD": 61.574039,\n        "MMK": 1654.055822,\n        "MNT": 3358.577492,\n        "MOP": 9.39555,\n        "MRO": 420.034328,\n        "MUR": 47.519786,\n        "MVR": 18.189587,\n        "MWK": 923.604844,\n        "MXN": 23.877916,\n        "MYR": 4.87132,\n        "MZN": 78.889116,\n        "NAD": 17.248929,\n        "NGN": 448.271902,\n        "NIO": 41.29943,\n        "NOK": 10.038361,\n        "NPR": 137.860725,\n        "NZD": 1.674838,\n        "OMR": 0.453139,\n        "PAB": 1.17292,\n        "PEN": 4.403857,\n        "PGK": 4.15286,\n        "PHP": 57.126458,\n        "PKR": 180.661871,\n        "PLN": 4.603756,\n        "PYG": 7538.285304,\n        "QAR": 4.283587,\n        "RON": 4.924616,\n        "RSD": 117.501834,\n        "RUB": 89.954221,\n        "RWF": 1153.035965,\n        "SAR": 4.412657,\n        "SBD": 9.397652,\n        "SCR": 24.473927,\n        "SDG": 447.688638,\n        "SEK": 10.259514,\n        "SGD": 1.583248,\n        "SHP": 0.850803,\n        "SLL": 12015.691953,\n        "SOS": 689.468733,\n        "SRD": 16.653145,\n        "STD": 24242.115546,\n        "SVC": 10.263173,\n        "SYP": 1479.481397,\n        "SZL": 17.248286,\n        "THB": 36.861263,\n        "TJS": 13.373504,\n        "TMT": 4.129751,\n        "TND": 3.289099,\n        "TOP": 2.695867,\n        "TRY": 9.62755 ...

# %%
# In order to visualize these changes, we need to print the string
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1617574386,
#     "base": "EUR",
#     "date": "2021-04-04",
#     "rates": {
#         "AED": 4.321484,
#         "AFN": 90.88952,
#         "ALL": 123.127977,
#         "AMD": 627.31014,
#         "ANG": 2.105721,
#         "AOA": 741.213753,
#         "ARS": 107.96303,
#         "AUD": 1.545851,
#         "AWG": 2.117821,
#         "AZN": 2.014971,
#         "BAM": 1.95453,
#         "BBD": 2.368225,
#         "BDT": 99.456838,
#         "BGN": 1.956332,
#         "BHD": 0.44356,
#         "BIF": 2314.307902,
#         "BMD": 1.176567,
#         "BND": 1.579618,
#         "BOB": 8.110705,
#         "BRL": 6.715896,
#         "BSD": 1.17292,
#         "BTC": 2.0296277e-05,
#         "BTN": 86.148192,
#         "BWP": 12.933775,
#         "BYN": 3.094042,
#         "BYR": 23060.71931,
#         "BZD": 2.364227,
#         "CAD": 1.479098,
#         "CDF": 2350.781681,
#         "CHF": 1.108903,
#         "CLF": 0.030577,
#         "CLP": 843.712651,
#         "CNY": 7.727103,
#         "COP": 4308.236525,
#         "CRC": 720.153348,
#         "CUC": 1.176567,
#         "CUP": 31.179034,
#         "CVE": 110.655902,
#         "CZK": 26.093145,
#         "DJF": 209.099598,
#         "DKK": 7.437577,
#         "DOP": 67.017152,
#         "DZD": 157.778871,
#         "EGP": 18.500879,
#         "ERN": 17.648165,
#         "ETB": 48.70856,
#         "EUR": 1,
#         "FJD": 2.441966,
#         "FKP": 0.850803,
#         "GBP": 0.850841,
#         "GEL": 4.029757,
#         "GGP": 0.850803,
#         "GHS": 6.782918,
#         "GIP": 0.850803,
#         "GMD": 60.298999,
#         "GNF": 11753.907401,
#         "GTQ": 9.046082,
#         "GYD": 245.386761,
#         "HKD": 9.148823,
#         "HNL": 28.390272,
#         "HRK": 7.563208,
#         "HTG": 93.847725,
#         "HUF": 361.348527,
#         "IDR": 17103.759011,
#         "ILS": 3.918672,
#         "IMP": 0.850803,
#         "INR": 86.334215,
#         "IQD": 1720.729693,
#         "IRR": 49539.366364,
#         "ISK": 148.765238,
#         "JEP": 0.850803,
#         "JMD": 173.620016,
#         "JOD": 0.834202,
#         "JPY": 130.171842,
#         "KES": 128.127327,
#         "KGS": 99.772083,
#         "KHR": 4756.27205,
#         "KMF": 492.753395,
#         "KPW": 1058.76334,
#         "KRW": 1329.268079,
#         "KWD": 0.355312,
#         "KYD": 0.97745,
#         "KZT": 501.546356,
#         "LAK": 11059.733018,
#         "LBP": 1775.237356,
#         "LKR": 233.995539,
#         "LRD": 203.546527,
#         "LSL": 17.248452,
#         "LTL": 3.474098,
#         "LVL": 0.711693,
#         "LYD": 5.341775,
#         "MAD": 10.659107,
#         "MDL": 21.191503,
#         "MGA": 4459.189762,
#         "MKD": 61.574039,
#         "MMK": 1654.055822,
#         "MNT": 3358.577492,
#         "MOP": 9.39555,
#         "MRO": 420.034328,
#         "MUR": 47.519786,
#         "MVR": 18.189587,
#         "MWK": 923.604844,
#         "MXN": 23.877916,
#         "MYR": 4.87132,
#         "MZN": 78.889116,
#         "NAD": 17.248929,
#         "NGN": 448.271902,
#         "NIO": 41.29943,
#         "NOK": 10.038361,
#         "NPR": 137.860725,
#         "NZD": 1.674838,
#         "OMR": 0.453139,
#         "PAB": 1.17292,
#         "PEN": 4.403857,
#         "PGK": 4.15286,
#         "PHP": 57.126458,
#         "PKR": 180.661871,
#         "PLN": 4.603756,
#         "PYG": 7538.285304,
#         "QAR": 4.283587,
#         "RON": 4.924616,
#         "RSD": 117.501834,
#         "RUB": 89.954221,
#         "RWF": 1153.035965,
#         "SAR": 4.412657,
#         "SBD": 9.397652,
#         "SCR": 24.473927,
#         "SDG": 447.688638,
#         "SEK": 10.259514,
#         "SGD": 1.583248,
#         "SHP": 0.850803,
#         "SLL": 12015.691953,
#         "SOS": 689.468733,
#         "SRD": 16.653145,
#         "STD": 24242.115546,
#         "SVC": 10.263173,
#         "SYP": 1479.481397,
#         "SZL": 17.248286,
#         "THB": 36.861263,
#         "TJS": 13.373504,
#         "TMT": 4.129751,
#         "TND": 3.289099,
#         "TOP": 2.695867,
#         "TRY": 9.627556,
#         "TTD": 7.960404,
#         "TWD": 33.5857,
#         "TZS": 2728.459264,
#         "UAH": 32.656227,
#         "UGX": 4296.341943,
#         "USD": 1.176567,
#         "UYU": 52.047377,
#         "UZS": 12338.661371,
#         "VEF": 233264085898.67575,
#         "VND": 27149.290718,
#         "VUV": 129.560151,
#         "WST": 2.991203,
#         "XAF": 655.632302,
#         "XAG": 0.04717,
#         "XAU": 0.000681,
#         "XCD": 3.179732,
#         "XDR": 0.827776,
#         "XOF": 654.757865,
#         "XPF": 119.862804,
#         "YER": 294.553824,
#         "ZAR": 17.274432,
#         "ZMK": 10590.517952,
#         "ZMW": 25.906666,
#         "ZWL": 378.855064
#     }
# }

# %%
# It contains 3 keys; the value for the 'rates' key is another dictionary
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %% [markdown]
# ### Incorporating parameters in the GET request

# %%
# Request parameters are added to the URL after a question mark '?'
# In this case, we request for the exchange rates of the US Dollar (USD) and Pound Sterling (GBP) only
param_url = base_url + "&symbols=USD,GBP"    
param_url
# Out:
# 'http://api.exchangeratesapi.io/v1/latest?access_key=607afcc8df989a520b996d1f2bda8702&symbols=USD,GBP'

# %%
# Making a request to the server with the new URL, containing the parameters
response = requests.get(param_url)
response.status_code
# Out:
# 200

# %%
# Saving the response data
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1617574386,
#  'base': 'EUR',
#  'date': '2021-04-04',
#  'rates': {'USD': 1.176567, 'GBP': 0.850841}}

# %%
# 'data' is a dictionary
data['base']
# Out:
# 'EUR'

# %%
data['date']
# Out:
# '2021-04-04'

# %%
data['rates']
# Out:
# {'USD': 1.176567, 'GBP': 0.850841}

# %%
# As per the documentation of this API, we can change the base with the parameter 'base'
param_url = base_url + "&symbols=GBP"

# %%
param_url = param_url + "& base = USD"

# %%
# Sending a request and saving the response JSON, all at once
data = requests.get(param_url).json()
data
# Out:
# {'success': True,
#  'timestamp': 1617574386,
#  'base': 'EUR',
#  'date': '2021-04-04',
#  'rates': {'GBP': 0.850841}}

# %%
usd_to_gbp = data['rates']['GBP']
usd_to_gbp
# Out:
# 0.850841

# %% [markdown]
# ### Obtaining historical exchange rates

# %%
base_url = "https://api.exchangeratesapi.io"

# %%
# We can also ask for the exhange rates at a particular day in the past with '/DATE', where DATE is in the format YYYY-MM-DD
historical_url = base_url + "/2016-01-26"
historical_url
# Out:
# 'https://api.exchangeratesapi.io/2016-01-26'

# %%
# Making the GET request
response = requests.get(historical_url)
response.status_code
# Out:
# 200

# %%
# Pretty printing the data
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": false,
#     "error": {
#         "code": 101,
#         "type": "missing_access_key",
#         "info": "You have not supplied an API Access Key. [Required format: access_key=YOUR_ACCESS_KEY]"
#     }
# }

# %% [markdown]
# ### Extracting data for a time period

# %%
# The last feautre of this API is: giving the historical exchange rates for every day over some time period

# %%
# The URL for this request is formed with '/history' and the parameters 'start_at' and 'end_at'
time_period = base_url + "/history" + "& start_date = 2017-04-26 & end_date = end_at=2018-04-26 & symbols = GBP"
time_period
# Out:
# 'https://api.exchangeratesapi.io/history& start_date = 2017-04-26 & end_date = end_at=2018-04-26 & symbols = GBP'

# %%
# Extracting the response JSON object
data = requests.get(time_period).json()

# %%
# Pretty printing the JSON
# Notice that the dates are in random order
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": false,
#     "error": {
#         "code": 101,
#         "type": "missing_access_key",
#         "info": "You have not supplied an API Access Key. [Required format: access_key=YOUR_ACCESS_KEY]"
#     }
# }

# %%
# We can use the 'sort_keys' parameter of the json.dumps() method to order these dates chronologically
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "error": {
#         "code": 101,
#         "info": "You have not supplied an API Access Key. [Required format: access_key=YOUR_ACCESS_KEY]",
#         "type": "missing_access_key"
#     },
#     "success": false
# }

# %%
# This data can then be used to plot the change in the exchange rate through time or any other further analysis

# %% [markdown]
# ### Testing the API response to incorrect input

# %%
# Testing how the API behaves if given incorrect input parameters

# %%
# Trying out an invalid DATE
invalid_url = base_url + "/2019-13-01"

# %%
# Making the request
response = requests.get(invalid_url)
response.status_code # The server responds with a 400 error code indicating a 'bad request'
# Out:
# 400

# %%
# There is also an error message in the JSON
response.json()
# Out:
# {'error': "time data '2019-13-01' does not match format '%Y-%m-%d'"}

# %%
# Testing an invalid BASE CURRENCY
invalid_url = base_url + "/2019-12-01?base=USB"

# %%
response = requests.get(invalid_url)
response.status_code
# Out:
# 400

# %%
response.json()
# Out:
# {'error': "Base 'USB' is not supported."}

# %%
# Testing an invalid EXCHANGE CURRENCY
invalid_url = base_url + "/2019-12-01?symbols=WBP"

# %%
response = requests.get(invalid_url)
response.status_code
# Out:
# 400

# %%
response.json()
# Out:
# {'error': "Symbols 'WBP' are invalid for date 2019-12-01."}

# %% [markdown]
# ### Creating a simple currency convertor

# %%
# We can use the data provided from this API to create a simple currency convertor

# %%
# Gathering input parameters from the user
date = input("Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): ")
base = input("Convert from (currency): ")
curr = input("Convert to (currency): ")
quan = float(input("How much {} do you want to convert: ".format(base)))

# Constructing the URL based on the user parameters and sending a request to the server
url = base_url + "/" + date + "?base=" + base + "&symbols=" + curr
response = requests.get(url)

# Displaying the error message, if something went wrong
if(response.ok is False):
    print("\nError {}:".format(response.status_code))
    print(response.json()['error'])

else:
    data = response.json()
    rate = data['rates'][curr]
    
    result = quan*rate
    
    print("\n{0} {1} is equal to {2} {3}, based upon exchange rates on {4}".format(quan,base,result,curr,data['date']))
# Out:
# Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): 2018-05-01
# Convert from (currency): USD
# Convert to (currency): S
# How much USD do you want to convert: 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-446-fa7df3a25668> in <module>
#      16 else:
#      17     data = response.json()
# ---> 18     rate = data['rates'][curr]
#      19
#      20     result = quan*rate
#
# KeyError: 'rates'

# %% [markdown]
# ## Another example: the iTunes search API

# %%
# The documentation for this particular API can be found here:
# https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/

# %% [markdown]
# ### Passing parameters in the request

# %%
# define base URL
base_site = "https://itunes.apple.com/search"

# %%
# We can manually add parameters to the URL, as seen before
# E.G., searching for 'the beatles'
url = base_site + "?term=the+beatles&country=us"

# submit a GET request with parameters needed
requests.get(url)
# Out:
# <Response [200]>

# %%
# Note, that the space in 'the beatles' was replaced with a '+' in the URL
# Having to worry about special symbols in the URL can make the code harder to write and 'more buggy'

# %%
# Another way of expressing the parameters is to pass them to the get() method
# We pass the key/value parameter pairs as a dictionary to 'params'

r = requests.get(base_site, params = {"term": "the beatles", "country": "us"})
r.status_code
# Out:
# 200

# %%
# The request package incorporates those paramaters into the URL automatically
# check the URL we submitted the request to
r.url
# Out:
# 'https://itunes.apple.com/search?term=the+beatles&country=us'

# %%
# This way of stating parameters is the preffered one

# %% [markdown]
# ### Investigating the output and parameters

# %%
# The request went through OK
r.status_code
# Out:
# 200

# %%
# Inspecting the response's JSON
info = r.json()
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815898,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "Here Comes the Sun",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "Here Comes the Sun (2019 Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/here-comes-the-sun-2019-mix/1474815798?i=1474815898&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/here-comes-the-sun-2019-mix/1474815798?i=1474815898&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/a4/d6/36/a4d6368e-731a-b2dc-d1a2-786e7886fbc1/mzaf_10527553788341453800.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 7,
#             "trackTimeMillis": 185707,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815799,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "Come Together",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "Come Together (2019 Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/come-together-2019-mix/1474815798?i=1474815799&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/come-together-2019-mix/1474815798?i=1474815799&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/3b/63/fb/3b63fbd0-d512-fa28-0278-8d0d4f01adad/mzaf_11251898970775172830.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 1,
#             "trackTimeMillis": 260200,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440834224,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Hey Jude",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Hey Jude (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/hey-jude-2015-stereo-mix/1440833098?i=1440834224&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/hey-jude-2015-stereo-mix/1440833098?i=1440834224&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/73/ac/8c/73ac8cf8-56db-34c6-10e6-8ff93f81b3c6/mzaf_7985505075688381983.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1968-08-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 21,
#             "trackTimeMillis": 425653,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833920,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "All You Need Is Love",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "All You Need Is Love (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/all-you-need-is-love-2015-stereo-mix/1440833098?i=1440833920&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/all-you-need-is-love-2015-stereo-mix/1440833098?i=1440833920&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/54/63/95/546395be-470a-be70-04d6-3b47951cad90/mzaf_8116058566388765711.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1967-07-07T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 18,
#             "trackTimeMillis": 227760,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441133100,
#             "trackId": 1441133277,
#             "artistName": "The Beatles",
#             "collectionName": "The Beatles 1967-1970 (The Blue Album)",
#             "trackName": "Hey Jude",
#             "collectionCensoredName": "The Beatles 1967-1970 (The Blue Album)",
#             "trackCensoredName": "Hey Jude",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/hey-jude/1441133100?i=1441133277&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/hey-jude/1441133100?i=1441133277&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/3a/10/49/3a10492d-3398-8ac3-536a-28f4fa4221d9/mzaf_3774318058101163645.plus.aac.p.m4a",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music128/v4/27/70/11/2770116d-0a57-f107-ba91-bd3679d44e5f/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music128/v4/27/70/11/2770116d-0a57-f107-ba91-bd3679d44e5f/source/60x60bb.jpg",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music128/v4/27/70/11/2770116d-0a57-f107-ba91-bd3679d44e5f/source/100x100bb.jpg",
#             "collectionPrice": 19.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1968-08-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 2,
#             "discNumber": 1,
#             "trackCount": 14,
#             "trackNumber": 13,
#             "trackTimeMillis": 431333,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441164495,
#             "trackId": 1441164738,
#             "artistName": "The Beatles",
#             "collectionName": "Let It Be",
#             "trackName": "Let It Be",
#             "collectionCensoredName": "Let It Be",
#             "trackCensoredName": "Let It Be",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/01/ff/05/01ff05d6-7892-4176-5efb-41a5438802d7/mzaf_8251314256578817405.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1970-03-06T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 12,
#             "trackNumber": 6,
#             "trackTimeMillis": 243027,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440834225,
#             "artistName": "The Beatles & Billy Preston",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Get Back",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Get Back (2015 Stereo Mix)",
#             "collectionArtistName": "The Beatles",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/get-back-2015-stereo-mix/1440833098?i=1440834225&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/get-back-2015-stereo-mix/1440833098?i=1440834225&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/b4/1c/cd/b41ccd3f-cfbe-19a2-d51d-328cdad05ce1/mzaf_1428995278865194672.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-04-11T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 22,
#             "trackTimeMillis": 191773,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441133180,
#             "trackId": 1441133834,
#             "artistName": "The Beatles",
#             "collectionName": "The Beatles (The White Album)",
#             "trackName": "Blackbird",
#             "collectionCensoredName": "The Beatles (The White Album)",
#             "trackCensoredName": "Blackbird",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/blackbird/1441133180?i=1441133834&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/blackbird/1441133180?i=1441133834&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/5d/42/3f/5d423ff6-a4f4-7810-a3db-3a92f3aeb203/mzaf_3688254684324179394.plus.aac.p.m4a",
#             "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/30x30bb.jpg",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/60x60bb.jpg",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/100x100bb.jpg",
#             "collectionPrice": 19.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1968-11-22T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 3,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 11,
#             "trackTimeMillis": 138387,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441164359,
#             "trackId": 1441164829,
#             "artistName": "The Beatles",
#             "collectionName": "Rubber Soul",
#             "trackName": "In My Life",
#             "collectionCensoredName": "Rubber Soul",
#             "trackCensoredName": "In My Life",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/in-my-life/1441164359?i=1441164829&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/in-my-life/1441164359?i=1441164829&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/31/ed/2f/31ed2f33-40e5-e7e9-1135-590c11b5449f/mzaf_5601204790489984849.plus.aac.p.m4a",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/ad/b6/b6/adb6b6d3-b3ee-ec61-10ea-91b173773b42/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/ad/b6/b6/adb6b6d3-b3ee-ec61-10ea-91b173773b42/source/60x60bb.jpg",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/ad/b6/b6/adb6b6d3-b3ee-ec61-10ea-91b173773b42/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1965-12-03T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 14,
#             "trackNumber": 11,
#             "trackTimeMillis": 146333,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833891,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Yesterday",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Yesterday (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/yesterday-2015-stereo-mix/1440833098?i=1440833891&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/yesterday-2015-stereo-mix/1440833098?i=1440833891&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/1c/26/c4/1c26c4fa-5376-3cb4-2274-6de1406b2d20/mzaf_1306707066957001602.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1965-09-13T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 11,
#             "trackTimeMillis": 125320,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833542,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "I Want to Hold Your Hand",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "I Want to Hold Your Hand (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/i-want-to-hold-your-hand-2015-stereo-mix/1440833098?i=1440833542&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/i-want-to-hold-your-hand-2015-stereo-mix/1440833098?i=1440833542&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/17/3f/a8/173fa821-b1d6-cc6c-4d31-0f43d6f53c6f/mzaf_5510883501742086084.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1963-11-29T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 4,
#             "trackTimeMillis": 145747,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833905,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Eleanor Rigby",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Eleanor Rigby (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/eleanor-rigby-2015-stereo-mix/1440833098?i=1440833905&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/eleanor-rigby-2015-stereo-mix/1440833098?i=1440833905&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/9d/ec/19/9dec1995-b48e-49f0-c699-ca60ae62d4ba/mzaf_3039771311118919537.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1966-08-05T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 16,
#             "trackTimeMillis": 125867,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833560,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Help!",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Help! (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/help-2015-stereo-mix/1440833098?i=1440833560&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/help-2015-stereo-mix/1440833098?i=1440833560&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/12/44/62/12446217-d3ff-a1ad-33fa-5cf39ad031b0/mzaf_5460530339045152975.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1965-07-19T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 10,
#             "trackTimeMillis": 139240,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440834249,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Let It Be",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Let It Be (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/let-it-be-2015-stereo-mix/1440833098?i=1440834249&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/let-it-be-2015-stereo-mix/1440833098?i=1440834249&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/4e/64/5c/4e645c61-8a6f-b733-605a-995f9c2cda3f/mzaf_1457302811904849737.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1970-03-06T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 26,
#             "trackTimeMillis": 230440,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833902,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Yellow Submarine",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Yellow Submarine (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/yellow-submarine-2015-stereo-mix/1440833098?i=1440833902&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/yellow-submarine-2015-stereo-mix/1440833098?i=1440833902&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/e7/7b/b1/e77bb1ff-5407-388e-d44a-eebdacc0d0ff/mzaf_6439049356747100214.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1966-08-05T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 15,
#             "trackTimeMillis": 158800,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833543,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Can't Buy Me Love",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Can't Buy Me Love (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/cant-buy-me-love-2015-stereo-mix/1440833098?i=1440833543&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/cant-buy-me-love-2015-stereo-mix/1440833098?i=1440833543&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/f7/8d/31/f78d319c-c991-2b84-1a26-822ab65e903d/mzaf_7847944666694571956.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1964-03-16T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 5,
#             "trackTimeMillis": 131213,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440834221,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Hello, Goodbye",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Hello, Goodbye (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/hello-goodbye-2015-stereo-mix/1440833098?i=1440834221&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/hello-goodbye-2015-stereo-mix/1440833098?i=1440834221&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/c6/16/36/c61636a1-a295-b0ea-01b1-348c5ec666c0/mzaf_7348360297735842592.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1967-11-24T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 19,
#             "trackTimeMillis": 207787,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833544,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "A Hard Day's Night",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "A Hard Day's Night (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/a-hard-days-night-2015-stereo-mix/1440833098?i=1440833544&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/a-hard-days-night-2015-stereo-mix/1440833098?i=1440833544&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/d6/d9/00/d6d900df-5c39-b5aa-59cf-4c8af2e5c226/mzaf_8010247441040680055.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1964-07-10T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 6,
#             "trackTimeMillis": 152920,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440834236,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Something",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Something (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/something-2015-stereo-mix/1440833098?i=1440834236&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/something-2015-stereo-mix/1440833098?i=1440834236&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/91/0f/f6/910ff66b-8ab0-8983-5d19-26464300f2c0/mzaf_2269981489538876608.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-10-06T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 24,
#             "trackTimeMillis": 181413,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833893,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Day Tripper",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Day Tripper (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/day-tripper-2015-stereo-mix/1440833098?i=1440833893&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/day-tripper-2015-stereo-mix/1440833098?i=1440833893&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/ed/9c/d5/ed9cd587-f7f6-1c6b-8dc3-f2f8d776a966/mzaf_7049642521360281009.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1965-12-03T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 12,
#             "trackTimeMillis": 169000,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833911,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Penny Lane",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Penny Lane (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/penny-lane-2015-stereo-mix/1440833098?i=1440833911&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/penny-lane-2015-stereo-mix/1440833098?i=1440833911&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/8a/64/99/8a649930-8993-73d2-022c-d167ee2fd4eb/mzaf_7922881405945652433.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1967-02-13T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 17,
#             "trackTimeMillis": 180520,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440834467,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "The Long and Winding Road",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "The Long and Winding Road (2015 Stereo Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/the-long-and-winding-road-2015-stereo-mix/1440833098?i=1440834467&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/the-long-and-winding-road-2015-stereo-mix/1440833098?i=1440834467&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/c0/94/4e/c0944ed5-3565-3fb0-e2f5-99b3677b14b6/mzaf_2502683357232279658.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1970-05-11T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 27,
#             "trackTimeMillis": 219427,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833334,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "Love Me Do",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "Love Me Do (Mono)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/love-me-do-mono/1440833098?i=1440833334&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/love-me-do-mono/1440833098?i=1440833334&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/55/55/0a/55550a59-706b-dd46-6a67-65632bd85031/mzaf_5890227976073220653.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1962-10-05T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 1,
#             "trackTimeMillis": 140173,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1440833098,
#             "trackId": 1440833539,
#             "artistName": "The Beatles",
#             "collectionName": "1 (2015 Version)",
#             "trackName": "She Loves You",
#             "collectionCensoredName": "1 (2015 Version)",
#             "trackCensoredName": "She Loves You (Mono)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/she-loves-you-mono/1440833098?i=1440833539&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/she-loves-you-mono/1440833098?i=1440833539&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/70/dc/e4/70dce47e-fd19-01f6-e2bb-e77e21c4646c/mzaf_7313969891523882345.plus.aac.p.m4a",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1963-08-23T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 27,
#             "trackNumber": 3,
#             "trackTimeMillis": 140920,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441164604,
#             "trackId": 1441165168,
#             "artistName": "The Beatles",
#             "collectionName": "Sgt. Pepper's Lonely Hearts Club Band",
#             "trackName": "A Day In the Life",
#             "collectionCensoredName": "Sgt. Pepper's Lonely Hearts Club Band",
#             "trackCensoredName": "A Day In the Life",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/a-day-in-the-life/1441164604?i=1441165168&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/a-day-in-the-life/1441164604?i=1441165168&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/9b/ae/66/9bae6668-be06-396c-e7f6-69c4ee6b108d/mzaf_3640527744551969508.plus.aac.p.m4a",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/60x60bb.jpg",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1967-06-01T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
# ...
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 13,
#             "trackNumber": 3,
#             "trackTimeMillis": 208467,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441133180,
#             "trackId": 1441134086,
#             "artistName": "The Beatles",
#             "collectionName": "The Beatles (The White Album)",
#             "trackName": "Birthday",
#             "collectionCensoredName": "The Beatles (The White Album)",
#             "trackCensoredName": "Birthday",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/birthday/1441133180?i=1441134086&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/birthday/1441133180?i=1441134086&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/4d/3e/0e/4d3e0e54-3667-2906-59a9-454ee5058eb7/mzaf_5595264265348220958.plus.aac.p.m4a",
#             "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/30x30bb.jpg",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/60x60bb.jpg",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/100x100bb.jpg",
#             "collectionPrice": 19.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1968-11-22T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 3,
#             "discNumber": 2,
#             "trackCount": 13,
#             "trackNumber": 1,
#             "trackTimeMillis": 162080,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815905,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "Golden Slumbers",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "Golden Slumbers (2019 Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/golden-slumbers-2019-mix/1474815798?i=1474815905&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/golden-slumbers-2019-mix/1474815798?i=1474815905&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/25/c4/55/25c455ff-dbc0-ea4c-72eb-08bcd54ba89b/mzaf_5723773389855252051.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 14,
#             "trackTimeMillis": 91440,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815805,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "Octopus's Garden",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "Octopus's Garden (2019 Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/octopuss-garden-2019-mix/1474815798?i=1474815805&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/octopuss-garden-2019-mix/1474815798?i=1474815805&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview113/v4/c1/e8/1e/c1e81e29-f5ca-85d7-b713-1e0933a8d656/mzaf_13202177110968274844.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 5,
#             "trackTimeMillis": 170800,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815897,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "I Want You (She's So Heavy)",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "I Want You (She's So Heavy) [2019 Mix]",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/i-want-you-shes-so-heavy-2019-mix/1474815798?i=1474815897&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/i-want-you-shes-so-heavy-2019-mix/1474815798?i=1474815897&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/1a/b6/65/1ab6656e-ecd1-22f6-f351-e67c91b81878/mzaf_13316589927474516588.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 6,
#             "trackTimeMillis": 467360,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815803,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "Maxwell's Silver Hammer",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "Maxwell's Silver Hammer (2019 Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/maxwells-silver-hammer-2019-mix/1474815798?i=1474815803&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/maxwells-silver-hammer-2019-mix/1474815798?i=1474815803&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/83/1c/f3/831cf359-9671-fcb5-eeef-99d8249c5222/mzaf_5276904707735092268.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 3,
#             "trackTimeMillis": 207973,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441164604,
#             "trackId": 1441164866,
#             "artistName": "The Beatles",
#             "collectionName": "Sgt. Pepper's Lonely Hearts Club Band",
#             "trackName": "When I'm Sixty-Four",
#             "collectionCensoredName": "Sgt. Pepper's Lonely Hearts Club Band",
#             "trackCensoredName": "When I'm Sixty-Four",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/when-im-sixty-four/1441164604?i=1441164866&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/when-im-sixty-four/1441164604?i=1441164866&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/b2/96/fb/b296fb7e-334c-ab6d-6125-974d2deec6c8/mzaf_3175631363684734163.plus.aac.p.m4a",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/60x60bb.jpg",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/100x100bb.jpg",
#             "collectionPrice": 12.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1967-06-01T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 13,
#             "trackNumber": 9,
#             "trackTimeMillis": 157667,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": true
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815907,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "The End",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "The End (2019 Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/the-end-2019-mix/1474815798?i=1474815907&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/the-end-2019-mix/1474815798?i=1474815907&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/b7/03/93/b7039348-b3a4-1cdf-f48c-08a07f62fec4/mzaf_14155732651427747313.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 16,
#             "trackTimeMillis": 141907,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         },
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1474815798,
#             "trackId": 1474815900,
#             "artistName": "The Beatles",
#             "collectionName": "Abbey Road (2019 Mix)",
#             "trackName": "You Never Give Me Your Money",
#             "collectionCensoredName": "Abbey Road (2019 Mix)",
#             "trackCensoredName": "You Never Give Me Your Money (2019 Mix)",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/you-never-give-me-your-money-2019-mix/1474815798?i=1474815900&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/you-never-give-me-your-money-2019-mix/1474815798?i=1474815900&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/0a/68/32/0a68328d-c56c-831d-305e-e580e22d10e9/mzaf_4384933536595479445.plus.aac.p.m4a",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#             "collectionPrice": 9.99,
#             "trackPrice": 1.29,
#             "releaseDate": "1969-09-26T12:00:00Z",
#             "collectionExplicitness": "notExplicit",
#             "trackExplicitness": "notExplicit",
#             "discCount": 1,
#             "discNumber": 1,
#             "trackCount": 17,
#             "trackNumber": 9,
#             "trackTimeMillis": 242667,
#             "country": "USA",
#             "currency": "USD",
#             "primaryGenreName": "Rock",
#             "isStreamable": false
#         }
#     ]
# }

# %%
# This seems to contain a lot of data
# Let's check if there are some keys we don't see at first glance in the outermost dictionary
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
# There are, indeed, only these two keys

# %%
# The second one contains a list of all the results
# Let's look at one such result
print(json.dumps(info['results'][0], indent=4))

# It's a simple dictionary with a lot of data
# Out:
# {
#     "wrapperType": "track",
#     "kind": "song",
#     "artistId": 136975,
#     "collectionId": 1474815798,
#     "trackId": 1474815898,
#     "artistName": "The Beatles",
#     "collectionName": "Abbey Road (2019 Mix)",
#     "trackName": "Here Comes the Sun",
#     "collectionCensoredName": "Abbey Road (2019 Mix)",
#     "trackCensoredName": "Here Comes the Sun (2019 Mix)",
#     "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#     "collectionViewUrl": "https://music.apple.com/us/album/here-comes-the-sun-2019-mix/1474815798?i=1474815898&uo=4",
#     "trackViewUrl": "https://music.apple.com/us/album/here-comes-the-sun-2019-mix/1474815798?i=1474815898&uo=4",
#     "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/a4/d6/36/a4d6368e-731a-b2dc-d1a2-786e7886fbc1/mzaf_10527553788341453800.plus.aac.p.m4a",
#     "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg",
#     "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg",
#     "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg",
#     "collectionPrice": 9.99,
#     "trackPrice": 1.29,
#     "releaseDate": "1969-09-26T12:00:00Z",
#     "collectionExplicitness": "notExplicit",
#     "trackExplicitness": "notExplicit",
#     "discCount": 1,
#     "discNumber": 1,
#     "trackCount": 17,
#     "trackNumber": 7,
#     "trackTimeMillis": 185707,
#     "country": "USA",
#     "currency": "USD",
#     "primaryGenreName": "Rock",
#     "isStreamable": false
# }

# %%
# The first one states how many results are shown (by default, 50)
info["resultCount"]
# Out:
# 50

# %%
# The number of results can be set (to a maximum of 200) with the 'limit' parameter
r = requests.get(base_site, params = {"term": "the beatles", "country": "us", "limit": 200})
r.ok
# Out:
# True

# %%
info = r.json()
info
# Out:
# {'resultCount': 200,
#  'results': [{'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 136975,
#    'collectionId': 1441164604,
#    'trackId': 1441165171,
#    'artistName': 'The Beatles',
#    'collectionName': "Sgt. Pepper's Lonely Hearts Club Band",
#    'trackName': "Sgt. Pepper's Lonely Hearts Club Band",
#    'collectionCensoredName': "Sgt. Pepper's Lonely Hearts Club Band",
#    'trackCensoredName': "Sgt. Pepper's Lonely Hearts Club Band (Documentary)",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/music-video/sgt-peppers-lonely-hearts-club-band-documentary/1441165171?uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/music-video/sgt-peppers-lonely-hearts-club-band-documentary/1441165171?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/8d/74/1b/8d741b7f-065c-9ca4-bb11-eea38036f0ed/mzvf_7632512548032049898.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video62/v4/cc/8f/7b/cc8f7b9a-27d3-8067-c489-51a5983d2135/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video62/v4/cc/8f/7b/cc8f7b9a-27d3-8067-c489-51a5983d2135/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video62/v4/cc/8f/7b/cc8f7b9a-27d3-8067-c489-51a5983d2135/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2019-05-22T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 15,
#    'trackNumber': 14,
#    'trackTimeMillis': 248480,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 136975,
#    'collectionId': 1441133180,
#    'trackId': 1441134703,
#    'artistName': 'The Beatles',
#    'collectionName': 'The Beatles (The White Album)',
#    'trackName': 'The Beatles',
#    'collectionCensoredName': 'The Beatles (The White Album)',
#    'trackCensoredName': 'The Beatles (Documentary)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/music-video/the-beatles-documentary/1441134703?uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/music-video/the-beatles-documentary/1441134703?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video128/v4/32/a2/13/32a21383-7e17-e8ae-e0e0-bf6b78144fc0/mzvf_7037047804382233330.640x478.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video118/v4/99/45/26/99452619-7170-6390-a0b9-81ca068e02f7/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video118/v4/99/45/26/99452619-7170-6390-a0b9-81ca068e02f7/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video118/v4/99/45/26/99452619-7170-6390-a0b9-81ca068e02f7/source/100x100bb.jpg',
#    'collectionPrice': 19.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2019-05-22T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 3,
#    'discNumber': 3,
#    'trackCount': 32,
#    'trackNumber': 1,
#    'trackTimeMillis': 331490,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 136975,
#    'collectionId': 1441164359,
#    'trackId': 1441164850,
#    'artistName': 'The Beatles',
#    'collectionName': 'Rubber Soul',
#    'trackName': 'Rubber Soul',
#    'collectionCensoredName': 'Rubber Soul',
#    'trackCensoredName': 'Rubber Soul (Documentary)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/music-video/rubber-soul-documentary/1441164850?uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/music-video/rubber-soul-documentary/1441164850?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/67/f1/0e/67f10e34-9ad9-e7d7-ad48-4ec42da74b6b/mzvf_4470525888351062244.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video62/v4/1d/5e/6a/1d5e6a4c-0bf2-08d3-b298-182a3e8c0217/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video62/v4/1d/5e/6a/1d5e6a4c-0bf2-08d3-b298-182a3e8c0217/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video62/v4/1d/5e/6a/1d5e6a4c-0bf2-08d3-b298-182a3e8c0217/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2019-05-22T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 15,
#    'trackTimeMillis': 198000,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 136975,
#    'collectionId': 1441164670,
#    'trackId': 1441165242,
#    'artistName': 'The Beatles',
#    'collectionName': 'Revolver',
#    'trackName': 'Revolver',
#    'collectionCensoredName': 'Revolver',
#    'trackCensoredName': 'Revolver (Documentary)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/music-video/revolver-documentary/1441165242?uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/music-video/revolver-documentary/1441165242?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/d7/a7/89/d7a7891f-4e42-0e92-545c-ea6f1496b144/mzvf_2971689869222531886.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video118/v4/32/09/58/32095813-c73a-991a-5d34-d26ae0781fae/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video118/v4/32/09/58/32095813-c73a-991a-5d34-d26ae0781fae/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video118/v4/32/09/58/32095813-c73a-991a-5d34-d26ae0781fae/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2019-05-22T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 15,
#    'trackTimeMillis': 233000,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1474815798,
#    'trackId': 1474815898,
#    'artistName': 'The Beatles',
#    'collectionName': 'Abbey Road (2019 Mix)',
#    'trackName': 'Here Comes the Sun',
#    'collectionCensoredName': 'Abbey Road (2019 Mix)',
#    'trackCensoredName': 'Here Comes the Sun (2019 Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/here-comes-the-sun-2019-mix/1474815798?i=1474815898&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/here-comes-the-sun-2019-mix/1474815798?i=1474815898&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/a4/d6/36/a4d6368e-731a-b2dc-d1a2-786e7886fbc1/mzaf_10527553788341453800.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-09-26T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 17,
#    'trackNumber': 7,
#    'trackTimeMillis': 185707,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': False},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1474815798,
#    'trackId': 1474815799,
#    'artistName': 'The Beatles',
#    'collectionName': 'Abbey Road (2019 Mix)',
#    'trackName': 'Come Together',
#    'collectionCensoredName': 'Abbey Road (2019 Mix)',
#    'trackCensoredName': 'Come Together (2019 Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/come-together-2019-mix/1474815798?i=1474815799&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/come-together-2019-mix/1474815798?i=1474815799&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview123/v4/3b/63/fb/3b63fbd0-d512-fa28-0278-8d0d4f01adad/mzaf_11251898970775172830.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music114/v4/2a/f9/04/2af904cd-f05a-d5a1-8014-c1387855b56c/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-09-26T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 17,
#    'trackNumber': 1,
#    'trackTimeMillis': 260200,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': False},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440834224,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Hey Jude',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Hey Jude (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/hey-jude-2015-stereo-mix/1440833098?i=1440834224&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/hey-jude-2015-stereo-mix/1440833098?i=1440834224&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/73/ac/8c/73ac8cf8-56db-34c6-10e6-8ff93f81b3c6/mzaf_7985505075688381983.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1968-08-26T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 21,
#    'trackTimeMillis': 425653,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833920,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'All You Need Is Love',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'All You Need Is Love (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/all-you-need-is-love-2015-stereo-mix/1440833098?i=1440833920&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/all-you-need-is-love-2015-stereo-mix/1440833098?i=1440833920&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/54/63/95/546395be-470a-be70-04d6-3b47951cad90/mzaf_8116058566388765711.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1967-07-07T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 18,
#    'trackTimeMillis': 227760,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441133100,
#    'trackId': 1441133277,
#    'artistName': 'The Beatles',
#    'collectionName': 'The Beatles 1967-1970 (The Blue Album)',
#    'trackName': 'Hey Jude',
#    'collectionCensoredName': 'The Beatles 1967-1970 (The Blue Album)',
#    'trackCensoredName': 'Hey Jude',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/hey-jude/1441133100?i=1441133277&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/hey-jude/1441133100?i=1441133277&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/3a/10/49/3a10492d-3398-8ac3-536a-28f4fa4221d9/mzaf_3774318058101163645.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music128/v4/27/70/11/2770116d-0a57-f107-ba91-bd3679d44e5f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music128/v4/27/70/11/2770116d-0a57-f107-ba91-bd3679d44e5f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music128/v4/27/70/11/2770116d-0a57-f107-ba91-bd3679d44e5f/source/100x100bb.jpg',
#    'collectionPrice': 19.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1968-08-26T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 1,
#    'trackCount': 14,
#    'trackNumber': 13,
#    'trackTimeMillis': 431333,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164495,
#    'trackId': 1441164738,
#    'artistName': 'The Beatles',
#    'collectionName': 'Let It Be',
#    'trackName': 'Let It Be',
#    'collectionCensoredName': 'Let It Be',
#    'trackCensoredName': 'Let It Be',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/01/ff/05/01ff05d6-7892-4176-5efb-41a5438802d7/mzaf_8251314256578817405.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1970-03-06T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 6,
#    'trackTimeMillis': 243027,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440834225,
#    'artistName': 'The Beatles & Billy Preston',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Get Back',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Get Back (2015 Stereo Mix)',
#    'collectionArtistName': 'The Beatles',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/get-back-2015-stereo-mix/1440833098?i=1440834225&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/get-back-2015-stereo-mix/1440833098?i=1440834225&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/b4/1c/cd/b41ccd3f-cfbe-19a2-d51d-328cdad05ce1/mzaf_1428995278865194672.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-04-11T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 22,
#    'trackTimeMillis': 191773,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441133180,
#    'trackId': 1441133834,
#    'artistName': 'The Beatles',
#    'collectionName': 'The Beatles (The White Album)',
#    'trackName': 'Blackbird',
#    'collectionCensoredName': 'The Beatles (The White Album)',
#    'trackCensoredName': 'Blackbird',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/blackbird/1441133180?i=1441133834&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/blackbird/1441133180?i=1441133834&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/5d/42/3f/5d423ff6-a4f4-7810-a3db-3a92f3aeb203/mzaf_3688254684324179394.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/96/37/2e/96372e6e-be99-74bd-e2ab-8c2fe6b1ca25/source/100x100bb.jpg',
#    'collectionPrice': 19.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1968-11-22T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 3,
#    'discNumber': 1,
#    'trackCount': 17,
#    'trackNumber': 11,
#    'trackTimeMillis': 138387,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164359,
#    'trackId': 1441164829,
#    'artistName': 'The Beatles',
#    'collectionName': 'Rubber Soul',
#    'trackName': 'In My Life',
#    'collectionCensoredName': 'Rubber Soul',
#    'trackCensoredName': 'In My Life',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/in-my-life/1441164359?i=1441164829&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/in-my-life/1441164359?i=1441164829&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/31/ed/2f/31ed2f33-40e5-e7e9-1135-590c11b5449f/mzaf_5601204790489984849.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/ad/b6/b6/adb6b6d3-b3ee-ec61-10ea-91b173773b42/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/ad/b6/b6/adb6b6d3-b3ee-ec61-10ea-91b173773b42/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/ad/b6/b6/adb6b6d3-b3ee-ec61-10ea-91b173773b42/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-12-03T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 14,
#    'trackNumber': 11,
#    'trackTimeMillis': 146333,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833891,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Yesterday',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Yesterday (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/yesterday-2015-stereo-mix/1440833098?i=1440833891&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/yesterday-2015-stereo-mix/1440833098?i=1440833891&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/1c/26/c4/1c26c4fa-5376-3cb4-2274-6de1406b2d20/mzaf_1306707066957001602.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-09-13T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 11,
#    'trackTimeMillis': 125320,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833542,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'I Want to Hold Your Hand',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'I Want to Hold Your Hand (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/i-want-to-hold-your-hand-2015-stereo-mix/1440833098?i=1440833542&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/i-want-to-hold-your-hand-2015-stereo-mix/1440833098?i=1440833542&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/17/3f/a8/173fa821-b1d6-cc6c-4d31-0f43d6f53c6f/mzaf_5510883501742086084.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1963-11-29T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 4,
#    'trackTimeMillis': 145747,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833905,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Eleanor Rigby',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Eleanor Rigby (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/eleanor-rigby-2015-stereo-mix/1440833098?i=1440833905&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/eleanor-rigby-2015-stereo-mix/1440833098?i=1440833905&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/9d/ec/19/9dec1995-b48e-49f0-c699-ca60ae62d4ba/mzaf_3039771311118919537.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1966-08-05T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 16,
#    'trackTimeMillis': 125867,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833560,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Help!',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Help! (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/help-2015-stereo-mix/1440833098?i=1440833560&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/help-2015-stereo-mix/1440833098?i=1440833560&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/12/44/62/12446217-d3ff-a1ad-33fa-5cf39ad031b0/mzaf_5460530339045152975.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-07-19T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 10,
#    'trackTimeMillis': 139240,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440834249,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Let It Be',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Let It Be (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/let-it-be-2015-stereo-mix/1440833098?i=1440834249&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/let-it-be-2015-stereo-mix/1440833098?i=1440834249&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/4e/64/5c/4e645c61-8a6f-b733-605a-995f9c2cda3f/mzaf_1457302811904849737.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1970-03-06T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 26,
#    'trackTimeMillis': 230440,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833902,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Yellow Submarine',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Yellow Submarine (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/yellow-submarine-2015-stereo-mix/1440833098?i=1440833902&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/yellow-submarine-2015-stereo-mix/1440833098?i=1440833902&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/e7/7b/b1/e77bb1ff-5407-388e-d44a-eebdacc0d0ff/mzaf_6439049356747100214.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1966-08-05T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 15,
#    'trackTimeMillis': 158800,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833543,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': "Can't Buy Me Love",
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': "Can't Buy Me Love (2015 Stereo Mix)",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cant-buy-me-love-2015-stereo-mix/1440833098?i=1440833543&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cant-buy-me-love-2015-stereo-mix/1440833098?i=1440833543&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/f7/8d/31/f78d319c-c991-2b84-1a26-822ab65e903d/mzaf_7847944666694571956.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1964-03-16T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 5,
#    'trackTimeMillis': 131213,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440834221,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Hello, Goodbye',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Hello, Goodbye (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/hello-goodbye-2015-stereo-mix/1440833098?i=1440834221&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/hello-goodbye-2015-stereo-mix/1440833098?i=1440834221&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/c6/16/36/c61636a1-a295-b0ea-01b1-348c5ec666c0/mzaf_7348360297735842592.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1967-11-24T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 19,
#    'trackTimeMillis': 207787,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833544,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': "A Hard Day's Night",
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': "A Hard Day's Night (2015 Stereo Mix)",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/a-hard-days-night-2015-stereo-mix/1440833098?i=1440833544&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/a-hard-days-night-2015-stereo-mix/1440833098?i=1440833544&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/d6/d9/00/d6d900df-5c39-b5aa-59cf-4c8af2e5c226/mzaf_8010247441040680055.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1964-07-10T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 6,
#    'trackTimeMillis': 152920,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440834236,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Something',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Something (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/something-2015-stereo-mix/1440833098?i=1440834236&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/something-2015-stereo-mix/1440833098?i=1440834236&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/91/0f/f6/910ff66b-8ab0-8983-5d19-26464300f2c0/mzaf_2269981489538876608.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-10-06T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 24,
#    'trackTimeMillis': 181413,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833893,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Day Tripper',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Day Tripper (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/day-tripper-2015-stereo-mix/1440833098?i=1440833893&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/day-tripper-2015-stereo-mix/1440833098?i=1440833893&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/ed/9c/d5/ed9cd587-f7f6-1c6b-8dc3-f2f8d776a966/mzaf_7049642521360281009.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-12-03T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 12,
#    'trackTimeMillis': 169000,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833911,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Penny Lane',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Penny Lane (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/penny-lane-2015-stereo-mix/1440833098?i=1440833911&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/penny-lane-2015-stereo-mix/1440833098?i=1440833911&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/8a/64/99/8a649930-8993-73d2-022c-d167ee2fd4eb/mzaf_7922881405945652433.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1967-02-13T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 17,
#    'trackTimeMillis': 180520,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440834467,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'The Long and Winding Road',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'The Long and Winding Road (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/the-long-and-winding-road-2015-stereo-mix/1440833098?i=1440834467&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/the-long-and-winding-road-2015-stereo-mix/1440833098?i=1440834467&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/c0/94/4e/c0944ed5-3565-3fb0-e2f5-99b3677b14b6/mzaf_2502683357232279658.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1970-05-11T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 27,
#    'trackTimeMillis': 219427,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833334,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Love Me Do',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Love Me Do (Mono)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/love-me-do-mono/1440833098?i=1440833334&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/love-me-do-mono/1440833098?i=1440833334&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/55/55/0a/55550a59-706b-dd46-6a67-65632bd85031/mzaf_5890227976073220653.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1962-10-05T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 1,
#    'trackTimeMillis': 140173,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833539,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'She Loves You',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'She Loves You (Mono)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/she-loves-you-mono/1440833098?i=1440833539&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/she-loves-you-mono/1440833098?i=1440833539&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/70/dc/e4/70dce47e-fd19-01f6-e2bb-e77e21c4646c/mzaf_7313969891523882345.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/db/79/94/db79941b-df8c-0bfb-60a1-df43e7847abb/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1963-08-23T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 27,
#    'trackNumber': 3,
#    'trackTimeMillis': 140920,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164604,
#    'trackId': 1441165168,
#    'artistName': 'The Beatles',
#    'collectionName': "Sgt. Pepper's Lonely Hearts Club Band",
#    'trackName': 'A Day In the Life',
#    'collectionCensoredName': "Sgt. Pepper's Lonely Hearts Club Band",
#    'trackCensoredName': 'A Day In the Life',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/a-day-in-the-life/1441164604?i=1441165168&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/a-day-in-the-life/1441164604?i=1441165168&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/9b/ae/66/9bae6668-be06-396c-e7f6-69c4ee6b108d/mzaf_3640527744551969508.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/7b/0d/cc/7b0dccda-1a4a-e4c5-df7b-adfb86112fe7/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1967-06-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 13,
#    'trackTimeMillis': 335410,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1440833098,
#    'trackId': 1440833549,
#    'artistName': 'The Beatles',
#    'collectionName': '1 (2015 Version)',
#    'trackName': 'Eight Days a Week',
#    'collectionCensoredName': '1 (2015 Version)',
#    'trackCensoredName': 'Eight Days a Week (2015 Stereo Mix)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/eight-days-a-week-2015-stereo-mix/1440833098?i=1440833549&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/eight-days-a-week-2015-stereo-mix/1440833098?i=1440833549&uo=4',
# ...
#    'collectionId': 1441132965,
#    'trackId': 1441133714,
#    'artistName': 'The Beatles',
#    'collectionName': 'The Beatles 1962-1966 (The Red Album)',
#    'trackName': "You've Got to Hide Your Love Away",
#    'collectionCensoredName': 'The Beatles 1962-1966 (The Red Album)',
#    'trackCensoredName': "You've Got to Hide Your Love Away",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/youve-got-to-hide-your-love-away/1441132965?i=1441133714&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/youve-got-to-hide-your-love-away/1441132965?i=1441133714&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/ed/4b/41/ed4b4188-fb65-6dd3-7e09-32b7f93ae826/mzaf_1822263012000018273.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/1e/6a/db/1e6adb66-2feb-87b0-6649-af8c11d2fa29/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/1e/6a/db/1e6adb66-2feb-87b0-6649-af8c11d2fa29/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/1e/6a/db/1e6adb66-2feb-87b0-6649-af8c11d2fa29/source/100x100bb.jpg',
#    'collectionPrice': 19.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-08-06T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 13,
#    'trackNumber': 2,
#    'trackTimeMillis': 131307,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164495,
#    'trackId': 1441164497,
#    'artistName': 'The Beatles',
#    'collectionName': 'Let It Be',
#    'trackName': 'Two of Us',
#    'collectionCensoredName': 'Let It Be',
#    'trackCensoredName': 'Two of Us',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/two-of-us/1441164495?i=1441164497&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/two-of-us/1441164495?i=1441164497&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/29/49/ec/2949ec37-63f7-090d-8ad1-392b4a68e1f2/mzaf_5381130377392111171.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/a7/d6/f0/a7d6f05d-1c71-edd2-a6be-1e7c70ebca40/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1970-05-08T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 1,
#    'trackTimeMillis': 215813,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164524,
#    'trackId': 1441164546,
#    'artistName': 'The Beatles',
#    'collectionName': 'Help!',
#    'trackName': "You've Got to Hide Your Love Away",
#    'collectionCensoredName': 'Help!',
#    'trackCensoredName': "You've Got to Hide Your Love Away",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/youve-got-to-hide-your-love-away/1441164524?i=1441164546&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/youve-got-to-hide-your-love-away/1441164524?i=1441164546&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/ea/fc/13/eafc1360-2bb7-7570-8a9d-cc633e9ce44e/mzaf_1441586686422013840.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-08-06T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 14,
#    'trackNumber': 3,
#    'trackTimeMillis': 129120,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164416,
#    'trackId': 1441164419,
#    'artistName': 'The Beatles',
#    'collectionName': "A Hard Day's Night",
#    'trackName': 'If I Fell',
#    'collectionCensoredName': "A Hard Day's Night",
#    'trackCensoredName': 'If I Fell',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/if-i-fell/1441164416?i=1441164419&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/if-i-fell/1441164416?i=1441164419&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/70/8f/5e/708f5e9a-f8ee-3ffe-73fa-cb1a3bb0b12b/mzaf_2210614811414790081.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1964-07-10T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 3,
#    'trackTimeMillis': 139467,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441163490,
#    'trackId': 1441163498,
#    'artistName': 'The Beatles',
#    'collectionName': 'Magical Mystery Tour',
#    'trackName': 'The Fool On the Hill',
#    'collectionCensoredName': 'Magical Mystery Tour',
#    'trackCensoredName': 'The Fool On the Hill',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/the-fool-on-the-hill/1441163490?i=1441163498&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/the-fool-on-the-hill/1441163490?i=1441163498&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/e6/45/5f/e6455fcb-0a6c-7d5d-a7b3-cc6bfb8cce09/mzaf_968135865324615851.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music124/v4/74/de/04/74de0482-bbdd-d83d-7f92-3f41b0a0758b/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music124/v4/74/de/04/74de0482-bbdd-d83d-7f92-3f41b0a0758b/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music124/v4/74/de/04/74de0482-bbdd-d83d-7f92-3f41b0a0758b/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1967-11-27T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 2,
#    'trackTimeMillis': 179107,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164416,
#    'trackId': 1441164423,
#    'artistName': 'The Beatles',
#    'collectionName': "A Hard Day's Night",
#    'trackName': "Can't Buy Me Love",
#    'collectionCensoredName': "A Hard Day's Night",
#    'trackCensoredName': "Can't Buy Me Love",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cant-buy-me-love/1441164416?i=1441164423&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cant-buy-me-love/1441164416?i=1441164423&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/12/a2/9e/12a29e6d-b02f-bfaa-2766-087fad27a304/mzaf_2400562875018343863.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1964-03-16T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 7,
#    'trackTimeMillis': 131867,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164524,
#    'trackId': 1441164668,
#    'artistName': 'The Beatles',
#    'collectionName': 'Help!',
#    'trackName': "You're Going to Lose That Girl",
#    'collectionCensoredName': 'Help!',
#    'trackCensoredName': "You're Going to Lose That Girl",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/youre-going-to-lose-that-girl/1441164524?i=1441164668&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/youre-going-to-lose-that-girl/1441164524?i=1441164668&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/3f/18/06/3f1806e5-a774-1e7e-6686-72c886962eba/mzaf_1149267746948470183.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-08-06T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 14,
#    'trackNumber': 6,
#    'trackTimeMillis': 138667,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164524,
#    'trackId': 1441164669,
#    'artistName': 'The Beatles',
#    'collectionName': 'Help!',
#    'trackName': 'Ticket to Ride',
#    'collectionCensoredName': 'Help!',
#    'trackCensoredName': 'Ticket to Ride',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/ticket-to-ride/1441164524?i=1441164669&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/ticket-to-ride/1441164524?i=1441164669&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/98/73/fe/9873fe3e-84ab-d5e8-dc58-fe7168bc9a21/mzaf_4052891321119600179.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/e7/ac/a1/e7aca1b3-94d8-3fb9-c2d1-be67ba306dec/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1965-04-09T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 14,
#    'trackNumber': 7,
#    'trackTimeMillis': 189680,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441164416,
#    'trackId': 1441164421,
#    'artistName': 'The Beatles',
#    'collectionName': "A Hard Day's Night",
#    'trackName': 'And I Love Her',
#    'collectionCensoredName': "A Hard Day's Night",
#    'trackCensoredName': 'And I Love Her',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/and-i-love-her/1441164416?i=1441164421&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/and-i-love-her/1441164416?i=1441164421&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/45/32/68/453268f5-a70e-25ac-a2f4-0f3adf2ca15c/mzaf_688035700130791945.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Music114/v4/f6/0c/d8/f60cd816-d431-03de-b714-ce6d726b075c/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1964-07-10T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 5,
#    'trackTimeMillis': 149693,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 136975,
#    'collectionId': 1441133389,
#    'trackId': 1441133861,
#    'artistName': 'The Beatles',
#    'collectionName': 'Love',
#    'trackName': 'Hey Jude',
#    'collectionCensoredName': 'Love',
#    'trackCensoredName': 'Hey Jude',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-beatles/136975?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/hey-jude/1441133389?i=1441133861&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/hey-jude/1441133389?i=1441133861&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/f5/33/9f/f5339fb2-e5de-b907-8b37-9cff3c63cbf0/mzaf_1413505760317985981.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/ed/c1/be/edc1bea7-0178-4abd-0fec-059b48e48505/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/ed/c1/be/edc1bea7-0178-4abd-0fec-059b48e48505/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/ed/c1/be/edc1bea7-0178-4abd-0fec-059b48e48505/source/100x100bb.jpg',
#    'collectionPrice': 12.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2006-11-17T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 28,
#    'trackNumber': 24,
#    'trackTimeMillis': 238854,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Rock',
#    'isStreamable': True}]}

# %%
len(info['results'])
# Out:
# 200

# %%
# Finally, let's check the response to an invalid input
check_resp = requests.get(base_site, params = {"term": "alternative", "country": "us", "media": "hahaha"})
check_resp.ok
# Out:
# False

# %%
# Status code is 400 - meaning 'Bad request'
check_resp.status_code
# Out:
# 400

# %%
# Error message
check_resp.json()
# Out:
# {'errorMessage': 'Invalid value(s) for key(s): [mediaType]',
#  'queryParameters': {'output': 'json',
#   'callback': 'A javascript function to handle your search results',
#   'country': 'ISO-2A country code',
#   'limit': 'The number of search results to return',
#   'term': 'A search string',
#   'lang': 'ISO-2A language code'}}

# %% [markdown]
# ### Structuring and exporting the data

# %%
# It may be useful to store the data in a structured form
# The pandas package is great for that, as we can use its dataframe (basically a table)
# Since the results is a list of 'shallow' dictionaries, it neatly fits into a table
# A more complicated, nested dictionary may not be easily transformable into a table

# %%
import pandas as pd

# %%
# Creating the dataframe and populating it with the results of our search
songs_df = pd.DataFrame(info["results"])
songs_df
# Out:
#      artistId                   artistName  \
# 0      136975                  The Beatles
# 1      136975                  The Beatles
# 2      136975                  The Beatles
# 3      136975                  The Beatles
# 4      136975                  The Beatles
# 5      136975                  The Beatles
# 6      136975                  The Beatles
# 7      136975                  The Beatles
# 8      136975                  The Beatles
# 9      136975                  The Beatles
# 10     136975  The Beatles & Billy Preston
# 11     136975                  The Beatles
# 12     136975                  The Beatles
# 13     136975                  The Beatles
# 14     136975                  The Beatles
# 15     136975                  The Beatles
# 16     136975                  The Beatles
# 17     136975                  The Beatles
# 18     136975                  The Beatles
# 19     136975                  The Beatles
# 20     136975                  The Beatles
# 21     136975                  The Beatles
# 22     136975                  The Beatles
# 23     136975                  The Beatles
# 24     136975                  The Beatles
# 25     136975                  The Beatles
# 26     136975                  The Beatles
# 27     136975                  The Beatles
# 28     136975                  The Beatles
# 29     136975                  The Beatles
# ..        ...                          ...
# 170    136975                  The Beatles
# 171    136975                  The Beatles
# 172    136975                  The Beatles
# 173    136975                  The Beatles
# 174    136975                  The Beatles
# 175    136975                  The Beatles
# 176    136975                  The Beatles
# 177    136975                  The Beatles
# 178    136975                  The Beatles
# 179    136975                  The Beatles
# 180    136975                  The Beatles
# 181    136975                  The Beatles
# 182    136975                  The Beatles
# 183    136975                  The Beatles
# 184    136975                  The Beatles
# 185    136975                  The Beatles
# 186    136975                  The Beatles
# 187    136975                  The Beatles
# 188    136975                  The Beatles
# 189    136975                  The Beatles
# 190    136975                  The Beatles
# 191    136975                  The Beatles
# 192    136975                  The Beatles
# 193    136975                  The Beatles
# 194    136975                  The Beatles
# 195    136975                  The Beatles
# 196    136975                  The Beatles
# 197    136975                  The Beatles
# 198    136975                  The Beatles
# 199    136975                  The Beatles
#
#                                          artistViewUrl  \
# 0    https://music.apple.com/us/artist/the-beatles/...
# 1    https://music.apple.com/us/artist/the-beatles/...
# 2    https://music.apple.com/us/artist/the-beatles/...
# 3    https://music.apple.com/us/artist/the-beatles/...
# 4    https://music.apple.com/us/artist/the-beatles/...
# 5    https://music.apple.com/us/artist/the-beatles/...
# 6    https://music.apple.com/us/artist/the-beatles/...
# 7    https://music.apple.com/us/artist/the-beatles/...
# 8    https://music.apple.com/us/artist/the-beatles/...
# 9    https://music.apple.com/us/artist/the-beatles/...
# 10   https://music.apple.com/us/artist/the-beatles/...
# 11   https://music.apple.com/us/artist/the-beatles/...
# 12   https://music.apple.com/us/artist/the-beatles/...
# 13   https://music.apple.com/us/artist/the-beatles/...
# 14   https://music.apple.com/us/artist/the-beatles/...
# 15   https://music.apple.com/us/artist/the-beatles/...
# 16   https://music.apple.com/us/artist/the-beatles/...
# 17   https://music.apple.com/us/artist/the-beatles/...
# 18   https://music.apple.com/us/artist/the-beatles/...
# 19   https://music.apple.com/us/artist/the-beatles/...
# 20   https://music.apple.com/us/artist/the-beatles/...
# 21   https://music.apple.com/us/artist/the-beatles/...
# 22   https://music.apple.com/us/artist/the-beatles/...
# 23   https://music.apple.com/us/artist/the-beatles/...
# 24   https://music.apple.com/us/artist/the-beatles/...
# 25   https://music.apple.com/us/artist/the-beatles/...
# 26   https://music.apple.com/us/artist/the-beatles/...
# 27   https://music.apple.com/us/artist/the-beatles/...
# 28   https://music.apple.com/us/artist/the-beatles/...
# 29   https://music.apple.com/us/artist/the-beatles/...
# ..                                                 ...
# 170  https://music.apple.com/us/artist/the-beatles/...
# 171  https://music.apple.com/us/artist/the-beatles/...
# 172  https://music.apple.com/us/artist/the-beatles/...
# 173  https://music.apple.com/us/artist/the-beatles/...
# 174  https://music.apple.com/us/artist/the-beatles/...
# 175  https://music.apple.com/us/artist/the-beatles/...
# 176  https://music.apple.com/us/artist/the-beatles/...
# 177  https://music.apple.com/us/artist/the-beatles/...
# 178  https://music.apple.com/us/artist/the-beatles/...
# 179  https://music.apple.com/us/artist/the-beatles/...
# 180  https://music.apple.com/us/artist/the-beatles/...
# 181  https://music.apple.com/us/artist/the-beatles/...
# 182  https://music.apple.com/us/artist/the-beatles/...
# 183  https://music.apple.com/us/artist/the-beatles/...
# 184  https://music.apple.com/us/artist/the-beatles/...
# 185  https://music.apple.com/us/artist/the-beatles/...
# 186  https://music.apple.com/us/artist/the-beatles/...
# 187  https://music.apple.com/us/artist/the-beatles/...
# 188  https://music.apple.com/us/artist/the-beatles/...
# 189  https://music.apple.com/us/artist/the-beatles/...
# 190  https://music.apple.com/us/artist/the-beatles/...
# 191  https://music.apple.com/us/artist/the-beatles/...
# 192  https://music.apple.com/us/artist/the-beatles/...
# 193  https://music.apple.com/us/artist/the-beatles/...
# 194  https://music.apple.com/us/artist/the-beatles/...
# 195  https://music.apple.com/us/artist/the-beatles/...
# 196  https://music.apple.com/us/artist/the-beatles/...
# 197  https://music.apple.com/us/artist/the-beatles/...
# 198  https://music.apple.com/us/artist/the-beatles/...
# 199  https://music.apple.com/us/artist/the-beatles/...
#
#                                          artworkUrl100  \
# 0    https://is1-ssl.mzstatic.com/image/thumb/Video...
# 1    https://is2-ssl.mzstatic.com/image/thumb/Video...
# 2    https://is4-ssl.mzstatic.com/image/thumb/Video...
# 3    https://is2-ssl.mzstatic.com/image/thumb/Video...
# 4    https://is2-ssl.mzstatic.com/image/thumb/Music...
# 5    https://is2-ssl.mzstatic.com/image/thumb/Music...
# 6    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 7    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 8    https://is5-ssl.mzstatic.com/image/thumb/Music...
# 9    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 10   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 11   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 12   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 13   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 14   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 15   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 16   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 17   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 18   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 19   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 20   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 21   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 22   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 23   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 24   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 25   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 26   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 27   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 28   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 29   https://is4-ssl.mzstatic.com/image/thumb/Music...
# ..                                                 ...
# 170  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 171  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 172  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 173  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 174  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 175  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 176  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 177  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 178  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 179  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 180  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 181  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 182  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 183  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 184  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 185  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 186  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 187  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 188  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 189  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 190  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 191  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 192  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 193  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 194  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 195  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 196  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 197  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 198  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 199  https://is1-ssl.mzstatic.com/image/thumb/Music...
#
#                                           artworkUrl30  \
# 0    https://is1-ssl.mzstatic.com/image/thumb/Video...
# 1    https://is2-ssl.mzstatic.com/image/thumb/Video...
# 2    https://is4-ssl.mzstatic.com/image/thumb/Video...
# 3    https://is2-ssl.mzstatic.com/image/thumb/Video...
# 4    https://is2-ssl.mzstatic.com/image/thumb/Music...
# 5    https://is2-ssl.mzstatic.com/image/thumb/Music...
# 6    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 7    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 8    https://is5-ssl.mzstatic.com/image/thumb/Music...
# 9    https://is4-ssl.mzstatic.com/image/thumb/Music...
# 10   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 11   https://is1-ssl.mzstatic.com/image/thumb/Music...
# 12   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 13   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 14   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 15   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 16   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 17   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 18   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 19   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 20   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 21   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 22   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 23   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 24   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 25   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 26   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 27   https://is4-ssl.mzstatic.com/image/thumb/Music...
# 28   https://is3-ssl.mzstatic.com/image/thumb/Music...
# 29   https://is4-ssl.mzstatic.com/image/thumb/Music...
# ..                                                 ...
# 170  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 171  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 172  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 173  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 174  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 175  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 176  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 177  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 178  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 179  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 180  https://is5-ssl.mzstatic.com/image/thumb/Music...
# 181  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 182  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 183  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 184  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 185  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 186  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 187  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 188  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 189  https://is1-ssl.mzstatic.com/image/thumb/Music...
# 190  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 191  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 192  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 193  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 194  https://is2-ssl.mzstatic.com/image/thumb/Music...
# 195  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 196  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 197  https://is3-ssl.mzstatic.com/image/thumb/Music...
# 198  https://is4-ssl.mzstatic.com/image/thumb/Music...
# 199  https://is1-ssl.mzstatic.com/image/thumb/Music...
#
#                                           artworkUrl60 collectionArtistName  \
# 0    https://is1-ssl.mzstatic.com/image/thumb/Video...                  NaN
# 1    https://is2-ssl.mzstatic.com/image/thumb/Video...                  NaN
# 2    https://is4-ssl.mzstatic.com/image/thumb/Video...                  NaN
# 3    https://is2-ssl.mzstatic.com/image/thumb/Video...                  NaN
# 4    https://is2-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 5    https://is2-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 6    https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 7    https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 8    https://is5-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 9    https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 10   https://is4-ssl.mzstatic.com/image/thumb/Music...          The Beatles
# 11   https://is1-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 12   https://is3-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 13   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 14   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 15   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 16   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 17   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 18   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 19   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 20   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 21   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 22   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 23   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 24   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 25   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 26   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 27   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 28   https://is3-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 29   https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# ..                                                 ...                  ...
# 170  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 171  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 172  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 173  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 174  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 175  https://is5-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 176  https://is2-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 177  https://is5-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 178  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 179  https://is2-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 180  https://is5-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 181  https://is3-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 182  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 183  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 184  https://is3-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 185  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 186  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 187  https://is2-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 188  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 189  https://is1-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 190  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 191  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 192  https://is3-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 193  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 194  https://is2-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 195  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 196  https://is3-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 197  https://is3-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 198  https://is4-ssl.mzstatic.com/image/thumb/Music...                  NaN
# 199  https://is1-ssl.mzstatic.com/image/thumb/Music...                  NaN
#
#                      collectionCensoredName collectionExplicitness  \
# 0     Sgt. Pepper's Lonely Hearts Club Band            notExplicit
# 1             The Beatles (The White Album)            notExplicit
# 2                               Rubber Soul            notExplicit
# 3                                  Revolver            notExplicit
# 4                     Abbey Road (2019 Mix)            notExplicit
# 5                     Abbey Road (2019 Mix)            notExplicit
# 6                          1 (2015 Version)            notExplicit
# 7                          1 (2015 Version)            notExplicit
# 8    The Beatles 1967-1970 (The Blue Album)            notExplicit
# 9                                 Let It Be            notExplicit
# 10                         1 (2015 Version)            notExplicit
# 11            The Beatles (The White Album)            notExplicit
# 12                              Rubber Soul            notExplicit
# 13                         1 (2015 Version)            notExplicit
# 14                         1 (2015 Version)            notExplicit
# 15                         1 (2015 Version)            notExplicit
# 16                         1 (2015 Version)            notExplicit
# 17                         1 (2015 Version)            notExplicit
# 18                         1 (2015 Version)            notExplicit
# 19                         1 (2015 Version)            notExplicit
# 20                         1 (2015 Version)            notExplicit
# 21                         1 (2015 Version)            notExplicit
# 22                         1 (2015 Version)            notExplicit
# 23                         1 (2015 Version)            notExplicit
# 24                         1 (2015 Version)            notExplicit
# 25                         1 (2015 Version)            notExplicit
# 26                         1 (2015 Version)            notExplicit
# 27                         1 (2015 Version)            notExplicit
# 28    Sgt. Pepper's Lonely Hearts Club Band            notExplicit
# 29                         1 (2015 Version)            notExplicit
# ..                                      ...                    ...
# 170   The Beatles 1962-1966 (The Red Album)            notExplicit
# 171   The Beatles 1962-1966 (The Red Album)            notExplicit
# 172                      A Hard Day's Night            notExplicit
# 173                        Please Please Me            notExplicit
# 174   The Beatles 1962-1966 (The Red Album)            notExplicit
# 175                                Revolver            notExplicit
# 176                    Magical Mystery Tour            notExplicit
# 177                                Revolver            notExplicit
# 178                               Let It Be            notExplicit
# 179                    Magical Mystery Tour            notExplicit
# 180                                Revolver            notExplicit
# 181                             Rubber Soul            notExplicit
# 182   The Beatles 1962-1966 (The Red Album)            notExplicit
# 183   The Beatles 1962-1966 (The Red Album)            notExplicit
# 184                                   Help!            notExplicit
# 185   The Beatles 1962-1966 (The Red Album)            notExplicit
# 186   The Beatles 1962-1966 (The Red Album)            notExplicit
# 187                    Magical Mystery Tour            notExplicit
# 188   The Beatles 1962-1966 (The Red Album)            notExplicit
# 189                                    Love            notExplicit
# 190   The Beatles 1962-1966 (The Red Album)            notExplicit
# 191                               Let It Be            notExplicit
# 192                                   Help!            notExplicit
# 193                      A Hard Day's Night            notExplicit
# 194                    Magical Mystery Tour            notExplicit
# 195                      A Hard Day's Night            notExplicit
# 196                                   Help!            notExplicit
# 197                                   Help!            notExplicit
# 198                      A Hard Day's Night            notExplicit
# 199                                    Love            notExplicit
#
#      collectionId     ...      \
# 0      1441164604     ...
# 1      1441133180     ...
# 2      1441164359     ...
# 3      1441164670     ...
# 4      1474815798     ...
# 5      1474815798     ...
# 6      1440833098     ...
# 7      1440833098     ...
# 8      1441133100     ...
# 9      1441164495     ...
# 10     1440833098     ...
# 11     1441133180     ...
# 12     1441164359     ...
# 13     1440833098     ...
# 14     1440833098     ...
# 15     1440833098     ...
# 16     1440833098     ...
# 17     1440833098     ...
# 18     1440833098     ...
# 19     1440833098     ...
# 20     1440833098     ...
# 21     1440833098     ...
# 22     1440833098     ...
# 23     1440833098     ...
# 24     1440833098     ...
# 25     1440833098     ...
# 26     1440833098     ...
# 27     1440833098     ...
# 28     1441164604     ...
# 29     1440833098     ...
# ..            ...     ...
# 170    1441132965     ...
# 171    1441132965     ...
# 172    1441164416     ...
# 173    1441164816     ...
# 174    1441132965     ...
# 175    1441164670     ...
# 176    1441163490     ...
# 177    1441164670     ...
# 178    1441164495     ...
# 179    1441163490     ...
# 180    1441164670     ...
# 181    1441164359     ...
# 182    1441132965     ...
# 183    1441132965     ...
# 184    1441164524     ...
# 185    1441132965     ...
# 186    1441132965     ...
# 187    1441163490     ...
# 188    1441132965     ...
# 189    1441133389     ...
# 190    1441132965     ...
# 191    1441164495     ...
# 192    1441164524     ...
# 193    1441164416     ...
# 194    1441163490     ...
# 195    1441164416     ...
# 196    1441164524     ...
# 197    1441164524     ...
# 198    1441164416     ...
# 199    1441133389     ...
#
#                                      trackCensoredName  trackCount  \
# 0    Sgt. Pepper's Lonely Hearts Club Band (Documen...          15
# 1                            The Beatles (Documentary)          32
# 2                            Rubber Soul (Documentary)          16
# 3                               Revolver (Documentary)          16
# 4                        Here Comes the Sun (2019 Mix)          17
# 5                             Come Together (2019 Mix)          17
# 6                           Hey Jude (2015 Stereo Mix)          27
# 7               All You Need Is Love (2015 Stereo Mix)          27
# 8                                             Hey Jude          14
# 9                                            Let It Be          12
# 10                          Get Back (2015 Stereo Mix)          27
# 11                                           Blackbird          17
# 12                                          In My Life          14
# 13                         Yesterday (2015 Stereo Mix)          27
# 14          I Want to Hold Your Hand (2015 Stereo Mix)          27
# 15                     Eleanor Rigby (2015 Stereo Mix)          27
# 16                             Help! (2015 Stereo Mix)          27
# 17                         Let It Be (2015 Stereo Mix)          27
# 18                  Yellow Submarine (2015 Stereo Mix)          27
# 19                 Can't Buy Me Love (2015 Stereo Mix)          27
# 20                    Hello, Goodbye (2015 Stereo Mix)          27
# 21                A Hard Day's Night (2015 Stereo Mix)          27
# 22                         Something (2015 Stereo Mix)          27
# 23                       Day Tripper (2015 Stereo Mix)          27
# 24                        Penny Lane (2015 Stereo Mix)          27
# 25         The Long and Winding Road (2015 Stereo Mix)          27
# 26                                   Love Me Do (Mono)          27
# 27                                She Loves You (Mono)          27
# 28                                   A Day In the Life          13
# 29                 Eight Days a Week (2015 Stereo Mix)          27
# ..                                                 ...         ...
# 170                          Love Me Do (Mono Version)          13
# 171                                       Drive My Car          13
# 172                                 A Hard Day's Night          13
# 173                           I Saw Her Standing There          14
# 174               Norwegian Wood (This Bird Has Flown)          13
# 175                                        Love You To          14
# 176                               Magical Mystery Tour          11
# 177                                 I Want to Tell You          14
# 178                                           Get Back          12
# 179                                     Hello, Goodbye          11
# 180                                      Doctor Robert          14
# 181                                           The Word          14
# 182                      From Me to You (Mono Version)          13
# 183                                        Nowhere Man          13
# 184                              I've Just Seen a Face          14
# 185                    Please Please Me (Mono Version)          13
# 186                                 A Hard Day's Night          13
# 187                               All You Need Is Love          11
# 188                                               Girl          13
# 189  Being For the Benefit of Mr. Kite! / I Want Yo...          28
# 190                  You've Got to Hide Your Love Away          13
# 191                                          Two of Us          12
# 192                  You've Got to Hide Your Love Away          14
# 193                                          If I Fell          13
# 194                               The Fool On the Hill          11
# 195                                  Can't Buy Me Love          13
# 196                     You're Going to Lose That Girl          14
# 197                                     Ticket to Ride          14
# 198                                     And I Love Her          13
# 199                                           Hey Jude          28
#
#     trackExplicitness     trackId  \
# 0         notExplicit  1441165171
# 1         notExplicit  1441134703
# 2         notExplicit  1441164850
# 3         notExplicit  1441165242
# 4         notExplicit  1474815898
# 5         notExplicit  1474815799
# 6         notExplicit  1440834224
# 7         notExplicit  1440833920
# 8         notExplicit  1441133277
# 9         notExplicit  1441164738
# 10        notExplicit  1440834225
# 11        notExplicit  1441133834
# 12        notExplicit  1441164829
# 13        notExplicit  1440833891
# 14        notExplicit  1440833542
# 15        notExplicit  1440833905
# 16        notExplicit  1440833560
# 17        notExplicit  1440834249
# 18        notExplicit  1440833902
# 19        notExplicit  1440833543
# 20        notExplicit  1440834221
# 21        notExplicit  1440833544
# 22        notExplicit  1440834236
# 23        notExplicit  1440833893
# 24        notExplicit  1440833911
# 25        notExplicit  1440834467
# 26        notExplicit  1440833334
# 27        notExplicit  1440833539
# 28        notExplicit  1441165168
# 29        notExplicit  1440833549
# ..                ...         ...
# 170       notExplicit  1441132983
# 171       notExplicit  1441133727
# 172       notExplicit  1441164417
# 173       notExplicit  1441164819
# 174       notExplicit  1441133731
# 175       notExplicit  1441164815
# 176       notExplicit  1441163496
# 177       notExplicit  1441165144
# 178       notExplicit  1441164953
# 179       notExplicit  1441163755
# 180       notExplicit  1441165143
# 181       notExplicit  1441164626
# 182       notExplicit  1441133324
# 183       notExplicit  1441133732
# 184       notExplicit  1441164801
# 185       notExplicit  1441132990
# 186       notExplicit  1441133482
# 187       notExplicit  1441163780
# 188       notExplicit  1441134119
# 189       notExplicit  1441133408
# 190       notExplicit  1441133714
# 191       notExplicit  1441164497
# 192       notExplicit  1441164546
# 193       notExplicit  1441164419
# 194       notExplicit  1441163498
# 195       notExplicit  1441164423
# 196       notExplicit  1441164668
# 197       notExplicit  1441164669
# 198       notExplicit  1441164421
# 199       notExplicit  1441133861
#
#                                              trackName  trackNumber  \
# 0                Sgt. Pepper's Lonely Hearts Club Band           14
# 1                                          The Beatles            1
# 2                                          Rubber Soul           15
# 3                                             Revolver           15
# 4                                   Here Comes the Sun            7
# 5                                        Come Together            1
# 6                                             Hey Jude           21
# 7                                 All You Need Is Love           18
# 8                                             Hey Jude           13
# 9                                            Let It Be            6
# 10                                            Get Back           22
# 11                                           Blackbird           11
# 12                                          In My Life           11
# 13                                           Yesterday           11
# 14                            I Want to Hold Your Hand            4
# 15                                       Eleanor Rigby           16
# 16                                               Help!           10
# 17                                           Let It Be           26
# 18                                    Yellow Submarine           15
# 19                                   Can't Buy Me Love            5
# 20                                      Hello, Goodbye           19
# 21                                  A Hard Day's Night            6
# 22                                           Something           24
# 23                                         Day Tripper           12
# 24                                          Penny Lane           17
# 25                           The Long and Winding Road           27
# 26                                          Love Me Do            1
# 27                                       She Loves You            3
# 28                                   A Day In the Life           13
# 29                                   Eight Days a Week            8
# ..                                                 ...          ...
# 170                                         Love Me Do            1
# 171                                       Drive My Car            5
# 172                                 A Hard Day's Night            1
# 173                           I Saw Her Standing There            1
# 174               Norwegian Wood (This Bird Has Flown)            6
# 175                                        Love You To            4
# 176                               Magical Mystery Tour            1
# 177                                 I Want to Tell You           12
# 178                                           Get Back           12
# 179                                     Hello, Goodbye            7
# 180                                      Doctor Robert           11
# 181                                           The Word            6
# 182                                     From Me to You            3
# 183                                        Nowhere Man            7
# 184                              I've Just Seen a Face           12
# 185                                   Please Please Me            2
# 186                                 A Hard Day's Night            8
# 187                               All You Need Is Love           11
# 188                                               Girl           10
# 189  Being For the Benefit of Mr. Kite! / I Want Yo...           10
# 190                  You've Got to Hide Your Love Away            2
# 191                                          Two of Us            1
# 192                  You've Got to Hide Your Love Away            3
# 193                                          If I Fell            3
# 194                               The Fool On the Hill            2
# 195                                  Can't Buy Me Love            7
# 196                     You're Going to Lose That Girl            6
# 197                                     Ticket to Ride            7
# 198                                     And I Love Her            5
# 199                                           Hey Jude           24
#
#      trackPrice trackTimeMillis  \
# 0          1.99          248480
# 1          1.99          331490
# 2          1.99          198000
# 3          1.99          233000
# 4          1.29          185707
# 5          1.29          260200
# 6          1.29          425653
# 7          1.29          227760
# 8          1.29          431333
# 9          1.29          243027
# 10         1.29          191773
# 11         1.29          138387
# 12         1.29          146333
# 13         1.29          125320
# 14         1.29          145747
# 15         1.29          125867
# 16         1.29          139240
# 17         1.29          230440
# 18         1.29          158800
# 19         1.29          131213
# 20         1.29          207787
# 21         1.29          152920
# 22         1.29          181413
# 23         1.29          169000
# 24         1.29          180520
# 25         1.29          219427
# 26         1.29          140173
# 27         1.29          140920
# 28         1.29          335410
# 29         1.29          163320
# ..          ...             ...
# 170        1.29          141120
# 171        1.29          148453
# 172        1.29          153200
# 173        1.29          172947
# 174        1.29          125187
# 175        1.29          179827
# 176        1.29          169107
# 177        1.29          147973
# 178        1.29          187382
# 179        1.29          208840
# 180        1.29          134267
# 181        1.29          163107
# 182        1.29          117907
# 183        1.29          164187
# 184        1.29          125040
# 185        1.29          121333
# 186        1.29          154627
# 187        1.29          228381
# 188        1.29          151533
# 189        1.29          202209
# 190        1.29          131307
# 191        1.29          215813
# 192        1.29          129120
# 193        1.29          139467
# 194        1.29          179107
# 195        1.29          131867
# 196        1.29          138667
# 197        1.29          189680
# 198        1.29          149693
# 199        1.29          238854
#
#                                           trackViewUrl wrapperType
# 0    https://music.apple.com/us/music-video/sgt-pep...       track
# 1    https://music.apple.com/us/music-video/the-bea...       track
# 2    https://music.apple.com/us/music-video/rubber-...       track
# 3    https://music.apple.com/us/music-video/revolve...       track
# 4    https://music.apple.com/us/album/here-comes-th...       track
# 5    https://music.apple.com/us/album/come-together...       track
# 6    https://music.apple.com/us/album/hey-jude-2015...       track
# 7    https://music.apple.com/us/album/all-you-need-...       track
# 8    https://music.apple.com/us/album/hey-jude/1441...       track
# 9    https://music.apple.com/us/album/let-it-be/144...       track
# 10   https://music.apple.com/us/album/get-back-2015...       track
# 11   https://music.apple.com/us/album/blackbird/144...       track
# 12   https://music.apple.com/us/album/in-my-life/14...       track
# 13   https://music.apple.com/us/album/yesterday-201...       track
# 14   https://music.apple.com/us/album/i-want-to-hol...       track
# 15   https://music.apple.com/us/album/eleanor-rigby...       track
# 16   https://music.apple.com/us/album/help-2015-ste...       track
# 17   https://music.apple.com/us/album/let-it-be-201...       track
# 18   https://music.apple.com/us/album/yellow-submar...       track
# 19   https://music.apple.com/us/album/cant-buy-me-l...       track
# 20   https://music.apple.com/us/album/hello-goodbye...       track
# 21   https://music.apple.com/us/album/a-hard-days-n...       track
# 22   https://music.apple.com/us/album/something-201...       track
# 23   https://music.apple.com/us/album/day-tripper-2...       track
# 24   https://music.apple.com/us/album/penny-lane-20...       track
# 25   https://music.apple.com/us/album/the-long-and-...       track
# 26   https://music.apple.com/us/album/love-me-do-mo...       track
# 27   https://music.apple.com/us/album/she-loves-you...       track
# 28   https://music.apple.com/us/album/a-day-in-the-...       track
# 29   https://music.apple.com/us/album/eight-days-a-...       track
# ..                                                 ...         ...
# 170  https://music.apple.com/us/album/love-me-do-mo...       track
# 171  https://music.apple.com/us/album/drive-my-car/...       track
# 172  https://music.apple.com/us/album/a-hard-days-n...       track
# 173  https://music.apple.com/us/album/i-saw-her-sta...       track
# 174  https://music.apple.com/us/album/norwegian-woo...       track
# 175  https://music.apple.com/us/album/love-you-to/1...       track
# 176  https://music.apple.com/us/album/magical-myste...       track
# 177  https://music.apple.com/us/album/i-want-to-tel...       track
# 178  https://music.apple.com/us/album/get-back/1441...       track
# 179  https://music.apple.com/us/album/hello-goodbye...       track
# 180  https://music.apple.com/us/album/doctor-robert...       track
# 181  https://music.apple.com/us/album/the-word/1441...       track
# 182  https://music.apple.com/us/album/from-me-to-yo...       track
# 183  https://music.apple.com/us/album/nowhere-man/1...       track
# 184  https://music.apple.com/us/album/ive-just-seen...       track
# 185  https://music.apple.com/us/album/please-please...       track
# 186  https://music.apple.com/us/album/a-hard-days-n...       track
# 187  https://music.apple.com/us/album/all-you-need-...       track
# 188  https://music.apple.com/us/album/girl/14411329...       track
# 189  https://music.apple.com/us/album/being-for-ben...       track
# 190  https://music.apple.com/us/album/youve-got-to-...       track
# 191  https://music.apple.com/us/album/two-of-us/144...       track
# 192  https://music.apple.com/us/album/youve-got-to-...       track
# 193  https://music.apple.com/us/album/if-i-fell/144...       track
# 194  https://music.apple.com/us/album/the-fool-on-t...       track
# 195  https://music.apple.com/us/album/cant-buy-me-l...       track
# 196  https://music.apple.com/us/album/youre-going-t...       track
# 197  https://music.apple.com/us/album/ticket-to-rid...       track
# 198  https://music.apple.com/us/album/and-i-love-he...       track
# 199  https://music.apple.com/us/album/hey-jude/1441...       track
#
# [200 rows x 32 columns]

# %%
# Exporting the data to a CSV (Comma Separated Values) file
songs_df.to_csv("songs_info.csv")

# %% [markdown]
# # Pagination

# %%
# Loading the packages
import requests
import json

# %%
# We will use API for job listings on Github
# Documentation can be found on: https://jobs.github.com/api

# %%
# define base URL
base_site = "https://jobs.github.com/positions.json"

# %%
# Submiting a GET request
r = requests.get(base_site, params = {"description": "data science", "location": "los angeles"})
r.status_code
# Out:
# 200

# %%
# Inspect the response
r.json()
# Out:
# [{'id': '6186a24c-7028-4d83-a08f-bd8c45ae1073',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/6186a24c-7028-4d83-a08f-bd8c45ae1073',
#   'created_at': 'Fri Apr 02 17:14:04 UTC 2021',
#   'company': 'Mythical Games',
#   'company_url': 'http://mythical.games',
#   'location': 'Los Angeles, CA',
#   'title': 'Senior Technical Product Manager, Platform & Services',
#   'description': '<p>We are Mythical Games. A venture-backed next-generation game technology company at the intersection of video games and economics led by industry veterans. Our goal is to lead the industry with the launch of exceptional video game experiences that leverage distributed ledger technology, while also providing a platform of robust tools that will allow any other game developers to do the same.</p>\n<p>We are seeking a Senior Technical Product Manager, Platform &amp; Services to join a growing cross-functional team of quants, developers, and product leaders working to build a best-in-class marketplace for video game assets. The Sr. TPM, Platform &amp; Services role at Mythical Games presents an opportunity for a highly technical and detail-oriented Product Manager to take their career to the next level by joining the most exciting company at the intersection of Gaming, E-commerce, and Blockchain. In this role, you will work with cross-functional teams of Engineers, Quant Economists, and Data Scientists, to define, design, and manage the delivery of back-end systems enabling the operation of marketplace services. As a key contributor to Mythical\'s Marketplace team, you will be responsible for all eCommerce backend functionality, including catalog, inventory ingestion, matching engine, distribution, and state reconciliation. You will own the design of data pipelines and data services, metadata handling, and cross-platform integrations.</p>\n<p>You will be expected to contribute to the long-term product vision and roadmap, and to bring rigor and focus to the planning and development effort. Communication and collaboration is a key function: This role will serve as the primary cross-functional liaison between technical developers, designers, and various business stakeholders.</p>\n<p>The ideal candidate will have prior Technical Product Management experience in designing and implementing production services in a marketplace setting, be an expert on the design of engineering architecture, and will be familiar with statistical modeling and machine learning applications. You are a motivated collaborator, experienced in back-end engineering. You can prioritize trade-offs independently and work seamlessly with your counterparts in the team and across the org. You are a strong performer, willing to challenge the status quo and think outside of the box, with a passion for markets and data solutions.</p>\n<p>This role will report to our VP, Marketplace.</p>\n<p>COVID-19 Hiring Update: We’ve transitioned to a work-from-home model and were continuing to interview and hire during this time. This role is expected to begin as a remote position. We understand each person’s circumstances may be unique and will work with you to explore possible interim options.</p>\n<p>Responsibilities:</p>\n<p>You\'ll guide product definition, strategy, and long-term vision for the marketplace platform and internal services in close collaboration with a cross-functional team of engineers, economists, and data scientists\nOwn technical design and implementation of marketplace systems and tools and alignment of modeling, product, and engineering efforts\nConfigure and run data-driven experiments to inform product direction\nCreate flexible systems and data structures to allow for rapid iteration\nContinuously identify issues and opportunities, and optimize internal systems\nEstablish and measure success metrics after launch. Monitor performance data and incorporate customer feedback into essential product decisions\nSteward and document comprehensive system design, including integrations between internal and external services and platforms and tracking sources of truth\nDesign robust, fault-tolerant production systems to support a broad range of mission-critical internal services and coordinate closely with the SRE team to manage and monitor deployments\nCommunicate effectively with senior management as well as with counterparts across the organiz ...
#   'how_to_apply': '<p><a href="https://grnh.se/c83822dd3us">https://grnh.se/c83822dd3us</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcHVmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--e043867d492e7dab5f40b0b0ede0efa5d5c25d40/1591053190007.jpg'}]

# %%
# How many jobs have been found?
len(r.json())
# Out:
# 1

# %% [markdown]
# ### The page parameter

# %%
# Let's search for all jobs (no filter parameters)
r =  requests.get(base_site)
r.ok
# Out:
# True

# %%
r.json()
# Out:
# [{'id': '2e54a26b-cf4b-4225-8148-a36e04ee08ad',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/2e54a26b-cf4b-4225-8148-a36e04ee08ad',
#   'created_at': 'Fri Apr 02 21:17:39 UTC 2021',
#   'company': 'You Need A Budget (YNAB)',
#   'company_url': 'https://www.youneedabudget.com/',
#   'location': 'Remote',
#   'title': 'Humbly Confident Senior Full Stack Developer',
#   'description': '<h2><strong>About Us and Why We’re Hiring</strong></h2>\n<p>We build “You Need a Budget,” the best budgeting software and education resources around. (Those in the know call us YNAB, which is pronounced “why-nab.”) For more than a decade, people have been buying YNAB and then telling their friends what a difference it has made in their lives. <a href="https://www.google.com/search?q=ynab">Google us</a>, or read some of our <a href="https://apps.apple.com/us/app/ynab-you-need-a-budget/id1010865877">reviews on the app store</a>, and you’ll see what we mean. We love building something that has a huge positive impact on people’s lives.</p>\n<p>We have big plans for our entire app ecosystem, including our <a href="https://app.youneedabudget.com">web app</a> and <a href="https://api.youneedabudget.com/">API</a>. All of those plans necessitate changes on our back-end that runs on Rails/Postgres and our front-end Ember app written in TypeScript. That’s where you come in!</p>\n<p>We have one overarching requirement when it comes to joining our team: our <a href="https://docs.google.com/document/d/16hufsixsrv1j2jZkWUgQmeKpNfQRsacnnK2xTVwO0ew/edit">Cultural Manifesto</a> has to really <em>click</em> with you. If you’re nodding emphatically while reading this, you’ll probably fit right in!</p>\n<p>Of course, we have some firm* requirements too, like five years of full-stack professional web application development experience. For us this means you either know the server-side really well and have some client-side experience, or you’re an absolute expert on front-end development and have some server-side know-how.</p>\n<p>*Well, firm-<em>ish</em>. If you know you’re a great fit for this role but fall short of the five-year requirement, include a specific pitch with your application on why we should consider you anyway! How you pitch us is up to you, just make sure it’s short and creative.</p>\n<p>First, let’s talk about life at YNAB, and then we’ll go into detail about what we’re looking for.</p>\n<h2><strong>Who You’d Be Working With</strong></h2>\n<p>Our developer team is about 25 people strong, and we frequently operate in cross-functional teams, so you’ll get to work with awesome people from all different roles in the company.</p>\n<p>Regardless of their varied interests, all of our developers have one thing in common: They are a joy to work with. You won’t find heated arguments and raised voices here. We save our competitive spirit for YNAB’s external competitors (or the occasional lively board game session), but internally we build up our teammates and celebrate their successes. We all love to program and solve problems in creative ways, and we regularly take time to geek out and show each other something cool we built or found to make our lives easier.</p>\n<p>And of course, as a developer, you’ll work closely with our amazing designers. They have the awards (including at least one actual Emmy®) to prove they’re good at designing stuff. More importantly, they welcome feedback and suggestions during the development process and are happy to tweak an interaction if you tell them it will save you significant development effort.</p>\n<h2><strong>How You’ll Work at YNAB</strong></h2>\n<p>We strive hard to make working at YNAB a unique and fantastic experience (we’ve even been named <a href="https://fortune.com/best-small-workplaces/you-need-a-budget/">Fortune’s #1 Best Small Company to Work For</a>). We have a team full of truly exceptional people—the kind you’ll be excited to work with. Here’s how we operate:</p>\n<h3><strong>Responsibility and Empowerment</strong></h3>\n<p>YNAB appreciates, respects, and trusts the expertise and judgment of our developers. We empower them to do what they think is right.</p>\n<p>We also work collaboratively. We continuously seek the right amount of structure and unity necessary to maximize productivity. Where it makes sense, we designate someone to make a call.</p>\n<p>Even though our de ...
#   'how_to_apply': '<p><a href="https://ynab.recruiterbox.com/jobs/fk0ui65?source=Github">https://ynab.recruiterbox.com/jobs/fk0ui65?source=Github</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcDJmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--3a4d18a43d47c4394ad067916d01c7ad14d2946c/YNAB_wordmark_blue-LG.png'},
#  {'id': 'cb6dfb15-6c93-48d0-9edf-572cd234de76',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/cb6dfb15-6c93-48d0-9edf-572cd234de76',
#   'created_at': 'Fri Apr 02 17:48:46 UTC 2021',
#   'company': 'Yubico',
#   'company_url': 'https://www.yubico.com/',
#   'location': 'Palo Alto, CA',
#   'title': 'Software Engineer, Full-stack',
#   'description': '<p>Yubico’s mission is to create a safer internet for everyone. Our core invention, the YubiKey, a hardware-based token, revolutionized secure logins for top Internet brands, including Google and Facebook, and for millions of users in 160 countries. As we expand to more advanced software and services for encryption, collaboration and innovation are at the core of our culture. We are a multinational, fast-growing, and profitable company, offering an opportunity to bring your ideas to life with our global team.</p>\n<p><strong>The Role</strong></p>\n<p>Yubico is looking for a Software Engineer who is innovative and has a passion for building SaaS solutions to enable the integration and lifecycle of YubiKeys into a variety of customer environments. We are introducing multi-factor and passwordless experiences to strengthen defenses against account takeovers while also aiming to raise the usability bar of security.</p>\n<p>In this role you will be able to:</p>\n<ul>\n<li>Hone your skills in designing and developing scalable and globally-distributed services on Amazon Web Services or Google Cloud Platform</li>\n<li>Experiment, create prototypes, and refine your work based on user feedback, industry standards, and business needs</li>\n<li>Work collaboratively across functions - Product Managers, UX designers, and Support Engineers</li>\n<li>Design, propose, and build cloud services to enable desktop, mobile, and server users – standalone or network bound – to take advantage of the numerous hardware-backed key protocols and interfaces provided by our products: OTP, Challenge-Response, PIV SmartCard, FIDO, OpenPGP Card, and HSM functionality</li>\n</ul>\n<p><strong>Basic Qualifications</strong></p>\n<p>A successful candidate should meet the following qualification requirements:</p>\n<ul>\n<li>Bachelor’s Degree in Computer Science, or relevant work experience</li>\n<li>Cumulative 5+ years of demonstrated experience in shipping customer-facing applications</li>\n<li>Experience with building highly-scalable front-end applications (e.g. React/Redux, JavaScript, CSS, HTML, etc.)</li>\n<li>Proficiency in following web standards, applying cross-browser compatibility and accessibility techniques, and in building responsive applications</li>\n<li>Experience with back-end software development: designing, building, and testing APIs (e.g. Java, Go, etc.)</li>\n<li>Experience working with relational databases</li>\n<li>Strong computer science fundamentals in design, data structures, algorithm design, problem-solving, and complexity analysis</li>\n<li>Experience practicing good coding habits, including design documentation, unit testing, peer code reviews, and practicing agile methodology</li>\n</ul>\n<p><strong>Bonus Qualifications</strong></p>\n<p>A successful candidate does not need to possess but has an interest in learning one or more of the following technologies:</p>\n<ul>\n<li>UI/UX design skills</li>\n<li>AWS and GCP cloud platforms and services</li>\n<li>Experience with a NoSQL database, REST APIs</li>\n<li>Design expertise and experience with UI and workflow prototyping tools to support a variety of platforms - from desktop to mobile</li>\n<li>An interest in learning security and identity technologies such as Identity Management, Access Control, SAML, OAuth2, Microsoft Certificate Services, Azure Active Directory Federation, PKI, Open ID, and FIDO standards</li>\n</ul>\n',
#   'how_to_apply': '<p>Go to this link to apply: <a href="https://jobs.lever.co/yubico/d8221edf-5889-43d5-bf9c-ea1d97ff4991">https://jobs.lever.co/yubico/d8221edf-5889-43d5-bf9c-ea1d97ff4991</a></p>\n',
#   'company_logo': None},
#  {'id': '6186a24c-7028-4d83-a08f-bd8c45ae1073',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/6186a24c-7028-4d83-a08f-bd8c45ae1073',
#   'created_at': 'Fri Apr 02 17:14:04 UTC 2021',
#   'company': 'Mythical Games',
#   'company_url': 'http://mythical.games',
#   'location': 'Los Angeles, CA',
#   'title': 'Senior Technical Product Manager, Platform & Services',
#   'description': '<p>We are Mythical Games. A venture-backed next-generation game technology company at the intersection of video games and economics led by industry veterans. Our goal is to lead the industry with the launch of exceptional video game experiences that leverage distributed ledger technology, while also providing a platform of robust tools that will allow any other game developers to do the same.</p>\n<p>We are seeking a Senior Technical Product Manager, Platform &amp; Services to join a growing cross-functional team of quants, developers, and product leaders working to build a best-in-class marketplace for video game assets. The Sr. TPM, Platform &amp; Services role at Mythical Games presents an opportunity for a highly technical and detail-oriented Product Manager to take their career to the next level by joining the most exciting company at the intersection of Gaming, E-commerce, and Blockchain. In this role, you will work with cross-functional teams of Engineers, Quant Economists, and Data Scientists, to define, design, and manage the delivery of back-end systems enabling the operation of marketplace services. As a key contributor to Mythical\'s Marketplace team, you will be responsible for all eCommerce backend functionality, including catalog, inventory ingestion, matching engine, distribution, and state reconciliation. You will own the design of data pipelines and data services, metadata handling, and cross-platform integrations.</p>\n<p>You will be expected to contribute to the long-term product vision and roadmap, and to bring rigor and focus to the planning and development effort. Communication and collaboration is a key function: This role will serve as the primary cross-functional liaison between technical developers, designers, and various business stakeholders.</p>\n<p>The ideal candidate will have prior Technical Product Management experience in designing and implementing production services in a marketplace setting, be an expert on the design of engineering architecture, and will be familiar with statistical modeling and machine learning applications. You are a motivated collaborator, experienced in back-end engineering. You can prioritize trade-offs independently and work seamlessly with your counterparts in the team and across the org. You are a strong performer, willing to challenge the status quo and think outside of the box, with a passion for markets and data solutions.</p>\n<p>This role will report to our VP, Marketplace.</p>\n<p>COVID-19 Hiring Update: We’ve transitioned to a work-from-home model and were continuing to interview and hire during this time. This role is expected to begin as a remote position. We understand each person’s circumstances may be unique and will work with you to explore possible interim options.</p>\n<p>Responsibilities:</p>\n<p>You\'ll guide product definition, strategy, and long-term vision for the marketplace platform and internal services in close collaboration with a cross-functional team of engineers, economists, and data scientists\nOwn technical design and implementation of marketplace systems and tools and alignment of modeling, product, and engineering efforts\nConfigure and run data-driven experiments to inform product direction\nCreate flexible systems and data structures to allow for rapid iteration\nContinuously identify issues and opportunities, and optimize internal systems\nEstablish and measure success metrics after launch. Monitor performance data and incorporate customer feedback into essential product decisions\nSteward and document comprehensive system design, including integrations between internal and external services and platforms and tracking sources of truth\nDesign robust, fault-tolerant production systems to support a broad range of mission-critical internal services and coordinate closely with the SRE team to manage and monitor deployments\nCommunicate effectively with senior management as well as with counterparts across the organiz ...
#   'how_to_apply': '<p><a href="https://grnh.se/c83822dd3us">https://grnh.se/c83822dd3us</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcHVmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--e043867d492e7dab5f40b0b0ede0efa5d5c25d40/1591053190007.jpg'},
#  {'id': '139d649e-8a16-4f7c-87f6-aeadbff8ef21',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/139d649e-8a16-4f7c-87f6-aeadbff8ef21',
#   'created_at': 'Fri Apr 02 14:45:56 UTC 2021',
#   'company': 'WaveSense',
#   'company_url': 'https://wavesense.recruitee.com',
#   'location': 'Sommervile',
#   'title': 'DevOps Engineer',
#   'description': '<p><strong>DevOps Engineer</strong></p>\n<p><strong>COMPANY</strong>\nWaveSense is radically accelerating the arrival of self-driving vehicles by tackling some of the most challenging problems that stand in the way of safe and reliable navigation.\nEvery road in the world has a unique subsurface signature. WaveSense uses radar to create a map of those subsurface signatures from which self-driving cars can navigate. Vehicles using WaveSense are unaffected by common but challenging road conditions like snow, heavy rain, fog, or poor lane markings.\nWaveSense is working with leading autonomous vehicle and traditional automotive companies, is backed by leading investors, is growing quickly, and is building a talented team that wants to transform the future of mobility and work on some of the hardest and most important engineering problems around. If that sounds like you, please drop us a line.</p>\n<p><strong>ROLE</strong>\nAs a DevOps Engineer, you will work with the team to design and implement\xa0WaveSense\'s efforts around key local, vehicular, and\xa0cloud based infrastructure.\xa0\xa0</p>\n<p><strong>WHO YOU ARE + WHAT YOU\'LL DO</strong></p>\n<ul>\n<li>Design, test and implement cloud based continuous integration and deployment pipelines using Bitbucket and Jenkins.</li>\n<li>Design and develop deployment automation and validation tools across the entire software stack.</li>\n<li>Design and develop a software release, test, and deployment strategy.</li>\n<li>Manage the build system.</li>\n<li>Perform security, performance and availability assessments</li>\n<li>Optimize system performance, availability and scalability</li>\n<li>Troubleshoot source code management and deployment issues</li>\n<li>Create and maintain documentation on configuration, troubleshooting, design etc.</li>\n<li>Perform security audits and assist with hardening servers and systems against attacks</li>\n<li>Support internal trouble tickets</li>\n<li>Formulate daily procedures to ensure data and systems backup</li>\n<li>Maintain accounts for AWS, Google Workspaces.</li>\n<li>Maintain license server.</li>\n<li>Provide basic IT support for onboarding new employees including provisioning PC’s.</li>\n</ul>\n<p><strong>REQUIREMENTS</strong></p>\n<ul>\n<li>5 plus years working in DevOps (plus experience in software development and network management).</li>\n<li>Strong system administration (Unix/Linux/Windows).</li>\n<li>Strong working knowledge and experience with Git and Jenkins.</li>\n<li>Experience with build systems (cmake, make).</li>\n<li>Familiarity with agile development process and best practices.</li>\n<li>Programming and scripting experience in Python, C++#, PowerShell, Bash.</li>\n<li>Experience with containers (Docker).</li>\n<li>Knowledge of database, operating system and network security.</li>\n<li>Extensive knowledge and experience with CI/CD technologies and tools (Jenkins).</li>\n<li>Experience provisioning and managing AWS cloud resources (Terraform or similar).</li>\n<li>Previous experience with server configuration and maintenance.</li>\n<li>Bachelor\'s or Master’s degree or higher in Information Systems, Computer Science, Engineering, or equivalent job-related experience.</li>\n<li>Talented, passionate, and able to effectively work with the team to design, build, and execute core capabilities.</li>\n</ul>\n<p><strong>NICE TO HAVE</strong></p>\n<ul>\n<li>Experience with integrating embedded systems / IoT type environments into CI/CD models.</li>\n<li>Cloud engineering and architecture experience.</li>\n</ul>\n<p><strong>WORK</strong>\nMust be currently eligible to work in the US.\xa0 Please indicate if you need or will eventually need sponsorship on your application.\xa0\nApply for this job via\xa0<a href="https://ltpx.nl/ESYBjWo"><strong>the application form</strong></a>.</p>\n<p><em>Agency calls are not appreciated.</em><img src="https://camo.githubusercontent.com/2da2e352d0288668476d85e61afe48b4332e9b1c/68747470733a2f2 ...
#   'how_to_apply': '<p><a href="https://ltpx.nl/qx7mxOO">Click to apply</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcG1mIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--55d26c616819ae7dbe68538f2763cea61f6f4e2d/WaveSense.jpg%20.jpg'},
#  {'id': '709412f8-f28c-46a1-9c8a-c0b5a067f1c5',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/709412f8-f28c-46a1-9c8a-c0b5a067f1c5',
#   'created_at': 'Fri Apr 02 09:19:18 UTC 2021',
#   'company': 'Apex Clean Energy',
#   'company_url': 'https://vonq.io/3cKUpKo',
#   'location': 'Charlottesville, USA',
#   'title': 'Application Engineer',
#   'description': '<h2>Company Description</h2>\n<p>Apex Clean Energy develops, constructs, and operates utility-scale wind and solar power facilities across North America. Our mission-driven team of more than 250 renewable energy experts uses a data-focused approach and an unrivaled portfolio of projects to create solutions for the world’s most innovative and forward-thinking customers. For more information on how Apex is leading the transition to a clean energy future, visit apexcleanenergy.com.</p>\n<p>Apex strives to excel in every phase of project realization, from origination and financing to construction and asset management. Our mission-driven team seeks determined, resolute individuals who strive to innovate and go above the call of duty, and who will relentlessly do their part to help accelerate the shift to America’s clean energy future.</p>\n<h2>Job Description</h2>\n<p>Apex Clean Energy seeks an Application Engineer to join a technologically advanced team, focusing on innovation and delivery of critical applications and dashboards to foster business solutions and solve specific business challenges.</p>\n<p>Reporting to the Manager of Analytics and Systems Engineering within our Technology and Energy Team, you will be the main developer responsible for designing, developing, and implementing applications and programs that interface with the data warehouse. You will work closely with project teams and stakeholders across Apex in support of development and implementations activities including requirements gathering, system design and architecture, and deployment of applications. You will be responsible for then providing applications and dashboards using a combination of tools and programming languages that perform data extraction and data modeling. Ongoing operational support of ETL and data integration jobs are also an important task of this position comprised of scheduling, monitoring and troubleshooting to maintain optimal health of the environments.</p>\n<p>The Application Engineer serves as diagnostician and solution provider for data, information and business process-related analysis. We look to this role for technical expertise in specific data domains and incorporating data governance into daily activities. This role is responsible for providing expertise in the integration of data, insights, trends and solution recommendations. You will enable data driven decisions for your respective domain and partner with other analysts to extract, interpret, and perform advanced analytics.</p>\n<p><em>We are interested in every qualified candidate who is eligible to work in the United States. However, we are not able to sponsor visas at this time.</em></p>\n<h2>Responsibilities:</h2>\n<ul>\n<li>Design and develop applications interfacing with the data warehouse (e.g., Power Apps and Power BI dashboards) that effectively accomplish objectives and needs</li>\n<li>Collaborate with stakeholders to define business logic for source-to-target mappings and integration workflows.</li>\n<li>Design and develop data extraction SQL queries that are highly optimized for very large data sets</li>\n<li>Analyze and edit existing applications to improve functionality</li>\n<li>Remodel and adapt applications as needed to optimize performance</li>\n<li>Assisting in production support by resolving source data issues and refining transformation rules when needed</li>\n<li>Test applications extensively to ensure they are error and bug free</li>\n<li>Maintain application database</li>\n<li>Support the maintenance of the existing data warehouses and facilitate aggregation, slicing and dicing of data using dbt</li>\n<li>Creating and maintaining the company data dictionary as well as technical documentation for source-to-target mapping</li>\n<li>Support the management and maintenance of ETL processes</li>\n<li>Follow current trends, their impact on business strategies, and their implications for creating sustainable data warehouse architecture</li ...
#   'how_to_apply': '<p><a href="https://vonq.io/3cKUpKo">Click here for the application form!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcE9mIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--a8da06ef9630b3158f47bc2aaa325c5a2ca4b0ae/Apex%20Clean%20Energy.jpeg'},
#  {'id': 'a5900ace-8011-4dc8-a951-0e13256c5eb2',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/a5900ace-8011-4dc8-a951-0e13256c5eb2',
#   'created_at': 'Fri Apr 02 09:15:40 UTC 2021',
#   'company': 'Consorsbank',
#   'company_url': 'http://www.consorbank.de',
#   'location': 'Nürnberg',
#   'title': 'IT Application Manager – Backoffice-Anwendungen (w/m/d)',
#   'description': '<p>Für unseren Standort Nürnberg oder München in Voll- oder Teilzeit</p>\n<p>Gestalten Sie mit uns das Banking von Morgen! Denn wir bieten nicht nur modernes Online-Banking, sondern erleichtern mit selbst entwickelten Innovationen den Alltag unserer Kunden. Dabei hören wir zu und lassen die Kunden aktiv ihre Meinungen und Ideen beisteuern. Gestalten auch Sie mit – werden Sie Teil der Consorsbank und des starken Netzwerks von BNP Paribas.</p>\n<h2>Sie übernehmen Verantwortung:</h2>\n<p>Sie arbeiten in einem Team engagierter und freundlicher Kollegen und tragen Verantwortung für ein\nanspruchsvolles und komplexes Aufgabengebiet mit zentraler Bedeutung für das Unternehmen – die ITBetreuung unserer Backoffice-Systeme:</p>\n<ul>\n<li>Dabei sind Sie zentraler Ansprechpartner bei technischen und fachlichen Fragen und agieren als Schnittstelle zwischen Business, IT-Einheiten\nund externen Dienstleistern</li>\n<li>Als technischer Servicepartner für die betriebswirtschaftlichen Backoffice-Bereiche der\nBank sind Sie für den dauerhaften und fehlerfreien Betrieb der Kernbankensysteme verantwortlich</li>\n<li>Sie übernehmen Aufgaben bei der Behandlung von akuten Problemen, die neben technischem und fachlichem Wissen auch koordinative und kommunikative Fähigkeiten verlangen</li>\n<li>Im Rahmen der kontinuierlichen Verbesserung der Systeme prüfen Sie gemeldete Fehler und erarbeiten eine Lösung</li>\n<li>Für die mittel- bis längerfristige Weiterentwicklung der Systeme stimmen Sie Vorgaben mit allen Beteiligten ab, initiieren und begleiten die Umsetzung</li>\n</ul>\n<h2>Ihre Erfahrung sichert Qualität:</h2>\n<ul>\n<li>Sie bringen ein abgeschlossenes Hochschul- oder Fachhochschulstudium oder eine vergleichbare\nAusbildung mit IT-Anteil mit</li>\n<li>Idealerweise bringen Sie Erfahrung in der Betreuung komplexer IT Anwendungen mit und hatten bereits Berührungspunkte mit dem Aufbau Modularer Systemarchitekturen und der Kommunikation verteilter Anwendungen</li>\n<li>Sie verfügen über Grundkenntnisse in Unix/Linux, (PL/)SQL (Oracle), Job/BatchAutomatisierungssysteme (z.B. UC4), Serveranwendungen im Java-Umfeld</li>\n<li>Kenntnisse und Erfahrungen in der Finanzwirtschaft, insbesondere in Bezug auf Prozesse und Methoden in der Zahlungsverkehrsoder Wertpapierabwicklung, erleichtern Ihnen ihre tägliche Arbeit</li>\n<li>Sie sind Team-und Kommunikationsfähig, arbeiten gleichzeitig gerne selbstständig und das mit einem hohes Qualitätsbewusstsein</li>\n<li>Gute Deutsch- und Englischkenntnisse in Wort und Schrift runden ihr Profil ab</li>\n</ul>\n<h2>Was wir Ihnen bieten:</h2>\n<ul>\n<li>Ein hervorragendes Betriebsklima, kompetente Kollegen und Veranstaltungen, welche Zusammenarbeit und Kommunikation fördern</li>\n<li>Begegnung auf Augenhöhe in einer Du-Kultur</li>\n<li>Moderne Arbeitswelten an zentralen Standorten</li>\n<li>Betriebliches Gesundheitsmanagement mit vielfältigen Mitarbeiterangeboten rund um das Thema\n„Gesundheit“</li>\n<li>Gewinnbeteiligung: Sie profitieren direkt von unserem gemeinsamen Erfolg</li>\n<li>Betriebliche Altersvorsorge: Mit dem Testsieger BVV können Sie das Alter entspannt auf sich zukommen lassen</li>\n</ul>\n<h2>Dynamische Perspektiven in stabilem Umfeld</h2>\n<p>Die BNP Paribas Gruppe bietet in Deutschland ein einzigartiges Arbeitsumfeld: Unsere 12 Gesellschaften bilden gemeinsam eine lernende Organisation, in der unsere Mitarbeitenden ihr Wissen miteinander teilen und sich dafür einsetzen, dass unsere Kunden von diesem großen Erfahrungsschatz profitieren. Werden Sie Teil unseres Teams, und treiben Sie eine Welt im Wandel mit Ihren eigenen Ideen voran.</p>\n<p>Für Ihre Fragen ist Verena Blum unter 0911 3690 sowie per Mail: <a href="mailto:recruiting@consorsbank.de">recruiting@consorsbank.de</a> für Sie da. Wir freuen uns auf Ihre Bewerbung als IT Application Manager – Backoffice-Anwendungen (w/m/d) mit Nennung Ihrer Gehaltsvorstellung, dem frühestmöglichen Eintrittstermin und relevanten Zeugnissen über das <s ...
#   'how_to_apply': '<p><a href="https://vonq.io/3whsAkP">Klicken Sie hier um zum Bewerbungsformular zu gelangen!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcENmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--8b5e266d32b6f1c47d8a19626067e7d188491b31/cc.jpeg'},
#  {'id': '21d9e0e2-9b9a-4c7d-8c0c-26871b0bb7a6',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/21d9e0e2-9b9a-4c7d-8c0c-26871b0bb7a6',
#   'created_at': 'Thu Apr 01 19:07:46 UTC 2021',
#   'company': 'Thorlabs',
#   'company_url': 'https://www.thorlabs.com/',
#   'location': '07860',
#   'title': 'Mid-Level SQL Server Data Engineer',
#   'description': '<p>Looking for an experienced dynamic SQL Server Database Administrator/Engineer, with deep knowledge and broad experience of MS SQL and Azure Cloud skills to join our Database Engineering team at Thorlabs. We are a fast-paced and growing group that manages the complete data needs of the firm. Primary role of this position will be to cover all aspects of data needs in the organization, production system support and troubleshooting, implementing database systems, setup database monitoring, implement Disaster recovery Strategies, project planning, developing documentation and runbooks. This person will be part of a group rotation providing weekend on-call support.</p>\n<p>Essential Job Functions include the following, but are not limited to:</p>\n<ul>\n<li>Conduct monitoring, maintenance and development of our database solutions on-prem and Azure; including business critical reporting and BI systems.</li>\n<li>Troubleshoot technical issues and identify modifications needed in existing applications to meet changing user requirements. Research and troubleshoot data pipeline questions.</li>\n<li>Manage and maintain optimal performance of business critical applications, including Dynamics AX.</li>\n<li>Manage security role, Role base access, authentication and authorization of users accessing various database systems.</li>\n<li>Would require understanding manufacturing and lean processes to execute some functional specifications</li>\n<li>Develop and implement Disaster Recovery (DR) strategies, high availability and backup restore schedules.</li>\n<li>Develop and optimize queries to increase efficiency in our systems</li>\n<li>Collaborate on problem resolution, team decisions and project planning.</li>\n<li>Build fail-proof data pipelines (ETL) to move data between different systems while maintaining integrity using Azure tools and cloud-based ETL development processes.</li>\n<li>Experience connecting to varied data sources, on-prem and cloud.</li>\n<li>Excellent SQL coding experience with performance optimization for data queries.</li>\n<li>Understands different data models like normalized, de-normalized, stars, and snowflake models. Working experience with transactional, temporal, time series, and structured and unstructured data, AzureDataLake is a plus.</li>\n<li>Working experience with MPP DWH system like Azure synapse is highly desirable.</li>\n<li>Experience in deployment and maintenance of ETL Jobs.</li>\n<li>Is familiar with the reporting tools like Power Bi and SSRS or any other.</li>\n</ul>\n<p>Qualifications</p>\n<p>Experience:</p>\n<ul>\n<li>5+ years’ experience</li>\n</ul>\n<p>Education:</p>\n<ul>\n<li>Bachelor’s degree in Engineering/Science, or equivalent work experience</li>\n</ul>\n<p>Specialized Knowledge and Skills:</p>\n<ul>\n<li>SQL: clustering, mirroring, replication, scripting, stored procedures, functions, performance tuning and trouble shooting.</li>\n<li>Azure: Azure Data Factory, Azure SQL database, Azure Synapse, Databricks, Azure Analysis Services, Azure DataLake storage</li>\n<li>Reporting Tools: Power Bi, SSRS</li>\n<li>Languages: TSQL, Python, PowerShell, JSON, Pyspark</li>\n<li>Data modelling: Tabular model, Star Schema, Columnar modelling</li>\n</ul>\n<p>Thorlabs values its diverse environment and is proud to be an Equal Employment Opportunity/Affirmative Action Employer. All qualified individuals will receive consideration for employment without regard to race, color, religion, gender, gender identity or expression, sexual orientation, national origin, genetics, disability, age or veteran status. Job descriptions are not intended as and do not create employment contracts. The organization maintains its status as an at-will employer. Employees can be terminated for any reason not prohibited by law.</p>\n',
#   'how_to_apply': '<p>Please  be sure to complete an application on the Company\'s career site for consideration. Direct link below:</p>\n<p><a href="https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3392010">https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3392010</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBb1NmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--3c8771d67e8b937cccead21303ae98dfa0f14420/Company%20Logo.jpg'},
#  {'id': '353b2b8f-55c6-44b2-976e-2089c9503e22',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/353b2b8f-55c6-44b2-976e-2089c9503e22',
#   'created_at': 'Thu Apr 01 18:54:05 UTC 2021',
#   'company': 'Thorlabs',
#   'company_url': 'https://www.thorlabs.com/',
#   'location': '07860',
#   'title': 'Enterprise Data Architect',
#   'description': '<p>The Enterprise Data Architect (EDA) primary goal is to keep data easily accessible and accurate. To meet that goal, the EDA reviews, refines and implements data standards. Examples of data standards include those that define how data is categorized or how codes are assigned to represent specific products, customers and other data types. Gathering information about data use in the workplace, the architect creates a blueprint or road map, showing processes and services that affect data use and data standards. The architect works with project managers and business stakeholders to implement that design.</p>\n<p>The EDA is further expected to act as the team leader for the global DBA resources and provide them daily technical guidance and management. The role as EDA is hands on, relishing learning, provide guidance and create value added services for a data hungry organization\nAlthough the location of the position is in Newton, NJ, from time to time it may be required to undertake duties at other ThorLabs locations.</p>\n<p>Essential Job Functions include the following, but are not limited to:</p>\n<ul>\n<li>The EDA works with teams to solve business data problems.</li>\n<li>The EDA develops data modeling methods, databases, data warehouses, data lakes, master data and metadata.</li>\n<li>The EDA acts as a data evangelist to address business process improvement with users in finance, purchasing, quality, human resources and other departments.\nIn addition to the essential functions and duties listed above, all positions are also responsible for:</li>\n<li>Meeting company standards pertaining to quantity and quality of work performed on an ongoing basis, performing all work related tasks in a manner that is in compliance with all Company policies and procedures.</li>\n<li>Adhering to Company policies, procedures, and directives regarding standards of workplace behavior in completing job duties and assignments.</li>\n</ul>\n<p>The Company retains the right to change or assign other duties to this position.</p>\n<p>Physical Activities:</p>\n<ul>\n<li>This is largely a sedentary role; however, some filing is required. This would require the ability to lift files, open filing cabinets and bend or stand as necessary.</li>\n</ul>\n<p>Experience:</p>\n<ul>\n<li>10+ years of experience in database design, data warehousing and data modeling</li>\n</ul>\n<p>Education:</p>\n<ul>\n<li>Bachelor’s degree in Engineering/Science, or equivalent work experience.</li>\n</ul>\n<p>Specialized Knowledge and Skills:</p>\n<ul>\n<li>Prior experience as DBA architect</li>\n<li>Experience with the MS SQL stack - SSIS, SSAS, SSRS, Azure Synapse, Azure Analysis Services etc.</li>\n<li>Knowledge of ERP system databases, preferable MS Dynamics/Axapta.</li>\n<li>Comes from a mixed heterogeneous SQL environment</li>\n<li>Knowledge of project management</li>\n<li>Experience with data modeling software</li>\n<li>Experience with migrating to cloud, preferably Azure</li>\n<li>Communicate directly with users, speaking in terms they understand</li>\n<li>Should have good business knowledge and be able to explain technical concepts without using complex, technical terms.</li>\n</ul>\n<p>Thorlabs values its diverse environment and is proud to be an Equal Employment Opportunity/Affirmative Action employer. All qualified individuals will receive consideration for employment without regard to race, color, religion, gender, gender identify or expression, sexual orientation, national origin, genetics, disability, age or veteran status. Job descriptions are not intended as and do not create employment contracts. The organization maintains its status as an at-will employer. Employees can be terminated for any reason not prohibited by law.</p>\n',
#   'how_to_apply': '<p>Please be sure to complete an application on the Company\'s career site for consideration. Direct link below:</p>\n<p><a href="https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3429023">https://recruiting.myapps.paychex.com/appone/MainInfoReq.asp?R_ID=3429023</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBb0dmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--28374c4e5671b119cc2a94db42e38ceca515a16b/Company%20Logo.jpg'},
#  {'id': '81253ec3-d190-4cb9-9cf8-04a0798ec32b',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/81253ec3-d190-4cb9-9cf8-04a0798ec32b',
#   'created_at': 'Thu Apr 01 16:36:13 UTC 2021',
#   'company': 'Community Data Platforms',
#   'company_url': 'https://communitydataplatforms.com',
#   'location': 'remote',
#   'title': 'Product Support Analyst',
#   'description': '<p>About Community Data Platforms</p>\n<p>Community Data Platforms believes communities get smarter and stronger by using evidence-based decision-making.  CDP supports this mission by building data platforms in communities across the country to help leaders and decision-makers answer their Pressing Questions.</p>\n<p>With a five-year goal of serving 100 communities, CDP believes it can support data-driven decision-making among governments, business, and nonprofits, leading to better outcomes among a range of critical community organizations.  Communities have pressing questions and CDP’s team and approach develops actionable insights and communicates them clearly by using advanced visualizations.  We believe a community data platform is an essential community service.</p>\n<p>Working with Community Data Platforms</p>\n<p>We’re looking for ambitious and resourceful people to join a rapidly growing start-up serving communities across the country. Benefits include:</p>\n<p>A culture of intellectual humility and a passion for understanding the world around us (we don’t care who’s right – we care what’s right!)\nWorking with driven and intellectually curious people who are experts in their fields\nA close-knit team that is devoted to a common mission\nThe opportunity to be involved at the early stages of a start-up with enormous potential\nBeing at the forefront of the big data wave and its application to community-based decision-making\nRemote work – you set your own hours and complete your work on your own time – no micromanaging!</p>\n<p>Duties and Responsibilities\nOur ideal Product Support Analyst has experience coordinating customers’ technical issues and bug fixes with technical teams, especially in relation to data analytics development and implementation. This person is highly strategic and focused on improving CDP’s customer service through building trust in our products.</p>\n<p>Working across teams, he or she will look at customer responses and relationships and help make outcomes better. The right candidate has a teamwork attitude and is willing to roll up their sleeves and take on shared tasks to ensure completion.</p>\n<p>As a member of the customer success team, a successful candidate will develop a deep understanding of the customer experience, create and own multiple key performance metrics, and advance CDP’s ability to expand the reach of its data platforms.</p>\n<p>He or she will be responsible for:</p>\n<p>Serving as the go-to person for bugs and other technical issues</p>\n<p>Meeting with customer success specialists around technical issues and needs</p>\n<p>Providing technology support to community communications’ specialists surrounding CDP’s survey program</p>\n<p>Testing products to ensure bug fixes and technical issues are thoroughly resolved</p>\n<p>Communication with multiple teams and documentation</p>\n<p>The Product Support Analyst will support CDP’s survey team specifically with:</p>\n<p>Survey testing, review and quality analysis</p>\n<p>Monitoring surveys</p>\n<p>Working with customer success specialists to gain intimate knowledge of customer experience, then coordinating with managers on a queue of improvements based on this knowledge</p>\n<p>Internal delegation to the appropriate team member for bugs and technical issues</p>\n<p>Explaining and resolving external technical issues with customers</p>\n<p>This is a remote, part time or full time position. There is huge growth potential for the right candidate. CDP’s products have many moving parts. Therefore a successful candidate will be able to keep track of several small tasks, completing each on time and to high standards. Attention to detail is critical, while maintaining the larger picture of the company’s objectives.</p>\n<p>The proven ability to work collaboratively on diverse teams needs to be demonstrated in the application package.</p>\n<p>Requirements include:</p>\n<p>Previous experience and/or training related to custo ...
#   'how_to_apply': '<p>Please send a resume and cover letter to: <a href="mailto:jobs@communitydataplatforms.com">jobs@communitydataplatforms.com</a> and include the job title in the SUBJECT line of the email. Resumes without cover letters will be discarded.</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBbjJmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--cf4de63e0edc1d7a0d892a9e68f941b7a59606ab/CDP%20logo.png'},
#  {'id': '7069cbcb-102d-4be6-bb72-4e0ba079e726',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/7069cbcb-102d-4be6-bb72-4e0ba079e726',
#   'created_at': 'Thu Apr 01 15:57:57 UTC 2021',
#   'company': 'Carl Finance GmbH',
#   'company_url': 'https://www.carlfinance.de',
#   'location': 'Berlin',
#   'title': 'Senior Frontend Developer (m/w/d)',
#   'description': '<p>At Carl we support owners of small and medium-sized companies on their way to a successful company sale. Platform-based technology solutions provide our customers with uncomplicated access to a unique buyer network. Carl offers customized options to medium-sized businesses that for a long time were only available to large corporations. We promise our customers a company transfer with a high probability of success, in which the wishes of the entrepreneur are always at the forefront.</p>\n<p>Carl is currently actively involved in over 30 transactions with a combined volume of more than EUR 240 million. The team has gathered meaningful experience in leading companies (J.P. Morgan, McKinsey, Rocket Internet, Google etc.) and is supported by prominent advisory boards and investors. We address a fundamental problem of the European economy and pursue the goal of digitizing and professionalizing business succession in medium-sized companies. Initiative and commitment are rewarded with extensive responsibility in this phase of company development. If you are enthusiastic about this vision and would like to actively support the digitization of medium-sized businesses, we look forward to hearing from you!</p>\n<p><strong>Responsibilities</strong></p>\n<ul>\n<li>Primarily focus on building up the new Carl platform</li>\n<li>Be part of our multicultural team and strive to build products that delight users</li>\n<li>Provide guidance and mentorship to more junior developers</li>\n<li>Work with the product team to define and realise the product roadmap</li>\n</ul>\n<p><em>Work with a modern technology stack. Some examples of tools that we use are:</em></p>\n<ul>\n<li>React, NextJS</li>\n<li>Chakra UI, TailwindCSS</li>\n<li>Formik, react-intl</li>\n<li>Zustand for state management</li>\n<li>Webpack, Lerna</li>\n<li>Maintain our existing applications</li>\n</ul>\n<p><em>Work on the Carl shared libraries. We have libraries for:</em></p>\n<ul>\n<li>UI elements</li>\n<li>Data fetching + storage</li>\n<li>Analytics</li>\n<li>and more...</li>\n</ul>\n<p><strong>Requirements</strong></p>\n<ul>\n<li>More than 5-7 years of professional experience as a frontend developer</li>\n<li>Very good experience in working with the React ecosystem in larger projects</li>\n<li>You have experience in the complete feature lifecycle - from conception to final launch</li>\n<li>Are proactive in coming up with solutions to challenges</li>\n<li>Happy to take ownership of the technical side of the product</li>\n<li>You have experience mentoring other developers</li>\n<li>You can speak English fluently (German is a plus)</li>\n</ul>\n<p><strong>Benefits</strong></p>\n<ul>\n<li>Possibility to shape an entire industry with the help of software</li>\n<li>Challenging tasks, high responsibility, and a high impact</li>\n<li>Responsibility for own projects and a steep learning curve</li>\n<li>Working closely with an experienced developer team</li>\n<li>Deep insight into the workflow in a fast-growing startup</li>\n<li>Flat hierarchies as well as short and direct communication channels</li>\n<li>Motivated, talented colleagues</li>\n<li>Gym membership and other employer benefits</li>\n<li>Great atmosphere with free fruits &amp; drinks in our office in Berlin-Mitte</li>\n</ul>\n',
#   'how_to_apply': '<p><a href="https://carl.join.com/jobs/2049948-senior-frontend-developer-m-w-d?pid=357a3b4531918760973f&amp;oid=931a7239-ba3b-4e08-bcd1-ce4c27baa804&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=senior%2Bfrontend%2Bdeveloper%2Bm%2Bw%2Bd">https://carl.join.com/jobs/2049948-senior-frontend-developer-m-w-d?pid=357a3b4531918760973f&amp;oid=931a7239-ba3b-4e08-bcd1-ce4c27baa804&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=senior%2Bfrontend%2Bdeveloper%2Bm%2Bw%2Bd</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBbmFmIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--075fe9704acdffd031f3195f997a86f296f041a9/carl-finance-gmb-h-logo-xl.png'},
#  {'id': '2f497e92-3e04-419e-b985-86c1d8239f36',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/2f497e92-3e04-419e-b985-86c1d8239f36',
#   'created_at': 'Thu Apr 01 14:27:02 UTC 2021',
#   'company': 'Nouryon',
#   'company_url': 'https://www.nouryon.com/',
#   'location': 'Arnhem',
#   'title': 'Data Domain Specialist',
# ...
#   'how_to_apply': '<p><a href="https://t.gohiring.com/h/e79fe7e73e20c597e8b9cdb61a16df04a61c24ba12697ed46bf638ec22d46ada">application form</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcjZlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--88ddf2ee19f364d1b87d5617952b152d6670970a/Sharecare%20GmbH.png'},
#  {'id': 'a09dd3d4-f387-42c2-8757-96ed7715acb4',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/a09dd3d4-f387-42c2-8757-96ed7715acb4',
#   'created_at': 'Tue Mar 30 08:30:51 UTC 2021',
#   'company': 'Sharecare GmbH',
#   'company_url': 'https://www.sharecare.com/',
#   'location': 'Berlin',
#   'title': 'QA Engineer',
#   'description': '<p><strong>Who we are</strong></p>\n<p>Sharecare is the leading digital health company that helps people – no matter where they are in their health journey – unify and manage all their health in one place. Our comprehensive and data-driven virtual health platform is designed to help people, providers, employers, health plans, government organizations, and communities optimize individual and population-wide well-being by driving positive behavior change. Driven by our philosophy that we are all together better, at Sharecare, we are committed to supporting each individual through the lens of their personal health and making high-quality care more accessible and affordable for everyone.</p>\n<p>Our culture is fast-paced, high-energy and continually growing! We are always looking for people that value the opportunity to work hard, have fun on the job, and make a difference in the lives of others through their work every day! Our work is interesting and fun, because our team members are unique, talented and dynamic. We provide a setting where enthusiastic team members work together and take joy in coming to work. There are exciting career opportunities and advancement is supported by leadership teams who are invested in the growth and development of you.</p>\n<p><strong>Tasks and responsibilities</strong></p>\n<ul>\n<li>Be the voice of the users</li>\n<li>Ensure the quality of the company\'s product</li>\n<li>Create detailed, comprehensive and well-structured test plans</li>\n<li>Collaborate closely with other engineers and become a valued member of an autonomous, cross-functional team in our office in Berlin, Germany, and of our larger QA team in Atlanta, US.</li>\n</ul>\n<p><strong>Requirements</strong></p>\n<ul>\n<li>3+ years of experience as a QA Engineer</li>\n<li>Solid experience in Quality Assurance on web and mobile applications</li>\n<li>Experience in writing and maintaining test cases</li>\n<li>Curiosity and eagerness to learn new things and share your expertise</li>\n<li>Positive team spirit with a can-do attitude</li>\n<li>Fluent in English.</li>\n</ul>\n<p><strong>Knowledge and experience</strong></p>\n<ul>\n<li>Experience with automation tools, such as Selenium</li>\n<li>Passion for excellent software quality and user experience</li>\n<li>Excellent analytical and troubleshooting skills</li>\n<li>Knowledge of microservice architecture and log and alerts management tools would be advantageous.</li>\n</ul>\n<p><strong>What we offer</strong></p>\n<ul>\n<li>Be part of a dynamic, international and talented team</li>\n<li>The opportunity to get deeply involved in the research and development of our products</li>\n<li>A high degree of autonomy and flexibility</li>\n<li>A stack of the most modern technologies</li>\n<li>Flat hierarchies, cross-team collaborations and short and open channels of communication</li>\n<li>The chance to learn and grow with regular in-office tech training sessions and participation in conferences</li>\n<li>A generous perks and benefits program for all employees.</li>\n</ul>\n<p><strong>Application</strong></p>\n<p>Thank you for your interest in employment opportunities with <strong>Sharecare</strong>. We look forward to reviewing your submission!\nPlease apply with the link on the right.</p>\n<p><img src="https://camo.githubusercontent.com/d569a6fdaba910c8fd36733a3cc206ea3a320f52/68747470733a2f2f742e676f686972696e672e636f6d2f682f39663534316432623239656536626562353236643035656465663632623063366563656263613330383264383666623334643533323364643035393930346234"></p>\n',
#   'how_to_apply': '<p><a href="https://t.gohiring.com/h/8bc8ee8f0944acfb7e3ac6e9105cba9d7b7589bd70cf750346667255d67504ac">application form</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcnFlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--ba17fd40bc6d2965076fff919ae3e5bbdb1083ed/Sharecare%20GmbH.png'},
#  {'id': '21f600e4-b049-47a8-8bde-4168df3bf734',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/21f600e4-b049-47a8-8bde-4168df3bf734',
#   'created_at': 'Tue Mar 30 08:25:19 UTC 2021',
#   'company': 'go2cloud',
#   'company_url': 'https://www.go2cloud-hpc.de/',
#   'location': 'Hannover',
#   'title': 'DevOps Engineer (m/f/d)',
#   'description': '<p>go2cloud is a high performance computing (HPC) and infrastructure service provider founded in Europe with an international customer base and global reach. We are a rapidly growing and dynamic company in an industry of the future; we offer startup culture combined with professional services. Constant questioning of our processes and structures is part of our identity. Our goal is to provide high performance computing services related to artificial intelligence, big data analysis, blockchain, research and other compute-intensive applications, tasks and workflows. Due to the strong organic and inorganic growth of the corporate group, we are looking for new colleagues who want to shape the future with us.</p>\n<p><strong>Your mission</strong></p>\n<p>As a DevOps Engineer, you are continuously working in interdisciplinary project teams which are set in an agile development environment. You are eager to join our team creating a stable and scalable infrastructure located in different datacenters. You will take ownership of the infrastructure, monitor, optimize and automate it in order to make it future-proof. Your role in our DevOps team will be transformational and significant.</p>\n<p><strong>Responsibilities:</strong></p>\n<ul>\n<li>Support of the interaction between development, operations and quality assurance in the development and operation of IT services</li>\n<li>Grow and optimize our infrastructure; search for new technologies to keep it state of the art</li>\n<li>Ensure that our infrastructure is secured, monitored and scalable</li>\n<li>Drive the use of practices like continuous integration, continuous delivery and infrastructure as code</li>\n<li>You manage automation of reproducible configuration and rollout processes</li>\n</ul>\n<p><strong>Your profile</strong></p>\n<p><strong>Technical:</strong></p>\n<ul>\n<li>Software development experience and good knowledge of scripting languages such as Bash, Powershell, Python</li>\n<li>Practical knowledge with automated provisioning and management of private datacenter environments based on IaC tools (Terraform, Ansible)</li>\n<li>You have experience with automating and implementing recurring tasks in a CI/CD system (Azure DevOps)</li>\n<li>Proactive and practical approach about developing secure, scalable and stable environments</li>\n<li>Understanding of or experience in an agile software development environment</li>\n<li>Of course, you understand Git, YAML, Kanban and Docker</li>\n</ul>\n<p><strong>Personal:</strong></p>\n<ul>\n<li>Excellent communication skills in German and English</li>\n<li>Hands-on mentality, team player</li>\n<li>Good problem solving and troubleshooting skills</li>\n<li>Process-oriented mindset</li>\n</ul>\n<p><strong>Why should you join us?</strong></p>\n<p>This techstack awaits you:</p>\n<ul>\n<li>Terraform</li>\n<li>Azure DevOps</li>\n<li>Ansible</li>\n<li>Podman</li>\n<li>OpenStack</li>\n<li>Microsoft Azure</li>\n<li>RHEL/CentOS</li>\n<li>Icinga/Prometheus</li>\n</ul>\n<p>We offer the opportunity to be part of an exciting growth phase with plenty of room for personal and professional development. Due to the expansion of our group of companies, there are various opportunities to take over a responsible position in a timely manner. Join our small and diverse team and shape the future of high performance computing with us.</p>\n<p>We are looking for new colleagues who like to roll up their sleeves as much as we do and who bring along a lot of initiative as well as great enthusiasm for technologies. As an employer, equal opportunity is important to us. We firmly believe that employing a diverse workforce is essential to our success.</p>\n<p><img src="https://camo.githubusercontent.com/2bd0b20901135500832474dfaee44250e566a0c6/68747470733a2f2f742e676f686972696e672e636f6d2f682f65626131326535323263343431626132663538623930306336346238336334376165366665383765363763326430316431666261363638363537303464383831"></p>\n',
#   'how_to_apply': '<p><a href="https://t.gohiring.com/h/4392af72e05cc8a52361a40250909b2a5a476900049cf93dab2b2dd72c0a6fd3">application form</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcmllIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--aa3e21c9cc55fbbf1b17b655a9dbdec8a4fe2a93/go2group.png'},
#  {'id': 'ec55da29-4cc8-4713-b7a9-eb58e9a0584e',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/ec55da29-4cc8-4713-b7a9-eb58e9a0584e',
#   'created_at': 'Tue Mar 30 06:59:37 UTC 2021',
#   'company': 'KÖNIGSTEINER AGENTUR GmbH',
#   'company_url': None,
#   'location': 'Nürnberg',
#   'title': 'Ausbildung 2021 zum DevOps Specialist (m/w/d)',
#   'description': '<p>Entdecke eine neuartige Möglich\xadkeit, Dich zum DevOps Specialist (m/w/d) aus\xadbilden zu lassen – egal ob mit mittlerer Reife, als Ausbildungs- oder Studienabbrecher (m/w/d) – solange Dein Herz für neue Techno\xadlogien und Tools schlägt, freuen wir uns auf Deine Be\xadwer\xadbung.</p>\n<p>Was Dich erwartet\nDu lernst, ein Entwicklungs\xadteam dabei zu unter\xadstützen, seine Appli\xadka\xadtionen und Services mit einer geeig\xadneten Infra\xadstruktur zu releasen und zu be\xadtreiben\nDu wirst auf den Auf\xadbau der IT-Infra\xadstruk\xadtur nach dem Infra\xadstructure-as-Code (IaC)-Prin\xadzip vor\xadbe\xadreitet\nDu beschäftigst Dich mit hoch per\xadfor\xadmanten sowie hoch ver\xadfüg\xadbaren Services sowie deren Erstellung und Wartung\nDu entwickelst Skripte und Tools, die Dein Team für die Be\xadreit\xadstellung von Appli\xadka\xadtionen benö\xadtigt\nDu lernst, die Kon\xadzepte Continuous Integration und Continuous Deployment zu ver\xadstehen und umzu\xadsetzen\nDu arbeitest mit der Cloud-Computing-Platt\xadform von Microsoft Azure</p>\n<p>Was Dich auszeichnet\nDu bringst Eigeninitiative mit und hast Lust, Dich weiterzuentwickeln\nDu hast Spaß am Coden\nDu experimentierst gerne und lässt Dich auf Neues ein\nDu bist ein Netzwerker (m/w/d), der u. a. den Wissenstransfer sichert\nDu begeisterst Dich für Trends in der IT-Welt</p>\n<p>Was wir Dir bieten\nWahlweise IHK-Abschluss als Fach\xadinfor\xadmatiker (m/w/d) mit dem Schwer\xadpunkt System\xadinte\xadgra\xadtion oder An\xadwen\xaddungs\xadent\xadwick\xadlung\nSicherer Arbeitsplatz in einem leistungs- und wachs\xadtums\xadstarken Familien\xadunter\xadnehmen mit Tradition\nFundierte und struktu\xadrierte Ver\xadmitt\xadlung der Aus\xadbil\xaddungs\xadinhalte\nInteressante, abwechslungs\xadreiche und ver\xadant\xadwortungs\xadvolle Aufgaben\nArbeit in einem hoch moti\xadvier\xadten Team\nVielfältige Karriere\xadmöglich\xadkeiten\nWertschätzende Unter\xadnehmens\xadkultur\nArbeiten in einer Modern-Workplace-Um\xadgebung mit zeitgemäßer IT-Aus\xadstattung\nBetriebsrestaurant, Azubi-Ver\xadan\xadstal\xadtungen und vieles mehr</p>\n<p>Ausbildungs\xadvergütung nach Tarif Bau\xadwirt\xadschaft</p>\n<ol>\n<li>Jahr:     885 €</li>\n<li>Jahr:  1.108 €</li>\n<li>Jahr:  1.384 €</li>\n</ol>\n',
#   'how_to_apply': '<p><a href="https://brz.softgarden.io/sign-in?1&amp;l=de">https://brz.softgarden.io/sign-in?1&amp;l=de</a></p>\n',
#   'company_logo': None},
#  {'id': 'b6e2e98c-7868-4384-bb6a-c78fd3434063',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/b6e2e98c-7868-4384-bb6a-c78fd3434063',
#   'created_at': 'Tue Mar 30 01:16:21 UTC 2021',
#   'company': 'Axios',
#   'company_url': 'http://Axios',
#   'location': 'Remote (USA)',
#   'title': 'Senior Back-end Engineer',
#   'description': '<p>Quick take: Axios is a growth-stage startup dedicated to providing trustworthy, award-winning news content in an audience-first format. We’re hiring a Senior Backend Engineer!</p>\n<p>Why it matters: Our Engineering team enables our mission of delivering the cleanest, smartest, most efficient and trustworthy content to our users. This team member will be a core part of building our web-stack codebases, working closely with a squad on product direction, architecture, testing, and professional growth.</p>\n<p>Go deeper: In this role, you will help make Axios a stronger, more successful tech company through the following responsibilities:</p>\n<p>Building our products, with an emphasis on our newly launched B2B technology, Axios HQ\nWriting clean, well-documented, and well-tested code using best practices\nCollaborating with your product squad to ensure Axios ships the best products possible on time\nArchitect and build significant features across the platform\nMentoring and growing the next generation of software engineers through pair-programming and empathetic code review\nStaying up to date with industry trends and collaborating on best practices</p>\n<p>The details: Ideal candidates will embody an entrepreneurial spirit and passion for Axios’ mission and possess the following skills and attributes:</p>\n<p>Deep experience and interest in Python and Django/Django REST Framework\nFamiliarity with JavaScript/TypeScript and a frontend framework such as React, Angular or Vue\nExperience working with CI/CD pipelines and understanding of best deployment practices\nProven ability to ship high-quality, testable, and accessible code quickly\nExperience with PostgreSQL\nExperience building &amp; maintaining REST APIs\nExperience working on cross-functional agile teams where you advocate for technical needs as well as the best solution to the problems at hand\nSpecific passion for user-focused and data-driven decision making\nExperience with data modeling in relational databases\nExperience working with product designers and product managers\nA belief in and commitment to Axios’ diversity, equity, and inclusion values\xa0</p>\n<p>Don’t forget:</p>\n<p>Competitive salary\nHealth insurance (100% paid for individuals, 75% for families)\nPrimary caregiver 12-week paid leave\n401K\nGenerous vacation policy, plus company holidays\nCompany equity\nCommuter and cell phone benefit\nA commitment to an open, inclusive, and diverse work culture\nAnnual learning and development stipend</p>\n<p>Additional pandemic-related benefits:</p>\n<p>One mental health day per quarter\n$100 monthly work-from-home stipend\nTele-mental health services\xa0\nOneMedical membership, including tele-health services\xa0\nIncreased work flexibility for parents and caretakers\xa0\nAccess to the Axios “Family Fund”, which was created to allow employees to request financial support when facing financial hardship or emergencies\xa0\nCompany-sponsored fitness discount\nVirtual company-sponsored social events</p>\n',
#   'how_to_apply': '<p><a href="https://grnh.se/f8e39b411us">https://grnh.se/f8e39b411us</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcmFlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--4f869d9643ac18a70273d9a7d60bb464198f2070/Axios%20logo%20-%20RGB%20-%20minimum%20space.jpg'}]

# %%
len(r.json())
# Out:
# 50

# %%
# According to the documentation, the results are split into pages
# These were the results from the first page only

# %%
# To get the next page, we need to make another GET request with parameter 'page'
r =  requests.get(base_site, params = {"page": 2})
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'id': '0afd4a73-afae-480b-b84d-0de29bedbe22',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/0afd4a73-afae-480b-b84d-0de29bedbe22',
#   'created_at': 'Tue Mar 30 01:14:21 UTC 2021',
#   'company': 'Axios',
#   'company_url': 'http://Axios',
#   'location': 'Remote (USA)',
#   'title': 'Back-end Engineer',
#   'description': '<p>Quick take: Axios is a growth-stage startup dedicated to providing trustworthy, award-winning news content in an audience-first format. We’re hiring a Backend Engineer!</p>\n<p>Why it matters: Our Engineering team enables our mission of delivering the cleanest, smartest, most efficient and trustworthy content to our users. This team member will be a core part of building our web-stack codebases, working closely with a squad on product direction, architecture, testing, and professional growth.</p>\n<p>Go deeper: In this role, you will help make Axios a stronger, more successful tech company through the following responsibilities:</p>\n<p>Building our products, with an emphasis on our newly launched B2B technology, Axios HQ\nWriting clean, well-documented, and well-tested code\nCollaborating with your product squad to ensure Axios ships the best products possible on time\nHelp architect and build significant features across the platform\nStaying up to date with industry trends and collaborating on best practices</p>\n<p>The details: Ideal candidates will embody an entrepreneurial spirit and passion for Axios’ mission and possess the following skills and attributes:</p>\n<p>Experience and interest in Python and Django\nFamiliarity with JavaScript/TypeScript and a frontend framework such as React, Angular or Vue\nExperience working with CI/CD pipelines and understanding of best deployment practices\nExperience with PostgreSQL\nProven ability to ship high-quality, testable, and accessible code quickly\nExperience working with product designers and product managers\nExperience building &amp; maintaining REST APIs\nExperience with data modeling in relational databases\nA belief in and commitment to Axios’ diversity, equity, and inclusion values\xa0</p>\n<p>Don’t forget:</p>\n<p>Competitive salary\nHealth insurance (100% paid for individuals, 75% for families)\nPrimary caregiver 12-week paid leave\n401K\nGenerous vacation policy, plus company holidays\nCompany equity\nCommuter and cell phone benefit\nA commitment to an open, inclusive, and diverse work culture\nAnnual learning and development stipend</p>\n<p>Additional pandemic-related benefits:</p>\n<p>One mental health day per quarter\n$100 monthly work-from-home stipend\nTele-mental health services\xa0\nOneMedical membership, including tele-health services\xa0\nIncreased work flexibility for parents and caretakers\xa0\nAccess to the Axios “Family Fund”, which was created to allow employees to request financial support when facing financial hardship or emergencies\xa0\nCompany-sponsored fitness discount\nVirtual company-sponsored social events</p>\n',
#   'how_to_apply': '<p><a href="https://grnh.se/084ce78b1us">https://grnh.se/084ce78b1us</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcldlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--1496a7b0601971d57b397d4596f73387934dfe26/Axios%20logo%20-%20RGB%20-%20minimum%20space.jpg'},
#  {'id': 'a6a86c8a-5f53-4bad-87b0-0604c3c8b8a8',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/a6a86c8a-5f53-4bad-87b0-0604c3c8b8a8',
#   'created_at': 'Tue Mar 30 01:12:25 UTC 2021',
#   'company': 'Axios',
#   'company_url': 'http://Axios',
#   'location': 'Remote (USA)',
#   'title': 'Quality Engineer',
#   'description': '<p>Quick take: Axios is a growth-stage startup dedicated to providing trustworthy, award-winning news content in an audience-first format. We are hiring a\xa0Quality Engineer!</p>\n<p>Why it matters: The quality team’s mission at Axios is to ensure our technology is of the highest quality for our readers and clients every day. The quality team integrates tightly into our cross-functional product teams to refine requirements for our products and to ensure the systems delivered line up.</p>\n<p>Go deeper: The Quality Engineer’s responsibility is to ensure Axios’ products align with our business needs and are bug-free. Responsibilities of this role include:</p>\n<p>Participating with product managers and the rest of your squad to define and refine requirements\nProviding feedback to the squad on the potential risks and mitigation tactics of their intended approach\nUtilizing both manual and automated testing strategies\nManaging bugs, including identification, logging, tracking and triaging\nWorking with the team to manage risk and reduce it to an acceptable level\nWorking with engineers to implement test automation\nWriting and executing test plans</p>\n<p>The details: Ideal candidates will embody an entrepreneurial spirit, a passion for Axios’ mission and have the following skills and attributes:</p>\n<p>Experience in Software Quality Assurance or Quality Engineering\nExperience testing web applications\nExperience testing mobile applications\nExperience writing test automation\nExperience testing in an Agile environment\nExcellent written and verbal communication skills\nExceptionally collaborative\nObsessive attention to detail\nA belief in and commitment to Axios’ diversity, equity, and inclusion values</p>\n<p>We’ll be even more excited if you have:</p>\n<p>Worked in environments using Ruby, Python, Node and/or Javascript\nExperience testing services and working with Docker containers\nThe ability to set up test environments, deploy code, use the command line\nExperience working in a Continuous Integration environment</p>\n<p>Don’t forget:</p>\n<p>Competitive salary\nHealth insurance (100% paid for individuals, 75% for families)\nPrimary caregiver 12-week paid leave\n401K\nGenerous vacation policy, plus company holidays\nCompany equity\nCommuter and cell phone benefit\nA commitment to an open, inclusive, and diverse work culture\nAnnual learning and development stipend</p>\n<p>Additional pandemic-related benefits:</p>\n<p>One mental health day per quarter\n$100 monthly work-from-home stipend\nTele-mental health services\xa0\nOneMedical membership, including tele-health services\xa0\nIncreased work flexibility for parents and caretakers\xa0\nAccess to the Axios “Family Fund”, which was created to allow employees to request financial support when facing financial hardship or emergencies\xa0\nVirtual company-sponsored social events</p>\n',
#   'how_to_apply': '<p><a href="https://grnh.se/3f5752651us">https://grnh.se/3f5752651us</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBck9lIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--ad43ed8f11d0d4f8e9f54c3d0060dc86fa951f3f/Axios%20logo%20-%20RGB%20-%20minimum%20space.jpg'},
#  {'id': '33fd422a-10c4-43d4-84bc-6bac8fa84731',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/33fd422a-10c4-43d4-84bc-6bac8fa84731',
#   'created_at': 'Mon Mar 29 20:21:53 UTC 2021',
#   'company': 'A1500',
#   'company_url': 'https://a1500.com',
#   'location': 'Remote',
#   'title': 'Desarrollador React Native',
#   'description': '<p>Estamos en la búsqueda de un desarrollador experimentado en React Native para unirse a un equipo de trabajo con el objetivo de crear una aplicación mobile que se asemeja a otros productos del mercado que ofrecen contenido de video en formato de historias.</p>\n<p>Secciones estándar de Inicio, Search, Profile (login) y player con diferentes visualizaciones full screen. También cuenta con funcionalidades de "me gusta", "compartir" y similares a otras redes sociales.</p>\n<p>Los objetivos esperados del profesional son comprender el alcance del proyecto necesario para salir al mercado, la etapa actual de desarrollo, encontrar problemas existentes y ayudar a definir la mejor manera de llegar a una versión estable para su lanzamiento trabajando en equipo.</p>\n<p>La contratación es full remote como contractor para A1500, empresa radicada en USA. Se ofrece sueldo en dólares estadounidenses.</p>\n<p>El postulante debe:</p>\n<ul>\n<li>Tener experiencia trabajando con Redux-saga</li>\n<li>Poder compilar en simuladores tanto para Android como iOS</li>\n<li>Se valora conocimientos de React Native Video</li>\n<li>Se valora conocimientos de React Navigation V5</li>\n<li>Se valora conocimientos en WatermelonDB</li>\n<li>Se valoran conocimientos en react-native-reanimated y react-native-gesture-handler</li>\n<li>Idioma Español para comunicarse con el equipo. EXCLUYENTE</li>\n<li>Poder trabajar cerca de la zona horaria GMT-3</li>\n</ul>\n',
#   'how_to_apply': '<p>Envía tu CV o linkedin a <a href="mailto:jobs@a1500.com">jobs@a1500.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcktlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--512b92dba017d277ee6490c8de74955bf2ba17d4/a1500_logo-azul%20(1).png'},
#  {'id': 'd369f688-4fc0-4435-90cb-567254bd8dca',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/d369f688-4fc0-4435-90cb-567254bd8dca',
#   'created_at': 'Mon Mar 29 19:41:52 UTC 2021',
#   'company': 'Vida Health',
#   'company_url': 'https://www.vida.com',
#   'location': 'San Francisco or remote (USA)',
#   'title': 'Sr. Software Engineer - Backend',
#   'description': '<h2>About Us</h2>\n<p>At Vida, we empower individuals to overcome chronic mental and physical health conditions, once and for all. The impact of chronic conditions on healthcare is immense: in the US alone, chronic diseases like diabetes and heart disease drive 80% of the $3 trillion healthcare spending, which is at 18% of GDP. One in 3 individuals has a chronic health condition, and 1 in 4 struggles with mental health.</p>\n<p>Vida provides expert, personalized, on-demand health coaching and programs from a network of experienced health care providers and leading medical institutions. Vida is a next generation continuous care platform for both consumers and businesses, combining a consumer mobile app, an enterprise care platform offering on demand 24/7 solutions for chronic conditions. Vida platform runs in the cloud, captures real-time data from 100+ devices and apps, and integrates back to the employer, payer, and provider. We are trusted by Fortune 1000 companies, major national payers and large providers to enable their employees live their healthiest lives.</p>\n<p><strong><em>Vida is authorized to do business in many, but not all, states. If you are not located in or able to work from a state where Vida is registered, you will not be eligible for employment. Please speak with your recruiter to learn more about where Vida is registered.</em></strong></p>\n<p>The backend engineering team designs and builds our API’s and services that power the mobile and web applications. You will be joining this creative and dedicated team and make an immediate impact on our business. We are small enough for you to have a large impact and big enough to learn and grow from your peers.</p>\n<p>The team works cross functionally with a multidisciplinary team of mobile, test, web, product, design and clinical experts to build and design new product experiences for both our providers and our members.</p>\n<h2>Responsibilities</h2>\n<ul>\n<li>Design and build distributed infrastructure services which enable multiple applications for the rapid member growth at Vida.</li>\n<li>Collaborate within your team: review and give feedback on mobile and web features and designs, design APIs to enable the features, test, ramp, and monitor the success of the features you build</li>\n<li>Collaborate across Backend engineering: help bring new ideas and best practices to other Backend engineers, help define and drive the long term technical roadmap</li>\n<li>Be an owner of your work in all environments from staging to production. We are looking for those willing to raise their hand and step up to follow a project all the way through, from finding the problem to celebrating the solution.</li>\n<li>Help set up monitoring and alerting on services to continuously improve our SLA.</li>\n<li>Help find cloud native solutions to problems and find ways to increase efficiency and reduce cost of services</li>\n</ul>\n<h2>Qualifications</h2>\n<ul>\n<li>Experience with designing service oriented architectures, distributed systems, and REST APIs</li>\n<li>Ability to lead and coordinate delivery of work with other software engineers.</li>\n<li>Strong skills and experience in the foundational skills of Software Engineering, such as Data Structures, OO Design, Relational Databases</li>\n<li>Experience with cloud platforms such as AWS or Google Cloud</li>\n<li>Excellent communication and interpersonal skills</li>\n<li>Ability to inspire and make others around you better and become more energized</li>\n<li>A relentless focus on delivering maximum value to the end user</li>\n<li>Ownership mindset: Be excited about monitoring and alerting on your systems, be ready to query your own tracking data to find out how your feature is doing</li>\n<li>Has a track record of delivering high quality products/services.</li>\n<li>Growth mindset and an ability to persevere through grit</li>\n<li>5-8 years of relevant work experience</li>\n</ul>\n<h2>Bonus Skills</h2>\n<ul>\n<li ...
#   'how_to_apply': '<p>Apply online here: <a href="https://jobs.lever.co/vida/4a3eda24-5435-41e1-9fb5-ceef7c6afa8c?lever-origin=applied&amp;lever-source%5B%5D=GitHub">https://jobs.lever.co/vida/4a3eda24-5435-41e1-9fb5-ceef7c6afa8c?lever-origin=applied&amp;lever-source%5B%5D=GitHub</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBckNlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--05f91a2d0bb693a5cfb3639423d68dc32b04f4ac/vida_primary_color_RGB.png'},
#  {'id': 'ec3c2598-f4f9-4f1a-aeac-9b924af88e19',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/ec3c2598-f4f9-4f1a-aeac-9b924af88e19',
#   'created_at': 'Mon Mar 29 16:47:08 UTC 2021',
#   'company': 'Smaply',
#   'company_url': 'https://www.smaply.com/careers',
#   'location': 'Innsbruck, Austria',
#   'title': 'Senior Ruby on Rails Developer',
#   'description': '<p>Smaply is run by More than Metrics, a fast growing company in the field of service design, located in the heart of the Austrian Alps (perfect for sports and nature lovers). We have a software solution (Smaply) which helps other companies visualize, analyze and innovate their customer experience. We have B2B customers in more than 90 countries. \u200bWe are a small but mighty team of 27 folks with diverse backgrounds and 13 different nationalities. \u200bWe enjoy flat hierarchies, high transparency and a lot of flexibility. We are hard working, big dreaming and enjoying the ride with much laughter. Now we are looking for a peer to join us on our journey.</p>\n<h1>Senior Backend Developer</h1>\n<h2>Your role on this journey</h2>\n<ul>\n<li>You will be part of the entire lifecycle of new features, from the shitty first draft to the deployment of the finished feature</li>\n<li>You design, build, and maintain efficient, reusable, and reliable Ruby code</li>\n<li>You take over our RESTful API (RoR/Grape) and document it</li>\n<li>You regularly review our app performance and take measures to speed it up</li>\n<li>You implement, improve, maintain and cluster our services (MySQL, Redis, s3, Elasticsearch)</li>\n<li>You plan, improve and maintain our infrastructure orchestration IaC (infrastructure as code) over multiple hosting environments (gcloud, aws, on-prem, ...)</li>\n<li>You regularly review our ecosystem and perform updates and security checks</li>\n<li>You share standby-duties for maintenance in case of outages/errors</li>\n<li>You join forces with our frontend developers</li>\n</ul>\n<p><strong>Our tech stack</strong>\n<strong>GNU/Linux - Docker - Ruby on Rails - MySQL - Redis - Sidekiq - Webpack</strong></p>\n<h2>What we need from you</h2>\n<ul>\n<li>You’re experienced in Ruby on Rails development and have a natural interest in other -programming languages</li>\n<li>You have experience writing model-, system-, integration- and functional tests (or however you name them)</li>\n<li>You have professional experience in designing and implementing efficient RESTful APIs</li>\n<li>You have a good understanding of user authentication and able to quickly adopt new technologies like SAML, OpenID Connect, OAuth</li>\n<li>You have professional experience working with MySQL, Redis, s3, Elasticsearch or similar technologies</li>\n<li>You are a skilled GNU/linux user and highly confident with server configuration and management, especially in production environments</li>\n<li>You have professional experience orchestrating Ruby on Rails applications</li>\n<li>Drive to learn cutting edge cloud clustering and deployment techniques including Terraform, Rancher and Kubernetes</li>\n<li>You’re willing to take part in our (paid) standby-duty schedule and be on call if something goes south.</li>\n<li>You are a self-organized team player and take over tasks on personal initiative</li>\n</ul>\n<h2>Your benefits</h2>\n<ul>\n<li>A salary of at least 44.000 Euro p.a. (depending on your experience)</li>\n<li>38,5 hours/week with flexible work time and optional home office</li>\n<li>A variety of projects in a fast-growing and meaningful business</li>\n<li>Flat hierarchies, transparency and flexibility are our working standards</li>\n<li>Being creative and challenging the status quo is requested</li>\n<li>An energetic team achieving great things with many laughters along the way</li>\n<li>25 vacation days, full health insurance, occupational accident insurance, public pension scheme, public unemployment insurance and more. (Austria is a good place for social security).</li>\n<li>Benefits such as bonus payment, ESOP, subsidized public transport ticket, free parking, a big terrace with a bbq, free team lunches, legendary team events and many more</li>\n<li>The luxury of being surrounded by nature and having everything in walking distance</li>\n</ul>\n<p><strong>Join us in our exceptional base in Innsbruck, Austria, the action capital of ...
#   'how_to_apply': '<p>Ready? Drop us a line to <a href="mailto:career@smaply.com">career@smaply.com</a> to introduce yourself and let’s have a chat.</p>\n<p>We’re looking forward to meeting you!</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcXllIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--fae482fb08071f122baf1a5000116eacd737460e/1608049086745.png'},
#  {'id': 'cf736ac6-e402-45fb-8048-aecbe4ee4443',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/cf736ac6-e402-45fb-8048-aecbe4ee4443',
#   'created_at': 'Mon Mar 29 16:11:13 UTC 2021',
#   'company': 'Wipfli LLP',
#   'company_url': None,
#   'location': 'Chicago, IL',
#   'title': 'Senior Android Developer',
#   'description': '<p>At Wipfli, people count</p>\n<p>Our people are core to everything we do — the catalyst behind our ability to create exceptional impact and extraordinary results.</p>\n<p>We believe in flexibility. We focus on relationships. We encourage each individual to follow their own path. And we seek feedback openly, from all.</p>\n<p>People matter here and they feel it.</p>\n<p>And we value curiosity.\xa0 Curious is more than a personality trait. It’s a way of thinking. Of learning. Of working.</p>\n<p>There’s purpose in this wonder. It makes us better. It makes us Wipfli.</p>\n<p>If you want to be in an environment where you can make a difference — and make a professional home — Wipfli is the place for you.</p>\n<p>Responsibilities\nThe Senior Android Developer position is for an energetic and proactive engineer who will work alongside other application developers and support staff. We are looking for a decisive individual who possesses the skills set to manage multiple initiatives, spanning new software development projects as well as application maintenance and support.</p>\n<ul>\n<li>Lead architecture and development of Android applications</li>\n<li>Coordinate with strategy, internal and external stakeholders, and design during various project states</li>\n<li>Be a core contributor to codebases across many projects and clients</li>\n<li>Collaborate closely across development disciplines to coordinate, and in some cases drive feature functionality and implementation</li>\n<li>Promote good team practices, such as regular code review and pair programming</li>\n<li>Assisting the client support team using your technical background</li>\n<li>Bring vision to the team in the form of new technology recommendations and approaches</li>\n</ul>\n<p>Qualifications</p>\n<ul>\n<li>Minimum of 5 years development experience with the Android SDK in Android Studio</li>\n<li>Experience with Kotlin and Java</li>\n<li>Background working with RESTful APIs</li>\n<li>Familiarity working with Git version control in a collaborative team environment, creating pull requests and performing code reviews</li>\n<li>Strong knowledge of relational databases and ability to write performant queries using SQL</li>\n<li>Working knowledge of software design patterns, experience writing automated tests</li>\n<li>Have contributed to at least 1 application on the Google Play Store</li>\n<li>Familiar with Coroutin/Rxjava, Dagger/Koin, Retrofit and other libraries</li>\n<li>Experience with MVVM with DataBinding architecture</li>\n<li>Experience with Unit and UI testing</li>\n</ul>\n<p>Nice to Haves</p>\n<ul>\n<li>A published app in the Google Play Store that demonstrates your skills and expertise</li>\n<li>Experience working with alternative mobile frameworks like React Native/Fluter</li>\n<li>Skill is working with clients, explaining complex requirements and concerns to a variety of different audiences</li>\n<li>Experience building iOS and/or web applications</li>\n<li>A degree in computer science, software engineering, or similar field</li>\n</ul>\n<p>Our recruiting team will guide you through our evaluation and interviewing process. We will communicate an update on your status\xa0as soon as possible.\xa0The recruiting team member guiding you through this process is Jane Welch, and you can find her on LinkedIN\xa0Here. She is based in our\xa0Madison, WI office and looks forward to guiding you through this process.\xa0</p>\n',
#   'how_to_apply': '<p>Apply online: <a href="https://careers-wipfli.icims.com/jobs/3436/job">https://careers-wipfli.icims.com/jobs/3436/job</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcUdlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--025ede3f4a45db8a28da265ad9c1f84827d5cb55/Wipfli%20Logo%20Blue%20RGB.png'},
#  {'id': '5d51e61b-d9e0-4cbf-b259-43c841275ead',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/5d51e61b-d9e0-4cbf-b259-43c841275ead',
#   'created_at': 'Mon Mar 29 14:02:24 UTC 2021',
#   'company': 'Request',
#   'company_url': 'https://request.network/en',
#   'location': 'Remote',
#   'title': 'Full-stack Engineer',
#   'description': '<p>At Request, our mission is to interconnect isolated financial systems to create more efficient and inclusive economies. We are accomplishing this by building a completely decentralized and open network for transaction requests.</p>\n<p>WE BUILD THE FUTURE OF INVOICING AND BUSINESS</p>\n<p>Our core technology is an open-source protocol. It allows records of transactions to be easily stored and accessed on the blockchain. This network gives financial systems a shared language to communicate.</p>\n<p>On top of this, we are building Request Invoicing, a crypto-friendly invoicing application. Request users benefit from our unique payment detection solution, automatically reconciling invoices and their payments. CFOs, accountants and auditors save time and maintain more accurate bookkeeping.</p>\n<p>THE ROLE</p>\n<p>We are looking for an experienced Full-stack Engineer to join the development team, used to development on solutions with high usage (2000-5000 monthly users), to support our scaling phase.</p>\n<p>YOUR RESPONSIBILITIES</p>\n<p>Participate in the Request Invoicing development\nKeep yourself up-to-date with our stack: Typescript, Node, React, Mongo, Kubernetes, Docker, NPM, Circle CI.\nParticipate in the continuous improvement of the Request Network library, make it easy to pay and get paid on Ethereum and other public blockchains with open source packages: request-client.js, payment-processor, payment-detection, etc.\nPropose functional design improvements, challenge the infrastructure, the development &amp; release process.\nDesign and implement integrations with partners (Invoicing REST API, payment detection on other blockchains, accounting software etc.)\nOptionally gain knowledge and responsibility over our decentralized framework: ethers.js, IPFS, Solidity, Infura.</p>\n<p>QUALIFICATIONS</p>\n<p>Solid knowledge of computer science fundamentals: algorithms, data structures, databases, distributed systems, operating systems, networking\nStrong interest in blockchain technology, and the future of payments\nStrong knowledge of Typescript and Node.js\nUsed to open-source development\nUnderstanding of API design (REST, RPC)\nGood understanding of git and continuous integration tools\nSelf-motivated, innovative and proactive\nAbility to take responsibility for projects and the willingness to learn and grow professionally in a team environment\nWillingness to improve by giving and asking for feedback\nTeam spirit above personal results</p>\n<p>Bonus - this makes you stand out</p>\n<p>Good knowledge of Ethereum: frequent dapp usage or smart-contract development\nFamiliarity with kubernetes, Helm, Google Cloud Platform, CircleCI\nMobile development (architecture, design, development framework)\nCryptography\nMonitoring of stability and performances</p>\n<p>WHY WORK WITH REQUEST ?</p>\n<p>Being on the frontier of this new and exciting technology, you will be given the chance to lead the way forward!\nYou will have the opportunity to work in a highly ambitious team that wants to have a lasting impact on the way we experience finance tomorrow\nWork in an informal and friendly environment that is very open to new initiatives and ideas\nThe team is inclusive, with inspirational and international colleagues that like to participate in team events\nUnlimited vacation days with a mandatory minimum of 20/year.\nWe all work remotely (even without pandemic) but we love to meet as frequently as possible, with at least 3 company-wide reunions per year where possible.\nSalary: 60 000€ - 80 000€ yearly</p>\n',
#   'how_to_apply': '<p><a href="https://request-network.homerun.co/full-stack-engineer/en/apply?&amp;step=1">https://request-network.homerun.co/full-stack-engineer/en/apply?&amp;step=1</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcCtlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--5e035fc28a3086c2c5eb9f029d6f25cd98bd1d4a/Capture%20d%E2%80%99%C3%A9cran%202019-03-06%20%C3%A0%2014.51.53.png'},
#  {'id': '83730041-7cfb-41c7-a00e-d154e478e07a',
#   'type': 'Part Time',
#   'url': 'https://jobs.github.com/positions/83730041-7cfb-41c7-a00e-d154e478e07a',
#   'created_at': 'Mon Mar 29 13:48:20 UTC 2021',
#   'company': 'PGGM',
#   'company_url': None,
#   'location': 'Zeist',
#   'title': 'Senior Low code (Outsystems) Developer',
#   'description': '<p>PGGM heeft voor haar locatie in Zeist een vacature voor een</p>\n<p><strong>Senior Low code (Outsystems) Developer</strong>\n<strong>32-36 uur - Zeist</strong></p>\n<p><strong>Zie jij het als jouw nieuwe uitdaging om ons te helpen door een belangrijke rol te spelen in de transitie van .Net naar Outsystems?</strong></p>\n<p><strong>Jouw rol</strong>\nSinds 2020 zijn we met een kleine groep IT-medewerkers met het lowcode platform Outsystems applicaties aan het ontwikkelen voor het Pensioenbeheer domein. Outsystems is onze 2e ontwikkelstraat naast de al langer bestaande .NET ontwikkelstraat.  De backlog van de Outsystems teams groeit flink en daarom zijn we op zoek naar een ervaren Outsystems developer.</p>\n<p><em>Jouw baan als Senior Outsystems developer</em>\nAls Senior Outsystems developer werk je vanuit een klein team met enthousiaste en gedreven collega’s aan back-end oplossingen. Het team beheert en ontwikkelt softwaresystemen t.b.v. de communicatie met deelnemers via pensioenoverzichten (UPO’s) en via het Pensioenregister <a href="https://www.mijnpensioenoverzicht.nl">www.mijnpensioenoverzicht.nl</a>. Het huidige systeem is gebouwd in .NET en zal nieuw gebouwd worden in Outsystems. Met jouw kennis van Outsystems speel je een belangrijke rol in het begeleiden van de transitie van het huidige team, samen met collega’s van het al bestaande Outsystems team.</p>\n<p>Jouw rol als developer is onderdeel van een breed scala aan activiteiten van het team: het analyseren, ontwikkelen, testen en beheren van IT-oplossingen. Wat je doet, hangt af van wat er nodig is voor het team. Je zult je constant moeten aanpassen aan wat nodig is, waarbij je prioriteit is om te leveren wat je belooft: toekomstbestendige IT-oplossingen.</p>\n<p><strong>Jouw afdeling binnen PGGM</strong>\nSamen met 6 collega’s werk je in scrumteam Pensioencommunicatie, dat jaarlijks ruim 3 miljoen pensioenoverzichten voor deelnemers maakt, en 1,5 miljoen raadplegingen van <a href="https://www.mijnpensioenoverzicht.nl">www.mijnpensioenoverzicht.nl</a> ondersteunt.</p>\n<p>Je komt te werken in een zelfsturend team, met een groot verantwoordelijkheidsgevoel. Het team is onderdeel van Pensioenbeheer IT waar ongeveer 150 IT medewerkers samenwerken aan de uitdagende veranderkalender, o.a. de voorbereiding op het nieuwe pensioencontract, maar uiteraard ook aan de run.</p>\n<p>In onze professionele werkomgeving krijg je volop kansen om jouw vakmanschap te tonen en met de nieuwste tooling en technieken te werken.</p>\n<p><strong>Jouw achtergrond</strong>\nFouten maken? Als senior developer ben jij hier niet bang voor. Sterker nog, jij weet dat dit erbij hoort om elke dag beter te worden. Ook als er niet om gevraagd wordt pak jij alle noodzakelijke werkzaamheden op, dus soms ook test(automatisering), soms bouw, soms analyse, etc. Je houdt van afwisseling en vindt het leuk om met mensen van de business samen de juiste oplossing te zoeken. Door te observeren en te luisteren vallen jou zaken op, stelt vragen en komt met ideeën voor verbetering. Je biedt actief hulp aan en staat er open voor dat iemand resultaat bereikt via een andere weg, ook al is die misschien minder efficiënt en snel. Je laat iemand in zijn waarde, maar prikkelt wel om te verbeteren. Je maakt een goede afweging tussen resultaat, kwaliteit en tijd. En die afweging wordt constant getoetst en bijgesteld, door met de andere betrokkenen te praten. In jouw beleving gaat het er niet om dat IT fantastisch is, maar dat IT er is om Pensioenbeheer haar werk beter te laten doen.</p>\n<p>Verder beschik je over:</p>\n<ul>\n<li>Hbo werk- en denkniveau, bij voorkeur door een opleiding in een technische richting.</li>\n<li>Minimaal 2 jaar ervaring als Outsystems developer.</li>\n<li>Kennis van .Net en SQL is een pré.</li>\n<li>Interesse in (pensioen)functionaliteit.</li>\n</ul>\n<p><strong>Dutch speaking candidates only.</strong></p>\n<p><strong>Wat wij bieden:</strong>\nVolop kansen om jezelf te ontwikke ...
#   'how_to_apply': '<p>Wil jij als Senior Low code (Outsystems) developer de verantwoordelijkheid dragen voor een goed pensioen van 4,4 miljoen pensioendeelnemers? Solliciteer dan op deze vacature en kies voor een baan met impact.</p>\n<p>Heb je vragen of wil je eerst meer te weten komen tijdens een virtuele kop koffie? Neem dan contact op met Wendy Ship, via 06 – 20 31 18 52 of <a href="wendy.ship@pggm.nl">wendy.ship@pggm.nl</a>.</p>\n<p>Wij ontvangen je sollicitatie graag via onze <a href="https://www.pggm.nl/werken-bij/vacatures/vacature/senior-low-code-outsystems-developer---zeist-32-36-uur/?id=a0w1v00000CYpAcAAL&amp;utm_source=github&amp;utm_medium=referral&amp;utm_term=2021&amp;utm_content=182976&amp;utm_campaign=senior-low-code-outsystems-developer">sollicitatiepagina</a>.</p>\n<p>Informatie over de sollicitatieprocedure vind je terug op onze website.</p>\n<p><strong>PGGM en Corona</strong>\nDoor de Corona situatie, werken de meeste PGGM’ers momenteel vanuit huis. Als we met je kennis willen maken, betekent dit dat de interviews grotendeels via videocalls plaatsvinden. Een afrondend gesprek doen we op kantoor. Nemen we je aan? Dan zal het grootste deel van jouw inwerktraject op afstand gebeuren. Hierbij maken we gebruik van Microsoft Teams. Het is beperkt mogelijk om collega’s op kantoor te ontmoeten.</p>\n<p><strong>Aan intermediairs</strong>\n<strong>We weten dat er veel partijen zijn die graag met ons mee willen zoeken of hun diensten willen aanbieden voor deze vacature, maar bij PGGM werven we nieuwe collega’s zelf. Acquisitie naar een werving &amp; selectie-opdracht of onaangekondigde aanbiedingen van CV\'s stellen we dan ook niet op prijs en nemen wij niet in behandeling. Mochten we er niet uitkomen, dan bellen we jou.</strong></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcDJlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--857258d6c9f1336a73c637804b36493b03ef3e35/Logo%20PGGM.jpg'},
#  {'id': '59ebfd26-4246-4114-9d6e-d7d8bd84528b',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/59ebfd26-4246-4114-9d6e-d7d8bd84528b',
#   'created_at': 'Mon Mar 29 11:37:09 UTC 2021',
#   'company': 'Verkstedt GmbH',
#   'company_url': 'https://verkstedt.com',
#   'location': 'Berlin',
#   'title': 'Junior DevOps Engineer (f/m/x)',
#   'description': '<p>Hi! We are verkstedt. 👋</p>\n<p>We are a team of software developers, located in the heart of Berlin Mitte.</p>\n<p>We are passionate about delivering high quality web applications with a strong focus on performance, scalability and robust solutions that don’t bother us during a nice board game session on a Saturday night.</p>\n<p>We are looking for a DevOps Engineer to join our team.</p>\n<p>Join us and become part of a seasoned team of skilled engineers! We offer you the opportunity to shape and evolve large-scale software projects, work flexibly and focus on code and shipping products, not bureaucracy.</p>\n<p>Software engineering is always about trade-offs. Thus we try to focus on implementing pragmatic solutions and getting things done, rather than succumbing to dogmas.</p>\n<p><strong>Tasks</strong></p>\n<p>Your tasks will involve a combination of the following:</p>\n<ul>\n<li>Setting up and maintaining our cloud infrastructure on Google Cloud Platform (GCP) with Terraform, Kubernetes, Cloud SQL, Cloud Run, and more.</li>\n<li>Exploring and evaluating new tools and services (lately we are interested in setting up and testing out Rasa).</li>\n<li>Loving care of a small server zoo using Ansible, Docker and some Linux.</li>\n<li>Loosing a good portion of your sanity when building and maintaining CI/CD pipelines for our frontend and backend applications.</li>\n<li>Supporting the team with infrastructure and ideas on how to run things in a pragmatic yet robust way.</li>\n<li>Participate in as little meetings as possible.</li>\n<li>Contributing to open source projects.</li>\n<li>Working on greenfield projects.</li>\n<li>If this sounds like what you are looking for, get in touch! – We look forward to meeting you.</li>\n</ul>\n<p><strong>Requirements</strong></p>\n<p>Basically there is only one major requirement we have: you should simply enjoy collaborating on providing the infrastructure for great applications!</p>\n<p>If you can combine this with some experience on cloud infrastructure, we’re very interested to meet for a coffee! 😊</p>\n<p>Apart from that, since we’re a small team and we strongly believe that software development is a team sport and it is important for you to be self organised and enjoy interacting with other human beings.</p>\n<p>This also includes a strong ability to find pragmatic solutions for complex problems and being able to accept that there are always multiple ways to achieve a given goal.</p>\n<p>For us this also includes, that no one should be afraid of failures. As a team we only should try not to repeat them.</p>\n<p>You should also be able to speak English fluently (and from time to time it can come in handy to speak a few words in German).</p>\n<p><strong>Benefits</strong></p>\n<ul>\n<li>a competitive salary.</li>\n<li>flexible working hours.</li>\n<li>time for working on Open Source projects during our regular Open Fridays and</li>\n<li>you can choose the gear you like.</li>\n<li>Implementing web applications means hard work, so we always make sure to have enough coffee, fruits, Club Mate &amp; snacks in the office and at our place we also hold regular Board Game evenings for those interested.</li>\n<li>Great! Simply fill in the application form below and we will get in touch within a week.</li>\n</ul>\n<p>What we then usually do is to start with a quick chat via Skype (or whatever channel works) to get to know each other and for you to ask any question that might come to mind.</p>\n<p>If we all agree to proceed we would invite you for a coding challenge, which allows us to have a second more indepth discussion with you about your work.</p>\n<p>And that’s basically all the application process there is.</p>\n',
#   'how_to_apply': '<p><a href="https://verkstedt.join.com/jobs/2054861-junior-devops-engineer-f-m-x?pid=357a3b4531918760973f&amp;oid=7cebefc6-0553-4199-9188-53c5f0816f6d&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=junior%2Bdevops%2Bengineer%2Bf%2Bm%2Bx">https://verkstedt.join.com/jobs/2054861-junior-devops-engineer-f-m-x?pid=357a3b4531918760973f&amp;oid=7cebefc6-0553-4199-9188-53c5f0816f6d&amp;utm_source=github_jobs&amp;utm_medium=paid&amp;utm_campaign=single%2Bposting&amp;utm_content=junior%2Bdevops%2Bengineer%2Bf%2Bm%2Bx</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcGVlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--41e3b421681b09e96c8450eeffc6757cf600367b/Logo-verkstedt-292x300.png'},
#  {'id': '2e129e0f-8ace-4911-920e-70a8b60e6b50',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/2e129e0f-8ace-4911-920e-70a8b60e6b50',
#   'created_at': 'Mon Mar 29 08:51:36 UTC 2021',
#   'company': 'Lampenwelt GmbH',
#   'company_url': 'https://www.lampenwelt.de/',
#   'location': '10969',
#   'title': 'Microsoft System Specialist 100% Homeoffice (m/w/x)',
#   'description': '<p>Suchst du eine neue, spannende Herausforderung? Eine Anstellung mit starken Entwicklungsmöglichkeiten in einem der führenden Online-Unternehmen Deutschlands? Persönliche und berufliche Entfaltungsmöglichkeiten?</p>\n<p><a href="http://lampenwelt.de/">Lampenwelt.de</a> gehört zu den führenden E-Commerce Unternehmen Deutschlands und ist unter den Online-Spezialisten in seiner Branche <strong>Marktführer</strong> und Benchmark in Europa. Wir sind in <strong>17 europäischen Ländern</strong> aktiv. Mit einem Team von aktuell <strong>über 500 Mitarbeitern aus 25 Nationen</strong> schreiben wir die Erfolgsgeschichte von Lampenwelt fort – und brauchen Verstärkung.</p>\n<p><strong>Deine Aufgaben:</strong></p>\n<ul>\n<li>Administration klassischer Systemlandschaften auf Basis von Windows Server sowie einzelner Linux Systeme</li>\n<li>Unterstützung bei der Analyse und Migration von Workloads in die Cloud (Microsoft Azure, SaaS)</li>\n<li>Mithilfe bei Verwaltung und Aufbau verschiedener cloudbasierter Services auf Basis von Microsoft Azure</li>\n<li>Einarbeitung in die Steuerung von SaaS-Lösungen verschiedener Anbieter, besonders im Microsoft 365 Umfeld</li>\n<li>Weiterentwicklung interner Prozesse, z.B. im Bereich Security sowie Patchmanagement</li>\n<li>Planung und Durchführung von\u202fIT-Projekten im dynamischen E-Commerce-Umfeld</li>\n<li>Fehleranalysen, Erarbeitung von Problemlösungen und Sicherstellung störungsfreier Abläufe</li>\n<li>Technischer 2nd und 3rd Level Support als Teil eines motivierten &amp; aufstrebenden Teams</li>\n<li>Erstellung von Projekt-, System-\u202fund Anwendungsdokumentationen</li>\n</ul>\n<p><strong>Du bringst mit:</strong></p>\n<ul>\n<li>Abgeschlossene Berufsausbildung im Bereich der IT, abgeschlossenes Studium in den Bereichen Wirtschaftsinformatik,\u202fInformatik oder eine ähnliche Ausbildung\u202f</li>\n<li>Mehrjährige praktische Erfahrung\u202fals IT-Systemadministrator im Microsoft-Umfeld</li>\n<li>Erfahrung in der Systemvirtualisierierung, idealerweise mit Microsoft Azure und/oder VMware</li>\n<li>Teamfähigkeit, Kommunikationsbereitschaft und hohes Engagement</li>\n<li>Analytische, konzeptionelle, strukturierte und eigenständige Arbeitsweise</li>\n<li>Fundierte Problemlösungskompetenz</li>\n<li>Deutsche Sprachkenntnisse auf einem Mindestlevel von C1</li>\n<li>Gute Englischkenntnisse in Wort und Schrift</li>\n</ul>\n<p><strong>Wir bieten:</strong></p>\n<p><strong>Homeoffice</strong></p>\n<ul>\n<li>Home-Office Regelung</li>\n</ul>\n<p><strong>Mitarbeiterrabatte</strong></p>\n<ul>\n<li>Sonderkonditionen auf unsere Produktpalette</li>\n</ul>\n<p><strong>Ergonomischer Arbeitsplatz</strong></p>\n<ul>\n<li>Individuelle Arbeitsplatzeinrichtung und höhenverstellbare Tische</li>\n</ul>\n<p><strong>FlexWork</strong></p>\n<ul>\n<li>Möglichkeit der Gleitzeitarbeit</li>\n</ul>\n<p><strong>Freie Getränke und Obst</strong></p>\n<ul>\n<li>So viel Wasser und Kaffee, wie du trinken kannst und regelmäßige Obsttage</li>\n</ul>\n<p><strong>Individuelle Weiterentwicklungsmöglichkeiten</strong></p>\n<ul>\n<li>Individuelle Weiterbildung und Besuch von Fachmessen</li>\n</ul>\n<p><strong>JobRad</strong></p>\n<ul>\n<li>Beitrag zum eigenen Wunschrad</li>\n</ul>\n<p><strong>Sport- und Fitnessangebote</strong></p>\n<ul>\n<li>Sonderkonditionen für Lampenweltmitarbeiter in allen Fitnessstudios</li>\n</ul>\n<p><strong>Unternehmerische Atmosphäre</strong></p>\n<ul>\n<li>Firmenevents und hohe Wertschätzung der Mitarbeiter</li>\n</ul>\n<p><strong>Teamgeist</strong></p>\n<ul>\n<li>Auf einen Kaffee treffen mit unserem CEO in der Teeküche? Teilnehmen an der firmeneigenen Lauf- oder Fußballgruppe? Bei uns wird das Miteinander gelebt!</li>\n</ul>\n<p><strong>Dein Ansprechpartner:</strong></p>\n<p>Melissa Barnes\n+49 6642-406 99 9930\n<a href="mailto:melissa.barnes@lampenwelt.de">melissa.barnes@lampenwelt.de</a></p>\n<p>Wir freuen uns auf deine aussagekräftigen Bewerbungsunterlagen!\n<strong>Bewerbungen bitte online unte ...
#   'how_to_apply': '<p><a href="https://t.gohiring.com/h/ea1994f1cfb5c23d5af9328814caf32d855d6a0c097f67e40c7acb51d771d1f7">application form</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcE9lIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--6817c5a1d60a7857c0946eb8ece66b11bc967d57/Lampenwelt%20GmbH.jpg'},
#  {'id': 'fd66c52e-ea9f-4e73-a7a4-3a4a43c64fdb',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/fd66c52e-ea9f-4e73-a7a4-3a4a43c64fdb',
#   'created_at': 'Mon Mar 29 08:00:12 UTC 2021',
#   'company': 'DEVK Versicherungen',
#   'company_url': 'https://www.devk.de/',
#   'location': 'Germany (50735 Cologne)',
#   'title': 'Pega Entwickler (d/m/w)',
#   'description': '<p>Pega Entwickler (d/m/w)</p>\n<p>Seit mehr als 130 Jahren legen Versicherte in Deutschland ihre Risiken des Alltags vertrauensvoll in die Hände der DEVK Versicherungen. Heute ist die DEVK bundesweit präsent und betreut die persönlichen Anliegen von über vier Millionen Kunden in allen Versicherungssparten.</p>\n<p>In unserem Team "Akquiseanwendungen" entwickeln wir mit agilen Methoden auf der Plattform Pega eine neue CRM-Software, die von unseren Kunden und Mitarbeitenden bereits erfolgreich genutzt wird. Wenn Sie unser Team durch Ihr Wissen ergänzen und kontinuierlich weitere Skills in Coaching Sessions, Pair Programming, PEGA-Schulungen und einem intensiven Austausch im Team aufbauen wollen, sind Sie bei uns richtig!</p>\n<p>Ihre Aufgaben</p>\n<ul>\n<li>Entwicklung des DEVK-Vertriebssystems basierend auf aktueller Pega Version 8.4</li>\n<li>Umsetzung von Aufgaben in einem agilen Team</li>\n<li>Unterstützung bei der Analyse von fachlichen und technischen Anforderungen</li>\n<li>Stetige Weiterentwicklung Ihres technischen Know Hows in Pega</li>\n</ul>\n<p>Ihr Profil</p>\n<ul>\n<li>Erfolgreich abgeschlossenes (Wirtschafts-) Informatikstudium oder vergleichbare Ausbildung</li>\n<li>Erfahrungen im Bereich Softwareentwicklung</li>\n<li>Datenbankkenntnisse im Bereich PostgreSQL von Vorteil</li>\n<li>Spaß an eigenverantwortlichem Arbeiten in einem jungen und dynamischen Team</li>\n<li>Innovationsfähigkeit und Interesse an neuen technologischen Entwicklungen</li>\n<li>Offenheit das Angebot der DEVK zur permanenten Weiterentwicklung anzunehmen</li>\n</ul>\n<p>Unsere Benefits</p>\n<ul>\n<li>Sichere Arbeitsplätze in einem stetig wachsenden Unternehmen</li>\n<li>Eine hervorragende arbeitgeberfinanzierte betriebliche Altersversorgung</li>\n<li>Flexible Arbeitszeitmodelle</li>\n<li>Möglichkeit für Homeoffice / Mobiles Arbeiten</li>\n<li>Stark vergünstigtes Job-Ticket</li>\n</ul>\n<p>Informieren Sie sich über unsere weiteren Benefits. Wir freuen uns darauf, Sie persönlich kennenzulernen. Falls Sie noch Fragen haben, rufen Sie uns gerne an.</p>\n<p>Ihr Ansprechpartner\nTanja Willing\nTel.: +49 221 757-1154</p>\n',
#   'how_to_apply': '<p><a href="https://bewerbungsportal.devk.de/index">https://bewerbungsportal.devk.de/index</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcEdlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--af86e5d1b1c321d3a5b89fa9a217e17c8ee0b3ef/DEVK_logo_treffer.png'},
#  {'id': '7cab75c5-221f-4a1b-94b9-b02b86db00b9',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/7cab75c5-221f-4a1b-94b9-b02b86db00b9',
#   'created_at': 'Mon Mar 29 07:56:59 UTC 2021',
#   'company': 'DEVK Versicherungen',
#   'company_url': 'https://www.devk.de',
#   'location': 'Germany (50735 Cologne)',
#   'title': 'Spezialist (d/m/w) MSSQL & IIS',
# ...
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaG1lIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--0ad36fd5fda1b4425a68092988bd8af5cb5fa49e/logo-parity-dark.png'},
#  {'id': '802627e3-383f-4f4a-b6d4-52ba56bfe73e',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/802627e3-383f-4f4a-b6d4-52ba56bfe73e',
#   'created_at': 'Wed Mar 24 14:57:49 UTC 2021',
#   'company': 'BT Careers',
#   'company_url': 'https://www.bt.com/careers',
#   'location': 'Birmingham, UK',
#   'title': 'Data Engineer',
#   'description': "<p>Data has never been more important to BT. We’re creating the best personal experiences for our customers to help them stay connected, and that mission is all underpinned by high quality, low latency data. This role will play a critical part in the creation and running of BT Consumer’s foundational data layer and the data products built on top.</p>\n<p>As part of a team of highly skilled data engineers, you will create and maintain our logical data models, integrating data from multiple data sources into a central cloud repository. You will apply data cleansing and data standardisation rules, providing clear documentation of the business rules embedded in the system, with the potential of solving data quality issues through your team. You will work closely with the wider team to understand what the data journey needs to look like and work closely with the Data Architect team to develop our products and services. You will write and maintain data engineering user documentation to provide transparency and maintain the knowledge base within the team.</p>\n<p>You'll have the following responsibilities</p>\n<p>Applies specialist data expertise to develop and advise approach on a range of complex, high impact and data solutions a services. Assures data availability and quality in Consumer and across our systems. Helps to resolve technical problems. Proactively identifies new potential data sources and assess feasibility of ingesting. Develops tangible and ongoing standardisation, simplification and efficiency of engineering processes, reviewing and revising continuous improvement opportunities. Assures a high quality and comprehensive data flow and manage a team that provides a consumption layer where the business has access to all the data it needs. Ensures all data is compliant. Ensures that all data acquired is fully described/understood and communicated using appropriate tools. Productionise any tactical data feeds, including documentation</p>\n<p>You'll have the following skills &amp; experience</p>\n<p>Deep technical knowledge of complex (and simple) data architectures, covering all aspects (compliance, risk, security) of our requirements. Detailed knowledge of the concepts and principles of data engineering. Sound awareness of Data Management best practice, including data lifecycle management. Extensive skills in SQL, both at production grade and at analytical level, gained through intensive application in a commercial business environment. Can deliver complex big data solutions with structured and unstructured data. Excellent oral and written communication skills for all levels of an organisation. Collaborate to identify how work activities across the teams are related and highlight inefficiencies. You help to remove barriers and find the resources or support needed to improve processes. Lead collaborative ways of working and continuous improvement in your team\nBenefits</p>\n<p>Along with the great development and networking building opportunities you will also enjoy:</p>\n<p>A target bonus of up to 10%.\nPension contributions.\nShare save scheme.\nAccess to exclusive staff products and savings.</p>\n",
#   'how_to_apply': '<p>Apply online here &gt; <a href="https://bit.ly/3tOMDVz">https://bit.ly/3tOMDVz</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaGFlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--018eb42d0e5925d8c90666b99cab00ce5b0322ba/72943102_10158157464064271_469294175737610240_n.png'},
#  {'id': '3e31e5f9-cd24-4f2f-927c-2e4d91d78a36',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/3e31e5f9-cd24-4f2f-927c-2e4d91d78a36',
#   'created_at': 'Wed Mar 24 15:00:42 UTC 2021',
#   'company': 'Parity Technologies',
#   'company_url': 'http://parity.io',
#   'location': 'Berlin, DE or Remote',
#   'title': 'Rust Performance Engineer',
#   'description': "<p>At Parity Technologies we maintain and create blockchain software: dealing with P2P networking, consensus algorithms, cryptography, databases, and decentralized applications can be expected.</p>\n<p>We strive to write the fastest, lightest, and safest core technology in Blockchain and write lots of open-source code. Parity Technologies is based in Berlin and London, but remote work is possible for the right people and we are flexible on location.</p>\n<p>We are looking for someone very experienced with the Rust programming language, all the way down to compiler knowledge. You will be responsible for the performance of our application and investigate problems, design necessary tests, perform monitoring and architect solutions to counter possible bottlenecks.</p>\n<p>Parity works in a very flat hierarchy with lots of autonomy and high levels of personal responsibility, and we try to mimic an open-source workflow in much of what we do.</p>\n<p>Requirements:</p>\n<ul>\n<li>Highly experienced with Rust.</li>\n<li>Understanding how the Rust compiler, toolchain, and async work.</li>\n<li>Strong knowledge of data structures, algorithms, and efficient implementation in modern programming languages.</li>\n<li>Keen interest in hunting down performance problems and memory leaks, including building tooling for it.</li>\n<li>Writing efficient and maintainable code.</li>\n<li>Ability to work independently and autonomously.</li>\n</ul>\n<p>Nice to have:</p>\n<ul>\n<li>Understanding of blockchain technologies.</li>\n<li>An interest in decentralized and privacy technology and Web3.</li>\n<li>Knowledge of internals of the rust async stack, especially tokio and threading.</li>\n<li>Already written performance metering and improvement tooling.</li>\n</ul>\n<p>Benefits:</p>\n<ul>\n<li>Competitive salaries and benefits.</li>\n<li>Opportunity to become an expert in latest blockchain technologies.</li>\n<li>Working at Parity means focusing on stuff that matters: building cutting-edge technology for a better and more decentralized internet. Our teams enjoy a high degree of freedom and autonomy to achieve that goal.</li>\n<li>Because we value initiative and learning, we've defined a generous personal improvement budget to attend conferences or skills courses of your own choosing. We think you know what's best for you!</li>\n<li>Parity is a diverse company with people from various countries and we will support you with</li>\n<li>German or English language courses where needed (and desired).</li>\n<li>We have a remote-friendly company setup.</li>\n<li>Bringing the team together is something we value a lot and we have regular company retreats (or will have, pending the Covid pandemic).</li>\n</ul>\n<p>Not a perfect match to our requirements? We're happy to receive your application anyways and hear how you think you can help us achieve our mission.</p>\n",
#   'how_to_apply': '<p>Apply directly at <a href="https://grnh.se/3060623b3us">https://grnh.se/3060623b3us</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBaGVlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--b1b1040933be6114b5b31171e46d56b18ffde76e/logo-parity-dark.png'},
#  {'id': '02b68b31-9894-44e0-ac69-21c9da5c7977',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/02b68b31-9894-44e0-ac69-21c9da5c7977',
#   'created_at': 'Wed Mar 24 12:47:54 UTC 2021',
#   'company': 'Parity Technologies',
#   'company_url': 'http://parity.io/jobs',
#   'location': 'Berlin, DE or Remote',
#   'title': 'JavaScript Lead Engineer',
#   'description': '<p>Parity Technologies builds core infrastructure for blockchains and the future Web — one that respects the freedom and data of individuals — and helps empower developers to create better services through decentralized technologies.</p>\n<p>Have a look at our current documentation to see what you’ll be working with:</p>\n<p>Polkadot-JS API and toolset docs: <a href="https://polkadot.js.org/">https://polkadot.js.org/</a></p>\n<p>In this role, you will:</p>\n<ul>\n<li>Technically design and build Web Applications for Polkadot-js ecosystem</li>\n<li>Support the entire application lifecycle (concept, design, build, test, release and support)</li>\n<li>Write clean code to produce fully functional web &amp; mobile applications</li>\n<li>Write tests and make sure code is up to high level standard</li>\n<li>Work closely with our UX team to build interfaces to make the user experience intuitive and enjoyable</li>\n<li>Collaborate with the core team to plan and implement new features and improvements</li>\n<li>Take responsibility for development progress and work with the team to overcome roadblocks</li>\n</ul>\n<p>Your Background:</p>\n<ul>\n<li>Experience in working with a range of different JavaScript APIs and Frameworks</li>\n<li>Ability to produce working, auditable, well-tested code.</li>\n<li>Ability to learn new technologies and concepts quickly</li>\n<li>Ability to come up with technical solutions and application architecture</li>\n<li>Ability to work autonomously, be proactive, prioritize, communicate, and function in a distributed team.</li>\n<li>Passionate about bringing the Web 3 vision of a decentralized web to the world.</li>\n</ul>\n<p>Nice-to-haves:</p>\n<ul>\n<li>Former involvement in Open Source Projects</li>\n<li>Knowledge in blockchain technologies</li>\n<li>Knowledge in another programming language than JavaScript/ TypeScript</li>\n<li>Experience with working on the Node database layer (eg. Express, MongoDB, CouchDB, GraphQL)</li>\n</ul>\n<p>Relevant tech-stack we’re currently using:</p>\n<p>JavaScript (ES2015+), TypeScript, WebAssembly, Node, React, Electron, RxJS, Jest, GitHub, GitLab, Vuepress</p>\n<p>Benefits:</p>\n<ul>\n<li>Competitive salaries and benefits.</li>\n<li>Opportunity to become an expert in latest blockchain technologies.</li>\n<li>Working at Parity means focusing on stuff that matters: building cutting-edge technology for a better and more decentralized internet. Our teams enjoy a high degree of freedom and autonomy to achieve that goal.</li>\n<li>Because we value initiative and learning, we\'ve defined a generous personal improvement budget to attend conferences or skills courses of your own choosing. We think you know what\'s best for you!</li>\n<li>Parity is a diverse company with people from various countries and we will support you with</li>\n<li>German or English language courses where needed (and desired).</li>\n<li>We have a remote-friendly company setup.</li>\n<li>Bringing the team together is something we value a lot and we have regular company retreats (or will have, pending the Covid pandemic)</li>\n</ul>\n',
#   'how_to_apply': '<p>Apply directly at <a href="https://grnh.se/7bb41d213us">https://grnh.se/7bb41d213us</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZzZlIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--6f358a66c7b65e88b9a33a23e836812e3cfb4a2a/logo-parity-dark.png'},
#  {'id': '333f25c3-629f-49bd-a495-6c85f8a79f1c',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/333f25c3-629f-49bd-a495-6c85f8a79f1c',
#   'created_at': 'Wed Mar 24 12:18:36 UTC 2021',
#   'company': 'Reaktor',
#   'company_url': 'https://www.reaktor.com',
#   'location': 'Amsterdam',
#   'title': 'Software Developer',
#   'description': '<p>Curious about applying your tech skills in different domains?\nEnjoy planning and theory, but get the most joy out of the execution?\nPassionate about finding new ways of working with your teammates?\nExcited about solving human problems with a holistic approach?</p>\n<p>Look at you sounding like a Reaktorian already 😎</p>\n<p><strong>At Reaktor, we design and build tomorrow’s digital products. We are known for our flat hierarchy, have a <a href="https://www.glassdoor.nl/Locatie/Reaktor-Amsterdam-Locatie-EI_IE589428.0,7_IL.8,17_IC3064478.htm">5-star Glassdoor rating</a>, and <a href="https://reaktorspace.com/reaktor-hello-world/">launched a satellite</a> running Node.js in low Earth orbit.</strong></p>\n<p>The Amsterdam office has a unique vibe, being a lively mix of 18 nationalities. From day one, our growth philosophy has been to hire any and all Reaktorians out there. This has served us well, with a welcoming community of humans who will connect with you beyond the day-to-day. Check out the Reaktor culture in our <a href="https://www.reaktor.com/blog/?utm_source=github&amp;utm_medium=referral&amp;utm_campaign=software_developer&amp;utm_content=job_listing">blog</a> and listen to our <a href="https://www.reaktor.com/forkpullmergepush/?utm_source=github&amp;utm_medium=referral&amp;utm_campaign=software_developer&amp;utm_content=job_listing">podcast</a>.</p>\n<p><strong>We make our clients succeed in technology</strong></p>\n<p>Reaktor teams work in close co-operation with our clients. We deliver anything from the automation of beer brewing processes and fintech mobile apps; to the scaling of infrastructure needed for drops of limited-edition adidas sneakers.</p>\n<p>When you’re a Reaktorian, you’re going to be collaborating with our top minds to solve really juicy tech problems in meaningful, future-forward ways. If it runs code, our team can make it.</p>\n<p><strong>Ideally you…</strong></p>\n<ul>\n<li>View your colleagues and clients as individuals with their respective strengths and weaknesses.</li>\n<li>Believe that sometimes tech is best solved with no code at all, but by talking to the right people.</li>\n<li>Can work with the team to decide the best tools for the job at hand. Sometimes it’s Clojure running in a Kubernetes cluster, and sometimes it’s a small piece of JS running on AWS Lambda.</li>\n<li>Enjoy working with juniors and seniors on the shiny and dirty bits of the codebase. No ivory tower architects here.</li>\n</ul>\n<p><strong>What about the tech?</strong></p>\n<p>We know that good developers can create great things in any language. We have no hard language or tech requirements. Things we get excited about include: functional programming, state management, Node.js, Clojure, TypeScript, React, Swift, Kotlin, SQL and NoSQL, Kanban.</p>\n<p><strong>Sounds like you? We need to meet!</strong></p>\n<ul>\n<li>💻 We’ll start with a brief video chat, just to say hi. Hi!</li>\n<li>👋🏽 Then we’ll get to know you a bit better. We call this the Culture and Attitude interview.</li>\n<li>😎 Next up is a technical interview. No brain teasers or sorting algos, we promise. You choose a couple of topics to discuss, we’ll choose a couple of topics to discuss.</li>\n<li>📃 Finally, the closing interview. Here we discuss practicalities and make you an offer we hope you can’t refuse.</li>\n<li>❤️ You’re in!</li>\n</ul>\n<p>So, dear future colleague, we can’t wait to hear from you! Please, apply with <a href="https://www.reaktor.com/careers/software-developer-amsterdam/?utm_source=github&amp;utm_medium=referral&amp;utm_campaign=software_developer&amp;utm_content=job_listing#apply">this form</a>.</p>\n',
#   'how_to_apply': '<p><a href="https://www.reaktor.com/careers/software-developer-amsterdam/?utm_source=github&amp;utm_medium=referral&amp;utm_campaign=software_developer&amp;utm_content=job_listing#apply">Click here for the application form!</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBZ3llIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--8ce99d22a630860bfe6f091adf1dc52736a88bb8/reaktor_logo_RGB_black.png'}]

# %%
len(r.json())
# Out:
# 50

# %%
# Making a request to a non-existing page
r = requests.get(base_site, params = {"page": 10})
r.status_code
# Out:
# 200

# %%
# The response is an empty list
r.json()
# Out:
# []

# %% [markdown]
# ### Extracting results from multiple pages

# %%
# Let's obtain the results of the first 5 pages
results = []

# %%
for i in range(5):
    r =  requests.get(base_site, params = {"page": i+1})
    
    if len(r.json()) == 0:   # We have reached the end of the results
        break
    else:
        # Add the response results to our list of results
        results.extend(r.json())

# %%
# number of found jobs
len(results)
# Out:
# 250
